# %%
import os

import json
import pandas as pd
from utils.bedrock_functions import build_anthropic_request_body, invoke_bedrock_endpoint
from utils.prompts import gen_search_task_prompt

data_dir = '/home/ec2-user/code_repos/PersonalizationAE/inputs/pwab_data'

# %%
def load_json(files, data_dir= data_dir):
    if isinstance(files, str):
        with open(f"{data_dir}/{files}", "r", encoding="utf-8") as f:
            data = json.load(f)
            print(f"Loaded {len(data)} records from {files}")
            return data

    elif isinstance(files, list):
        
        combined_data = []
        for filepath in files:
            with open(f"{data_dir}/{filepath}", "r", encoding="utf-8") as f:
                data = json.load(f)
                combined_data.append(data)
                print(f"Loaded {len(data)} records from {filepath}")
                
        # if combined_data is a list of lists, flatten it
        if isinstance(combined_data[0], list):
            combined_data = [item for sublist in combined_data for item in sublist]
        # if combined_data is a list of dicts, combine them
        elif isinstance(combined_data[0], dict):
            combined_data = {k: v for d in combined_data for k, v in d.items()}
        else:
            raise ValueError("Data must be a list of lists or a list of dicts.")
        return combined_data

    else:
        raise ValueError("Argument must be either a single file path (string) or a list of file paths.")

# %%
filenames = os.listdir(data_dir)

# Identify files belonging to 'all_products'
all_products_files = [
    f for f in filenames
    if f.startswith("all_products_part_") and f.endswith(".json")
]

# Identify files belonging to 'user_history'
user_history_files = [
    f for f in filenames
    if f.startswith("user_history_part_") and f.endswith(".json")
]

# Sort files if desired (e.g., to ensure consistent order)
all_products_files.sort()
user_history_files.sort()

# %%
all_products = load_json(all_products_files)
user_history = load_json(user_history_files)
user_instructions = load_json("user_instructions.json")
user_profiles = load_json("user_profiles.json")
# Out:
# Loaded 17886 records from all_products_part_1.json
# Loaded 17886 records from all_products_part_2.json
# Loaded 334 records from user_history_part_1.json
# Loaded 334 records from user_history_part_2.json
# Loaded 332 records from user_history_part_3.json
# Loaded 2 records from user_instructions.json
# Loaded 1000 records from user_profiles.json

# %%
user_instructions['train'][0]['target']['product_info']#['user_id']
# Out:
# {'main_category': 'Home_and_Kitchen',
#  'title': 'Electropan Replacement Vacuum Filter Brush Kit for Robotic Vacuum ILIFE V3, V3s, V3s pro, V5, V5s, V5s pro ILIFE Robot Vacuum Replacement Parts Ilife Vacuum Filters V3s',
#  'average_rating': 4.3,
#  'rating_number': 2534,
#  'features': ['Vaccum Parts works with Ilife V3, Ilife V3s pro, Ilife V5, Ilife V5s, Ilife V5s Pro Robotic Vacuum Cleaner. Good quality ilife v3s pro Robotic Vacuum Replacement Parts',
#   'Robot Parts Cleaner Accessory kit can keep your vacuum cleaner at peak performance, Suggest to replace ILIFE Vacuum Filters & Robot Vacuum Brush Replacement every 2-3 months',
#   'Vacuum Cleaner Parts/ robot Vacuum Accessories for Ilife robot helps to keep your house clean and save effort for housework',
#   'Ilife Vacuum Replacement Parts is very easy to install, and very easy to wash these Ilife vacuum parts (including Ilife robot vacuum hepa filters, Ilife vacuum primary filter, Ilife robot vacuum side brushes)',
#   '100% Compatible with Ilife Vacuum Cleaner Accessories/Ilife Parts/Replacement Vacuum Filters/Vacuum Cleaner Hepa Filters Replacements for Ilife'],
#  'description': [],
#  'price': '18.0',
#  'store': 'Electropan',
#  'categories': ['Home & Kitchen',
#   'Vacuums & Floor Care',
#   'Vacuum Parts & Accessories',
#   'Attachments & Brushes',
#   'Attachments'],
#  'details': {'Brand Name': 'Electropan',
#   'Item Weight': '6.7 ounces',
#   'Package Dimensions': '8.03 x 5.31 x 2.44 inches',
#   'Color': 'Part 2',
#   'Compatible Device': 'ilife v3s vacuum robot, ilife robot vacuum cleaner V3, ilife vacuum cleaner V5, ilife v5s robotic mop & vacuum cleaner, ilife v5s pro robot vacuum mop cleaner',
#   'Material Type': 'HEPA',
#   'Batteries Included?': 'No',
#   'Batteries Required?': 'No',
#   'Best Sellers Rank': {'Industrial & Scientific': 11469,
#    'Commercial Indoor Vacuum Fittings': 15,
#    'Vacuum Attachments': 301},
#   'Date First Available': 'August 20, 2020',
#   'Brand': 'Electropan',
#   'Material': 'HEPA',
#   'Compatible Devices': 'ilife v3s vacuum robot, ilife robot vacuum cleaner V3, ilife vacuum cleaner V5, ilife v5s robotic mop & vacuum cleaner, ilife v5s pro robot vacuum mop cleanerilife v3s vacuum robot, ilife robot vacuum cleaner V3, ilife vacuum cleaner V5, ilife v5s robotic mop & vacuum cleaner, ilife v5s pro robot vacuum m…  See more',
#   'Duration': '3',
#   'Reusability': 'Reusable'},
#  'parent_asin': 'B08GC2KTG6'}

# %%
user_prof_list = []
for i in range(len(user_instructions['train'])):
    user_prof_list.append(user_profiles[user_instructions['train'][i]['user_id']]['user_profile'])

# %%
df = pd.DataFrame(user_prof_list)

# %%
df
# Out:
#       Gender    Age Occupation Price Sensitivity  \
# 0     Female  35-44     Writer            Medium
# 1     Female  35-44     Writer            Medium
# 2     Female  35-44     Writer            Medium
# 3     Female  35-44     Writer            Medium
# 4     Female  35-44     Writer            Medium
# ...      ...    ...        ...               ...
# 6891  Female  35-44     Writer            Medium
# 6892  Female  35-44     Writer            Medium
# 6893  Female  25-34      Other               Low
# 6894  Female  25-34      Other            Medium
# 6895  Female  35-44     Writer            Medium
#
#                                       Shopping Interest  \
# 0     Electronics, Home & Kitchen, Fashion, Health &...
# 1     Electronics, Home & Kitchen, Fashion, Health &...
# 2     Electronics, Home & Kitchen, Fashion, Health &...
# 3     Electronics, Home & Kitchen, Fashion, Health &...
# 4     Electronics, Home & Kitchen, Fashion, Health &...
# ...                                                 ...
# 6891               Home & Kitchen, Electronics, Fashion
# 6892               Home & Kitchen, Electronics, Fashion
# 6893  Electronics, Home & Kitchen, Health & Househol...
# 6894   Electronics, Home Goods, Clothing, Personal Care
# 6895               Home & Kitchen, Electronics, Fashion
#
#                                        Brand Preference Diversity Preference  \
# 0     Aibocn, DACHEE, IBENZER, Columbia, Nutrition E...                 High
# 1     Aibocn, DACHEE, IBENZER, Columbia, Nutrition E...                 High
# 2     Aibocn, DACHEE, IBENZER, Columbia, Nutrition E...                 High
# 3     Aibocn, DACHEE, IBENZER, Columbia, Nutrition E...                 High
# 4     Aibocn, DACHEE, IBENZER, Columbia, Nutrition E...                 High
# ...                                                 ...                  ...
# 6891  Anker, Sleepwish, DOWAN, Under Armour, Canon, ...               Medium
# 6892  Anker, Sleepwish, DOWAN, Under Armour, Canon, ...               Medium
# 6893  Amazon, Fantasia, Hypnotic Gems, Cuarto Astral...                 High
# 6894  ASURION, MR.SIGA, WYUZE, Hanes, SONORO KATE, D...               Medium
# 6895  Anker, Sleepwish, DOWAN, Under Armour, Canon, ...               Medium
#
#      Interaction Complexity                                  Tone and Style  \
# 0                      High                Enthusiastic, Detailed, Positive
# 1                      High                Enthusiastic, Detailed, Positive
# 2                      High                Enthusiastic, Detailed, Positive
# 3                      High                Enthusiastic, Detailed, Positive
# 4                      High                Enthusiastic, Detailed, Positive
# ...                     ...                                             ...
# 6891                 Medium  Detailed, practical, and occasionally humorous
# 6892                 Medium  Detailed, practical, and occasionally humorous
# 6893                   High                Positive, Enthusiastic, Detailed
# 6894                 Medium               Positive, Enthusiastic, Practical
# 6895                 Medium  Detailed, practical, and occasionally humorous
#
#                                          Item Reference  \
# 0     Specific products and brands mentioned frequently
# 1     Specific products and brands mentioned frequently
# 2     Specific products and brands mentioned frequently
# 3     Specific products and brands mentioned frequently
# 4     Specific products and brands mentioned frequently
# ...                                                 ...
# 6891  Specific products and brands mentioned frequently
# 6892  Specific products and brands mentioned frequently
# 6893  Specific products and brands mentioned in reviews
# 6894  Specific products, Purchase history, Recommend...
# 6895  Specific products and brands mentioned frequently
#
#                                     Focus Aspect
# 0                          Quality, Brand, Price
# 1                          Quality, Brand, Price
# 2                          Quality, Brand, Price
# 3                          Quality, Brand, Price
# 4                          Quality, Brand, Price
# ...                                          ...
# 6891                Average Rating, Price, Brand
# 6892                Average Rating, Price, Brand
# 6893  Average Rating, Number of Ratings, Quality
# 6894                              Average Rating
# 6895                Average Rating, Price, Brand
#
# [6896 rows x 11 columns]

# %%
#get all unique values in the dataframe for each column
unique_vals = {}
for col in df.columns:
    # print(col, df[col].unique())
    unique_vals[col] = df[col].unique()

# %%
unique_vals#.keys()
# Out:
# {'Gender': array(['Female', 'Male'], dtype=object),
#  'Age': array(['35-44', '45-49', '25-34', '56+', '50-55', '18-24'], dtype=object),
#  'Occupation': array(['Writer', 'Other', 'Homemaker', 'Programmer', 'Retired',
#         'Self-employed', 'Customer service', 'Veteran', 'Driver',
#         'College/grad student', 'Pharmacist', 'Technician/Engineer',
#         'Social worker', 'Artist', 'Doctor/health care', 'DJ/Producer',
#         'Nurse', 'Baker', 'Photographer', 'Chef', 'Musician'], dtype=object),
#  'Price Sensitivity': array(['Medium', 'Low', 'High'], dtype=object),
#  'Shopping Interest': array(['Electronics, Home & Kitchen, Fashion, Health & Beauty',
#         'Home Decor, Kitchenware, Fashion, Health & Beauty',
#         'Home & Kitchen, Electronics, Health & Personal Care',
#         'Electronics, Kitchenware, Home Organization',
#         'Clothing, Home Decor, Kitchen Supplies, Health & Beauty',
#         'Home & Kitchen, Electronics, Personal Care',
#         'Home and Kitchen, Health and Personal Care, Elderly Care Products',
#         'Home & Kitchen, Electronics, Art Supplies, Food & Beverages',
#         'Home & Kitchen, Electronics, Fashion, Health & Personal Care',
#         'Electronics, Gadgets, Home Improvement, Food',
#         'Home & Kitchen, Fashion, Electronics, Health & Beauty',
#         'Electronics, Home & Kitchen, Fashion',
#         'Health supplements, office furniture, electronics, clothing, home goods',
#         'Sports, Electronics, Kitchenware, Home Improvement',
#         'Health & Wellness, Home & Kitchen, Fashion, Electronics',
#         'Kitchen Supplies, Home Decor, Clothing, Electronics',
#         'Clothing, Home Decor, Accessories',
#         'Clothing, Home Goods, Health Products, Footwear',
#         'Home & Kitchen, Electronics, Health & Personal Care, Clothing',
#         'Clothing, Home Decor, Electronics, Health & Beauty',
#         'Electronics, Kitchen Appliances, Health Products, Home Goods',
#         'Fashion, Kitchen Tools, Home Goods',
#         'Home goods, clothing, kitchenware, and products for special needs children.',
#         'Food, Clothing, Home Decor, Health Products, Electronics, Gifts',
#         'Fashion, Home Decor, Health Supplements, Accessories',
#         'Home & Kitchen, Electronics, Fashion, Travel Accessories',
#         'Kitchen and Dining, Health and Wellness, Clothing',
#         'Home & Kitchen, Fashion, Electronics, Party Supplies',
#         'Home goods, Kitchen appliances, Clothing, Health supplements',
#         'Electronics, Home & Kitchen, Personal Care',
#         'Photography, Home Goods, Kitchenware, Health & Beauty, Fashion',
#         'Clothing, Health Supplements, Accessories',
#         "Kids' clothing, home goods, and personal accessories",
#         'Home decor, plants, kitchenware, clothing, and personal care products.',
#         'Electronics, Home Appliances, Clothing, Kitchenware',
#         'Clothing, Electronics, Kitchenware, Home Goods',
#         'Fashion, Health, Electronics, Home Goods',
#         'Health & Personal Care, Home & Kitchen, Fashion',
#         'Home & Kitchen, Fashion, Health & Beauty',
#         'Kitchen & Dining, Clothing, Electronics, Snacks',
#         'Home & Kitchen, Clothing, Electronics',
#         'Electronics, Clothing, Kitchen Appliances, Health & Fitness',
#         'Tablets, Cases, Kids Products, Home Accessories',
#         'Electronics, Streaming Devices, Storage Solutions, Home Decor',
#         "Kitchen & Dining, Kids' Products, Gifts",
#         'Home & Kitchen, Food & Beverages, Personal Care',
#         'Home decor, personal care, fashion, and gifts',
#         'Home & Kitchen, Fashion, Health & Wellness',
#         'Camera Accessories, Home & Kitchen, Health & Personal Care',
#         'Home goods, electronics, personal care, fashion, and gifts.',
#         'Home and Kitchen, Office Supplies, Personal Care',
#         'Electronics, Home & Kitchen, Clothing',
#         'Health & Wellness, Home & Kitchen, Fashion',
#         'Health and fitness, electronics, home decor',
#         'Home & Kitchen, Fashion, Electronics',
#         'Outdoor gear, clothing, electronics, home improvement',
#         'Electronics, Home & Kitchen, Fashion, Personal Care',
#         'Fashion, Health, Home Goods, Food',
#         'Clothing, Kitchenware, Health Products, Home Decor',
#         'Electronics, Home & Kitchen, Health & Household',
#         'Clothing, Accessories, Home Decor, Beauty Products',
#         'Health and wellness, clothing, home goods',
#         'Home & Kitchen, Athletic Wear, Footwear, Accessories',
#         'Electronics, Home Improvement, Apparel',
#         'Health supplements, kitchen appliances, pet products, home decor',
#         'Food and Beverages, Health Supplements, Snacks, Household Items',
#         'Health and wellness, home products, electronics',
#         'Electronics, Home & Kitchen, Personal Care, Clothing',
#         'Electronics, Fashion, Home Decor',
#         'Footwear, Kitchenware, Health & Personal Care',
#         'Clothing, Home Decor, Kitchen Items',
#         'Clothing, Accessories, Home Decor, Electronics, Health & Beauty',
#         'Home and Kitchen, Gifts, Personal Care',
#         'Home & Kitchen, Personal Care, Travel Accessories',
#         'Health and wellness products, home goods, and kitchen supplies.',
#         'Clothing, Home Goods, Electronics, Cleaning Supplies',
#         'Fashion, Home Goods, Electronics, Kids Products',
#         'Health & Fitness, Home & Kitchen, Fashion',
#         'Electronics, Home & Kitchen, Projectors, Audio Equipment',
#         'Clothing, Home Decor, Health Supplements, Kitchenware',
#         'Electronics, Kitchenware, Home Goods, Personal Care',
#         'Clothing, Kitchenware, Health & Beauty',
#         "Health and wellness products, children's products, kitchen items, and personal care.",
#         'Home & Kitchen, Gifts, Electronics, Clothing',
#         'Clothing, Accessories, Footwear, Home Goods',
#         'Jewelry, Home Decor, Fashion Accessories, Electronics',
#         'Kitchen & Dining, Fashion, Health & Beauty',
#         'Home and Kitchen, Health and Fitness, Fashion',
#         'Food, Kitchen Appliances, Home Decor',
#         'Health supplements, food items, kitchenware, personal care',
#         'Home goods, Health supplements, Personal care, Clothing, Snacks',
#         'Kitchen & Dining, Home & Kitchen, Clothing, Health & Personal Care',
#         'Home & Kitchen, Electronics, Clothing',
#         'Clothing, Accessories, Home Goods, Kitchenware, Games',
#         'Electronics, Clothing, Home & Kitchen, Jewelry',
#         'Home and Kitchen, Clothing, Electronics',
#         'Health and wellness products, kitchenware, personal care items',
#         'Electronics, Home Accessories, Fashion',
#         'Home goods, clothing, health products, kitchen items',
#         'Home and Kitchen, Fashion, Electronics, Personal Care',
#         'Electronics, Accessories, Gifts',
#         'Electronics, Home & Kitchen, Gaming',
#         'Home & Kitchen, Clothing, Electronics, Health & Personal Care',
#         'Home and Kitchen, Health and Personal Care, Electronics',
#         'Household items, personal care, food products',
#         'Electronics, Kitchen & Dining, Audio Equipment',
#         'Coffee, Home Decor, Kitchenware, Clothing, Electronics',
#         'Fashion, Home Decor, Health & Beauty, Kitchenware',
#         'Home decor, Halloween decorations, seasonal items, and gifts.',
#         'Clothing, Home Goods, Health & Wellness',
#         'Books, Home Decor, Kitchen Appliances, Fashion',
#         'Home Decor, Food, Kitchen Appliances',
#         'Home & Kitchen, Fashion, Party Supplies, Photography',
#         'Outdoor gear, fashion, electronics, home goods',
#         "Clothing, Home Decor, Kids' Products, Footwear",
#         'Sunglasses, Tech Accessories, Fitness Equipment, Kitchenware, Clothing, Home Organization',
#         'Electronics, Accessories, Home Goods',
#         'Sunglasses, Reading Glasses, Kitchen Appliances, Cycling Gear, Home Goods',
#         'Clothing, Footwear, Health Products, Home Goods',
#         'Electronics, Kitchenware, Home Goods, Apparel',
#         'Electronics, Home & Kitchen, Clothing, Music',
#         'Home & Kitchen, Health & Wellness, Fashion',
#         'Clothing, Accessories, Home Decor, Electronics',
#         'Electronics, Fashion, Home & Kitchen, Health & Personal Care',
#         'Home & Kitchen, Health & Household, Fashion',
#         'Electronics, Home Goods, Health & Beauty, Fashion',
#         'Home and Kitchen, Clothing, Personal Care',
#         'Clothing, Home Decor, Kitchen Appliances, Health Products',
#         'Home & Kitchen, Electronics, Health & Personal Care, Clothing & Accessories',
#         'Aromatherapy, Health & Wellness, Home Goods, Kitchen Supplies, Personal Care, Fashion',
#         'Kitchen & Dining, Health & Household, Clothing',
#         'Home Decor, Kitchenware, Health Products, Clothing, Personal Care',
#         'Health & Fitness, Fashion, Home Decor, Accessories',
#         'Home goods, Kitchenware, Health & Wellness, Outdoor Gear',
#         'Health supplements, electronics, home goods, clothing',
#         'Computer components, accessories, and peripherals',
#         'Home & Kitchen, Health & Personal Care, Electronics',
#         'Home appliances, cleaning tools, electronics, kitchenware, personal care',
#         'Clothing, Footwear, Home Decor, Kitchenware',
#         'Health supplements, Kitchen appliances, Clothing, Footwear',
#         'Electronics, Home Decor, Clothing, Outdoor Gear',
#         'Home & Kitchen, Fashion, Footwear, Accessories',
#         'Food, Kitchenware, Health Products, Home Decor',
#         'Clothing, Home Decor, Kitchenware, Footwear, Health & Fitness',
#         'Electronics, Home & Kitchen, Health & Personal Care',
#         'Kitchen & Dining, Eco-friendly products, Electronics, Fashion',
#         'Baking, Cooking, Home Decor, Personal Care, Fashion',
#         'Health and wellness, footwear, home goods, electronics',
#         'Health and wellness products, clothing, kitchen items',
#         'Electronics, Accessories, Home Products',
#         'Health & Fitness, Fashion, Kitchenware',
#         'Clothing, Home Decor, Kitchenware, Health Products',
#         'Home goods, electronics, kitchen supplies, decor',
#         'Kitchenware, Electronics, Fashion, Home Decor',
#         'Kitchen appliances, Coffee products, Health and wellness, Home goods, Clothing',
#         'Clothing, Accessories, Home Decor, Gadgets, Food',
#         'Jewelry, Electronics, Home Goods, Health Products, Fashion',
#         'Party Supplies, Home Decor, Candles, Clothing, Kitchen Items',
#         'Electronics, Clothing, Home & Kitchen',
#         'Home & Kitchen, Personal Care, Clothing',
#         'Health supplements, home goods, personal care, kitchenware, electronics',
#         'Home & Kitchen, Electronics, Footwear, Apparel',
#         'Health and wellness, home appliances, kitchen tools, audio equipment, fashion',
#         'Electronics, Home Appliances, Food & Beverages, Clothing',
#         'Home & Kitchen, Electronics, Outdoor Equipment, Fashion',
#         'Home & Kitchen, Clothing, Snacks, Personal Care',
#         'Clothing, Kitchenware, Home Decor, Health Products, Personal Care',
#         'Jewelry, Kitchenware, Home Decor, Health Products',
#         'Home & Kitchen, Personal Care, Electronics, Fashion',
#         'Fashion, Health, Home & Kitchen, Electronics',
#         'Footwear, Home Organization, Kitchenware, Clothing, Accessories',
#         'Kitchen & Dining, Health & Personal Care, Fashion, Home Decor',
#         "Health and wellness, household items, children's products, party supplies, fashion accessories",
#         'Clothing, Tea, Health Supplements, Footwear, Home Goods, Jewelry, Kitchen Appliances',
#         'Kitchen & Dining, Home & Kitchen, Electronics',
#         'Clothing, Electronics, Home Goods',
#         'Kitchen & Dining, Home Decor, Electronics, Health & Personal Care',
#         'Kitchen & Dining, Home Decor, Health & Wellness, Personal Care',
#         'Home goods, electronics, clothing',
#         'Home Decor, Electronics, Health Products, Kitchenware',
#         'Food, Kitchenware, Clothing, Electronics',
#         'Costumes, Eco-friendly products, Home essentials, Fashion, Kitchenware',
#         'Electronics, Health Supplements, Home Goods, Fashion',
#         'Electronics, Clothing, Home Goods, Sportswear',
#         'Electronics, Home Goods, Personal Care, Clothing',
#         'Electronics, Audio Equipment, Health Supplements, Home Appliances, Fashion',
#         'Home Decor, Kitchen Items, Cleaning Products, Gifts',
#         'Electronics, Fashion, Home & Kitchen',
#         'Kitchen, Home, Health, Food',
#         'Electronics, Home & Kitchen, Health & Household, Clothing, Food & Beverages',
#         'Electronics, Kitchenware, Clothing, Health & Beauty',
#         'Kitchen & Dining, Electronics, Home Decor',
#         'Health and wellness, clothing, kitchen tools, snacks',
#         'Home Decor, Kitchenware, Fashion',
#         'Kitchenware, Home Goods, Personal Care, Fashion',
#         'Fashion, Accessories, Electronics, Kitchenware',
#         'Clothing, Home Goods, Electronics, Kitchen Appliances',
#         'Clothing, Electronics, Home & Kitchen, Health & Beauty',
#         'Electronics, Photography, Home Goods, Personal Care',
#         "Household products, kids' snacks, personal care items, and electronics",
#         'Swimwear, Kitchen & Dining, Personalized Gifts',
#         'Home & Kitchen, Personal Care, Health & Wellness, Electronics, Fashion',
#         'Electronics, Home Appliances, Kitchenware, Clothing, Accessories',
#         'Home goods, Kitchenware, Health products, Clothing',
#         'Health and Beauty, Fashion, Gadgets',
#         'Electronics, Home & Kitchen, Outdoor Gear, Clothing',
#         'Clothing, Home Goods, Health & Beauty',
#         'Food, Kitchen Appliances, Clothing, Home Decor',
#         'Electronics, Home Appliances, Health & Personal Care, Clothing',
#         'Watches, Accessories, Tools',
#         'Home goods, snacks, personal care, clothing',
#         'Electronics, Health & Wellness, Home & Kitchen',
#         'Fashion, Home Goods, Health & Fitness, Electronics',
#         'Household cleaning, fitness, kitchen appliances, baking, personal care',
#         'Electronics, Home & Kitchen, Health & Personal Care, Food & Beverages, Clothing',
#         'Home & Kitchen, Health & Wellness, Food & Snacks',
#         'Kitchen & Dining, Health & Wellness, Fashion',
#         'Electronics, Fitness, Clothing',
#         "Health and wellness, home decor, kitchen gadgets, children's products",
#         'Electronics, Coffee, Fitness',
#         'Electronics, Clothing, Kitchen Appliances, Home Goods, Toys',
#         'Clothing, Home Decor, Kitchenware, Health & Beauty',
#         'Baby products, Clothing, Health supplements, Snacks, Home organization, Electronics, Kitchenware, Office supplies',
#         'Earrings, Bags, Home Decor',
#         'Clothing, Footwear, Home Goods, Kitchenware, Personal Care',
#         'Home & Kitchen, Health & Fitness, Snacks, Electronics',
#         'Home goods, kitchenware, personal care, pet products, fashion',
#         'Food, Home Goods, Clothing, Baby Products',
#         'Health and wellness, home goods, technology',
#         'Food, Kitchenware, Health Products, Eco-Friendly Products',
#         'Home & Kitchen, Health & Wellness, Electronics, Fashion',
#         'Home & Kitchen, Electronics, Food & Beverages',
#         'Electronics, Home & Kitchen, Clothing, Health & Personal Care',
#         'Home decor, clothing, accessories, gifts',
#         'Clothing, Kitchenware, Health & Beauty, Home Decor',
#         'Home and Kitchen, Jewelry Making, Personal Care',
#         'Kitchen & Dining,Electronics,Health & Household,Clothing,Coffee & Beverages',
#         'Clothing, Footwear, Home Goods, Electronics',
#         'Health foods, organic products, supplements',
#         'Electronics, MP3 Players, Computers, Accessories',
#         'Coffee, Clothing, Home Goods, Personal Care',
#         'Home and Kitchen, Health and Wellness, Personal Care, Kids Products',
#         'Health supplements, clothing, home goods, and personal care products',
#         'Home & Kitchen, Health & Household, Electronics',
#         'Electronics, Home Appliances, Food & Beverages, Personal Care',
#         'Electronics, Home & Kitchen, Health & Personal Care, Travel Accessories',
#         'Electronics, Accessories, Home Goods, Health Products',
#         'Kitchen and Dining, Health and Personal Care, Home Improvement',
#         'Outdoor gear, kitchen tools, home improvement, personal accessories',
#         'Home Decor, Clothing, Kitchen Supplies',
#         'Health and wellness products, kitchen gadgets, fashion items',
#         'Fashion, Footwear, Health Supplements',
#         'Jewelry, Home Decor, Electronics, Clothing',
#         'Electronics, Home Goods, Kids Products, Clothing',
#         'Electronics, Home Security, Smart Devices, Health Monitoring',
#         'Electronics, Clothing, Home Goods, Kitchenware, Accessories',
#         'Electronics, Clothing, Kitchenware, Home Improvement',
#         'Health and wellness, footwear, home decor, personal care',
#         'Clothing, Accessories, Home Decor, Kitchenware',
#         'Home goods, clothing, personal care, and family-related products.',
#         "Christmas decorations, women's fashion, kitchen gadgets, gifts for family",
#         'Electronics, Photography, Home Improvement, Kitchenware',
#         'Clothing, Accessories, Electronics, Home Goods',
#         'Electronics, Kitchen Appliances, Home Goods, Personal Care',
#         'Electronics, Photography, Home Appliances, Outdoor Gear',
#         'Clothing, Health Supplements, Accessories, Kitchenware',
#         'Electronics, Audio Equipment, Home Appliances, Clothing, Health Products',
#         'Wedding supplies, Health foods, Activewear, Fashion',
#         'Household items, electronics, personal care, food and beverages, clothing',
#         'Clothing, Accessories, Home Goods, Electronics',
#         'Electronics, Home Improvement, Kitchenware, Personal Care',
#         'Home decor, Kitchenware, Clothing',
#         'Home and Kitchen, Gardening, Technology, Fashion, Personal Care',
#         'Home & Kitchen, Health & Wellness, Personal Care, Electronics, Clothing',
#         'Health supplements, Fashion, Home decor, Kitchenware',
#         'Kitchen and Dining, Health and Wellness, Home Decor',
#         'Clothing, Tactical Gear, Kitchen Gadgets, Electronics',
#         'Clothing, Accessories, Home Goods, Personal Care',
#         'Electronics, Kitchen Appliances, Health Products',
#         'Electronics, Home & Kitchen, Clothing, Photography',
#         'Party Supplies, Home Decor, Kitchenware, Fashion',
#         'Clothing, Accessories, Home Decor, Footwear, Kitchenware',
#         'Kitchen & Dining, Fashion, Electronics, Home Decor',
#         'Home & Kitchen, Health & Personal Care, Sports & Outdoors, Electronics',
#         'Home & Kitchen, Electronics, Health & Beauty, Food & Beverage',
#         'Smart home devices, electronics, audio equipment',
#         'Electronics, Kitchenware, Clothing, Health Products',
#         'Home essentials, kitchen items, snacks, and family products',
#         'Gifts, Fashion, Home Decor, Accessories',
#         'Home decor, Kitchenware, Collectibles, Outdoor gear',
#         'Fashion, Home Decor, Electronics, Kitchenware',
#         'Home & Kitchen, Electronics, Art',
#         'Electronics, Home Decor, Fashion, Health & Beauty',
#         'Kitchen & Dining, Health & Personal Care, Fashion',
#         'Clothing, Footwear, Kitchen Supplies, Home Decor',
#         'Jewelry, Snacks, Fashion, Home Decor, Health Products',
#         'Household products, Clothing, Footwear, Kitchenware',
#         'Clothing, Accessories, Home Goods, Health Products',
#         'Kitchen & Dining, Electronics, Health & Beauty, Clothing',
#         'Kitchen, Home Decor, Fashion, Health & Beauty',
#         'Kitchen appliances, home decor, clothing, and personal care items',
#         'Home decor, Art, Fitness, Kitchenware',
#         'Footwear, Kitchenware, Tea, Organic Products',
#         'Health & Beauty, Electronics, Home & Kitchen, Fashion',
#         'Dresses, Jewelry, Accessories, Home Goods',
#         'Outdoor gear, activewear, health supplements, home goods',
#         'Foot care, home essentials, electronics, personal care, kitchen items',
#         "Home & Kitchen, Fashion, Kids' Products",
#         'Jewelry, Organic Food, Kitchenware',
#         'Footwear, Home Goods, Kitchenware, Health & Fitness',
#         'Coffee, Home Goods, Fashion',
#         'Health supplements, Kitchen tools, Wallets, Snacks, Personal care',
#         'Home goods, personal care, electronics, and fashion',
#         'Electronics, Home & Kitchen, Health & Personal Care, Fashion',
#         'Electronics, Clothing, Home Goods, Fitness',
#         'Home & Kitchen, Electronics, Health & Household',
#         'Clothing, Electronics, Kitchenware, Health & Personal Care, Food & Beverages',
#         'Health & Household, Kitchen & Dining, Clothing & Accessories',
#         'Clothing, Kitchen Appliances, Home Decor, Electronics',
#         'Electronics, Home Appliances, Accessories',
#         "Home & Kitchen, Kids' Products, Fashion",
#         'Clothing, Footwear, Electronics, Home Goods',
#         "Electronics, Home & Kitchen, Health & Beauty, Kids' Products",
#         'Health Supplements, Fitness Products, Outdoor Gear',
#         'Clothing, Home Decor, Gadgets, Gifts',
#         'Health and Kitchen Products',
#         'Home Decor, Kitchen Appliances, Fashion, Gifts',
#         'Electronics, Home Improvement, Personal Care',
#         'Food, Snacks, Home Goods, Health Products',
#         'Home & Kitchen, Clothing, Electronics, Personal Care',
#         'Home & Kitchen, Electronics, Fashion',
#         'Clothing, Accessories, Home Decor, Electronics, Health Products',
#         'Electronics, Home & Kitchen, Clothing, Accessories',
#         'Clothing, Home Goods, Baby Products, Kitchenware, Personal Care',
#         'Home Decor, Kitchen Items, Personal Care',
#         'Electronics, Fashion, Home Goods, Health & Beauty, Snacks',
#         'Health & Wellness, Kitchen Products, Home Comfort',
#         'Kitchen & Dining, Electronics, Clothing, Health & Personal Care',
#         'Work shoes, costumes, tech accessories, wallets, dental care, clothing, home decor',
#         'Batteries, Kitchen Tools, Health Products, Home Improvement, Personal Care, Electronics, Clothing',
#         'Home decor, electronics, jewelry, kitchenware',
#         'Coffee, Fitness, Home Goods, Fashion',
#         'Fashion, Home Decor, Electronics, Gifts',
#         'Home & Kitchen, Health & Wellness, Food & Beverages',
#         'Household products, cleaning supplies, health and wellness, technology accessories',
#         'Home and Kitchen, Personal Care, Clothing',
#         'Home and Kitchen, Health and Safety, Fashion',
#         'Lunch bags, essential oils, health supplements, work shoes',
#         'Clothing, Electronics, Home Goods, Fitness',
#         'Clothing, Accessories, Home Goods, Electronics, Health & Beauty',
#         'Coffee, Home Goods, Health Supplements, Snacks',
#         'Kitchen and Home Products, Health and Wellness, Gluten-Free Foods',
#         'Kitchenware, Gadgets, Clothing',
#         'Electronics, Kitchen, Clothing, Home Improvement',
#         'Home goods, Coffee, Electronics',
#         "Kids' products, home essentials, clothing, and outdoor gear.",
#         "Kids' products, kitchen items, and Disney merchandise",
#         'Home & Kitchen, Clothing, Accessories, Health & Wellness',
#         'Electronics, Home & Kitchen, Fashion, Health & Fitness',
#         'Electronics, Accessories, Home Goods, Fitness',
#         'Home & Kitchen, Personal Care, Fashion',
#         'Health supplements, Home decor, Kitchen gadgets, Personal care',
#         'Home & Kitchen, Bedding, Electronics, Fashion',
#         'Kitchen & Dining, Health & Wellness, Fashion, Home Organization',
#         'Electronics, Clothing, Home Goods, Personal Care',
#         'Health & Wellness, Home & Kitchen, Personal Care, Fashion',
#         'Jewelry, Tea, Clothing, Home Goods, Health Products',
#         'Home & Kitchen, Kitchenware, Health & Wellness, Personal Care',
#         'Kitchen & Dining, Health & Wellness, Fashion, Electronics',
#         'Clothing, Home Decor, Personal Care, Party Supplies',
#         'Kitchenware, Home Decor, Health & Personal Care',
#         'Home & Kitchen, Health & Personal Care, Jewelry, Fashion Accessories',
#         'Home & Kitchen, Health & Beauty, Fashion',
#         'Home goods, clothing, electronics, health products',
#         'Electronics, Kitchenware, Home Improvement, Personal Care',
#         'Home and Kitchen, Health and Wellness, Personal Care, Food and Beverages',
#         'Home organization, electronics, clothing, health supplements',
#         'Home goods, clothing, accessories, and personal care products',
#         'Electronics, Home Goods, Kitchenware, Fitness',
#         'Health and wellness, electronics, home goods, food and beverages',
#         'Electronics, Fitness Supplements, Home Organization',
#         'Health, Food, Home Decor, Fashion',
#         'Kitchen & Dining, Electronics, Home & Garden, Health & Household, Clothing',
#         'Snacks, Home Decor, Clothing, Beauty Products, Kitchen Items',
#         'Home decor, fashion, health supplements, and security products',
#         'Home & Kitchen, Clothing, Accessories',
#         'Travel Accessories, Electronics, Health Supplements',
#         'Home & Kitchen, Clothing, Electronics, Health & Beauty',
#         'Clothing, Home Goods, Electronics, Health Products',
#         'Kitchen & Dining, Craft Supplies, Electronics',
#         'Electronics, Home Improvement, Health & Fitness, Fashion',
#         'Home & Kitchen, Party Supplies, Personal Care',
#         'Clothing, Home Goods, Electronics',
#         'Home care, electronics, fashion accessories',
#         'Fashion, Home & Kitchen, Electronics, Health & Beauty',
#         'Kitchen and home products, electronics, health supplements, travel accessories',
#         'Home & Kitchen, Kids Products, Health & Wellness',
#         'Electronics, Home & Kitchen, Health & Beauty',
#         'Watches, Shoes, Kitchenware, Health Supplements',
#         'Kitchen & Dining, Health & Fitness, Baby Products, Fashion',
#         'Home & Kitchen, Fashion, Food & Beverages, Electronics',
#         "Home & Kitchen, Kids' Products, Clothing",
#         "Home decor, children's clothing, personal care, gifts",
#         "Baby products, Health supplements, Jewelry, Women's fashion",
#         "Kitchen & Dining, Home Decor, Fashion, Kids' Products",
#         'Electronics, Cycling gear, Health supplements, Clothing',
#         'Home Decor, Clothing, Eco-Friendly Products, Electronics',
#         'Home & Kitchen, Decor, Clothing, Electronics',
#         'Health supplements, electronics, household items, snacks',
#         'Electronics, Home & Kitchen, Health & Personal Care, Snacks, Gifts',
#         'Fashion, Home Decor, Electronics',
#         'Swimwear, Kitchen Decor, Health Products',
#         'Watches, Boots, Casual Wear',
#         'Electronics, Home Decor, Travel Accessories',
#         "Kids' clothing, home goods, personal care, and kitchen items",
#         'Home and Kitchen, Electronics, Personal Care',
#         'Home & Kitchen, Fashion, Health & Beauty, Gifts',
#         'Kitchen & Dining, Home & Kitchen, Health & Beauty, Clothing',
#         'Groceries, Electronics, Home Supplies, Jewelry',
#         'Computer hardware, peripherals, and accessories',
#         'Electronics, Jewelry, Home & Kitchen, Health & Beauty, Fashion',
#         'Food, Home & Kitchen, Personal Care, Clothing, Accessories',
#         'Home goods, kitchen items, personal accessories, gifts',
#         'Health supplements, Compression socks, Kitchen tools, Clothing',
#         'Electronics, Fashion, Home Goods, Travel Accessories',
#         'Fashion, Home Decor, Health & Beauty, Electronics',
#         'Home & Kitchen, Outdoor, Health & Fitness, Fashion',
#         'Health supplements, kitchen gadgets, home organization, clothing',
#         'Electronics, Kitchen & Dining, Health & Fitness, Home & Kitchen',
#         'Health and wellness products, kitchen gadgets, comfortable clothing',
#         'Health and Beauty, Home Organization, Kitchen Supplies, Clothing',
#         'Home & Kitchen, Health & Personal Care, Fashion',
#         'Home & Kitchen, Outdoor, Cooking',
#         'Health and wellness products, kitchen gadgets, home decor, and fashion.',
#         'Home and Kitchen, Health and Personal Care, Fashion',
#         'Cooking, Kitchen Appliances, Home Improvement',
#         'Home goods, health and wellness, clothing, and accessories',
#         'Jewelry, Outdoor Equipment, Electronics, Footwear, Supplements',
#         'Electronics, Fashion, Home & Kitchen, Sports',
#         'Jewelry, Footwear, Electronics, Clothing',
#         'Health snacks, home appliances, electronics',
#         'Home & Kitchen, Party Supplies, Electronics',
#         'Electronics, Kitchen Appliances, Health & Beauty, Footwear, Home & Kitchen',
#         'Fashion, Kitchenware, Health & Fitness',
#         'Jewelry, Kitchen Appliances, Home Decor, Health Products',
#         'Fashion, Health, Home Decor, Electronics',
#         'Kitchen Appliances, Electronics, Health Products',
#         'Clothing, Kitchenware, Health Products, Home Goods',
#         'Health, Coffee, Clothing, Home Goods',
#         'Food, Crafts, Clothing, Health Products',
#         'Home & Kitchen, Health & Personal Care, Fashion, Electronics',
#         'Clothing, Electronics, Kitchenware, Home Decor',
#         'Home decor, clothing, gifts, and personal items',
#         'Electronics, Home Goods, Clothing, Personal Care',
#         'Kitchen & Dining, Electronics, Home Improvement',
#         'Home & Kitchen, Fashion, Personal Care',
#         'Home & Kitchen, Personal Care, Food & Beverages, Clothing',
#         'Health supplements, Honey products, Kitchen gadgets',
#         'Electronics, Clothing, Kitchen Appliances, Outdoor Gear',
#         'Books, Home Goods, Health Products, Clothing, Kitchenware',
#         'Home & Kitchen, Gaming, Gifts',
#         "Clothing, Accessories, Home Decor, Kids' Items",
#         'Watches, Electronics, Home Goods',
#         'Kitchen & Dining, Fashion, Health & Beauty, Home Decor',
#         'Electronics, Kitchenware, Outdoor Gear, Home Accessories',
#         'Electronics, Home Goods, Clothing, Outdoor Equipment',
#         'Electronics, Jewelry, Home Appliances, Fashion',
#         'Electronics, Apparel, Home Goods, Food, Fitness',
#         'Food and Beverages, Health Products, Household Items',
#         'Electronics, Home & Kitchen, Health & Beauty, Food & Beverages',
#         'Kitchen appliances, teas, home goods, personal care, fashion accessories',
#         'Electronics, Kitchenware, Coffee, Tea',
#         'Clothing, Kitchenware, Electronics, Accessories',
#         'Home & Kitchen, Health & Wellness, Personal Care, Food & Beverages',
#         'Home decor, fashion accessories, kitchenware, gifts',
#         'Electronics, Health Supplements, Home Decor, Kitchen Supplies',
#         'Kitchen & Dining, Jewelry, Home Decor, Fashion',
#         'Electronics, Clothing, Sportswear, Kitchenware',
#         'Home goods, personal care, electronics, clothing',
#         'Food, Kitchenware, Health Supplements, Fitness Apparel',
#         'Home & Kitchen, Decor, Electronics, Fashion, Food & Beverages',
#         'Food, Beverages, Household Items, Electronics',
#         'Health and wellness, home improvement, comfort products, kitchen essentials, personal care',
#         'Home organization, kitchen storage, comfort footwear',
#         'Fashion, Accessories, Home Decor',
#         'Electronics, Kitchenware, Home Decor, Fashion',
#         "Home decor, Kids' products, Outdoor gear, Kitchenware, Electronics, Apparel",
#         'Home & Kitchen, Electronics, Fashion, Baby Products, Outdoor Gear',
#         'Electronics, Kitchen Appliances, Phone Accessories, Home Improvement',
#         'Lighters, Incense, Electronics, Home Appliances, Clothing',
#         'Electronics, Home & Kitchen, Clothing, Fitness',
#         'Home & Kitchen, Clothing, Health & Beauty',
#         'Home & Garden, Clothing, Footwear, Food & Beverages',
#         'Home & Kitchen, Fashion, Health & Beauty, Food & Beverages',
#         'Health and Personal Care, Home Organization, Kitchen Supplies, Personal Accessories',
#         'Electronics, Stickers, Outdoor Equipment',
#         'Home decor, Kitchenware, Clothing, Electronics, Toys, Party Supplies',
#         'Clothing, Home Goods, Kitchenware, Health & Fitness',
#         'Health supplements, home goods, kitchen tools, personal care',
#         'Health and wellness, kitchen gadgets, clothing',
#         'Home decor, clothing, health products, footwear, and snacks',
#         'Home & Kitchen, Bedding, Organization, Personal Care',
#         'Home goods, kitchenware, clothing, and accessories',
#         'Home & Kitchen, Cookware, Electronics, Health & Personal Care',
#         'Health and wellness products, fragrances, snacks',
#         "Home goods, clothing, kitchenware, health products, children's items",
#         'Footwear, Party Supplies, Kitchenware, Health Products',
#         'Electronics, Kitchenware, Home Improvement, Gadgets',
#         "Home decor, children's products, kitchen items, travel accessories",
#         'Household essentials, personal care, clothing, and food items.',
#         'Electronics, Home & Kitchen, Health & Personal Care, Clothing',
#         'Health and wellness, home goods, clothing, electronics',
#         'Kitchen appliances, electronics, home improvement, and gourmet food.',
#         'Electronics, Home Appliances, Tech Gadgets',
#         'Clothing, Kitchenware, Personal Care',
#         'Health supplements, snacks, clothing, home goods',
#         'Footwear, Health Supplements, Household Items, Clothing, Kitchenware',
#         'Home & Kitchen, Electronics, Clothing, Food',
#         'Home & Kitchen, Clothing, Health & Household',
#         'Home & Kitchen, Electronics, Fashion Accessories',
#         'Home goods, kitchen appliances, baking supplies, fashion',
#         'Electronics, Kitchen & Dining, Fashion Accessories',
#         'Home & Kitchen, Fashion, Accessories',
#         'Home Decor, Electronics, Clothing, Accessories',
#         'Electronics, Kitchen Appliances, Home Decor, Personal Care, Snacks',
#         'Home Decor, Bedding, Clothing, Garden Supplies',
#         'Household items, health and beauty products, snacks, electronics',
#         'Jewelry, Personalized Gifts, Clothing, Health & Beauty',
#         'Electronics, Kitchen & Dining, Home Office',
#         'Home goods, Kitchenware, Clothing, Electronics',
#         'Electronics, Clothing, Jewelry',
#         'Watches, Electronics, Home Appliances, Travel Accessories, Clothing',
#         'Kitchen & Dining, Health Supplements, Home Care',
#         'Personal Care, Home Goods, Baby Products, Electronics, Furniture, Outdoor Decor, Clothing',
#         'Home decor, electronics, jewelry',
#         'Health & Household, Electronics, Travel Accessories, Clothing',
#         'Kitchen & Dining, Electronics, Health & Fitness',
#         'Clothing, Kitchenware, Electronics, Beverages',
#         'Home & Kitchen, Clothing, Electronics, Health & Household',
#         'Kitchen & Dining, Home Goods, Health & Fitness, Personal Care',
#         'Home & Kitchen, Clothing, Health & Wellness, Tea',
#         'Home Decor, Kitchenware, Personal Care, Fashion',
#         'Home decor, kitchenware, gifts for children',
#         'Audio Equipment, Gaming Accessories, Tech Gadgets',
#         'Clothing, Home Goods, Kitchen Appliances, Accessories',
#         'Electronics, Fashion, Home & Kitchen, Health & Beauty',
#         'Home goods, clothing, electronics, food items',
#         'Health and wellness, kitchen products, personal care',
#         'Home & Kitchen, Electronics, Decor',
#         'Electronics, Photography, Home Appliances',
#         'Electronics, Home & Kitchen, Food & Beverages, Health & Personal Care',
#         'Home goods, Snacks, Electronics, Gifts, Apparel',
#         'Electronics, Health Supplements, Fashion',
#         'Home and Kitchen, Family-oriented products, Personal care',
#         'Food, Clothing, Household Items, Health Products',
#         'Health and wellness, home goods, personal care',
#         'Health supplements, kitchen appliances, personal care',
#         'Health supplements, home decor, electronics, kitchenware',
#         'Clothing, Footwear, Home Goods, Kitchen Supplies',
#         'Food, Health, Home, Electronics, Clothing',
#         'Electronics, Kitchen Appliances, Home Decor, Gadgets',
#         'Health supplements, kitchenware, home goods, clothing, and personal care products.',
#         'Health & Personal Care, Electronics, Fashion',
#         'Baking supplies, kitchen tools, home decor',
#         'Home goods, electronics, health products, food items',
#         'Footwear, Kitchenware, Electronics, Health Supplements',
#         'Electronics, Home & Kitchen, Gadgets',
#         'Electronics, Home & Kitchen, Health & Household, Fashion',
#         'Home & Kitchen, Snacks, Beverages, Decor',
#         'Clothing, Footwear, Home Goods, Personal Care',
#         'Kitchen and Dining, Personal Care, Fashion Accessories',
#         'Home & Kitchen, Health & Personal Care, Clothing & Accessories',
#         'Kitchen & Dining, Home Decor, Food Products, Personal Care',
#         'Health supplements, electronics, home goods, and accessories',
#         'Health and wellness, snacks, household items',
#         'Electronics, Accessories, Home Aids',
#         'Electronics, Home Improvement, Automotive, Health & Fitness',
#         'Jewelry, Gym Bags, Kitchen Appliances, Home Decor, Health Supplements',
#         'Clothing, Accessories, Footwear, Electronics',
#         'Watches, Fashion, Home Goods, Kitchen Supplies',
#         'Footwear, Cycling Gear, Electronics, Household Products, Clothing',
#         'Household products, Coffee, Personal care, Home decor',
#         'Health and wellness, kitchen gadgets, home decor',
#         'Coffee, Tea, Kitchenware, Home Decor',
#         'Clothing, Kitchenware, Home Goods, Health Products',
#         'Home & Kitchen, Kitchen Storage, Organization, Cleaning, Fashion',
#         'Watches, Clothing, Kitchen Appliances, Home Goods',
#         'Kitchen appliances, home improvement, and health-related products',
#         'Health and wellness products, kitchen tools, personal care items, and home improvement.',
#         'Home & Kitchen, Electronics, Personal Care, Clothing',
#         'Clothing, Kitchenware, Electronics, Health Products, Home Goods',
#         'Electronics, Footwear, Headphones, Home Goods',
#         'Watches, Electronics, Kitchenware, Home Goods',
#         'Home decor, automotive, health and cleaning products, electronics',
#         'Health & Wellness, Home & Kitchen, Sports & Fitness, Fashion',
#         'Tea, Snacks, Furniture, Kitchen Storage',
#         'Kitchen & Dining, Clothing, Footwear, Electronics, Home & Kitchen',
#         'Bedding, Kitchenware, Clothing, Accessories',
#         'Electronics, Health & Beauty, Home & Kitchen',
#         'Home & Kitchen, Health & Personal Care, Clothing',
#         'Kitchen & Dining, Fashion, Home Decor, Personal Care',
#         'Baking, Wedding Supplies, Home Decor, Electronics',
#         'Health & Wellness, Electronics, Home & Kitchen, Fashion',
#         'Home improvement, Kitchenware, Health & Personal Care, Gifts',
#         'Electronics, Clothing, Home Goods, Health & Beauty',
#         'Home & Kitchen, Electronics, Health & Personal Care, Fashion',
#         "Kitchen tools, electronics, home accessories, and children's products",
#         'Kitchenware, Home Decor, Personal Care, Fashion',
#         'Health and wellness, clothing, accessories',
#         'Home goods, kitchenware, fashion, and decor',
#         'Home and Kitchen, Electronics, Clothing',
#         'Health supplements, bedding, clothing, outdoor gear, electronics',
#         'Athletic wear, home organization, health supplements',
#         'Clothing, Kitchenware, Home Decor, Health & Beauty',
#         'Home & Kitchen, Fashion, Beauty',
#         'Running, Cycling, Comfort Products',
#         'Beverages, Clothing, Household Products, Personal Care, Food',
#         'Wine making kits, clothing, home goods, outdoor apparel, electronics',
#         'Home & Kitchen, Health & Personal Care, Electronics, Fashion',
#         'Home goods, electronics, clothing, personal care',
#         'Electronics, Home & Kitchen, Health & Household, Clothing, Personal Care',
#         'Clothing, Footwear, Home Goods, Health Products',
#         'Home & Kitchen, Fashion, Kids',
#         'Home and kitchen products, health supplements, electronics, and personal care items.',
#         'Home & Kitchen, Health & Personal Care, Baby Products, Arts & Crafts',
#         'Kitchen & Dining, Home & Kitchen, Health & Personal Care, Clothing, Shoes & Jewelry',
#         'Health Supplements, Kitchen Appliances, Fashion Accessories',
#         'Home decor, footwear, coffee, kitchen accessories, and personal care',
#         'Home improvement, electronics, fitness, and family-related products.',
#         "Home decor, Kids' items, Sports gear",
#         'Kitchen & Dining, Home Care, Office Supplies',
#         "Kids' products, home essentials, health and wellness",
#         'Electronics, Office Supplies, Home Goods, Kitchenware, Snacks',
#         'Candy, Kitchenware, Electronics, Fashion, Fitness',
#         'Photography, Home Organization, Kitchenware, Fashion Accessories, Health & Wellness',
#         'Electronics, Home Improvement, Gadgets, Smart Home Devices',
#         'Electronics, Clothing, Home & Kitchen, Health & Personal Care',
#         'Home decor, Kitchenware, Clothing, Gifts',
#         'Home goods, electronics, personal care, clothing',
#         'Electronics, Kitchenware, Fashion, Health & Beauty',
#         'Cookware, Home Improvement, Fitness, Office Supplies',
#         'Photography equipment, electronics, home office supplies, and personal gadgets.',
#         "Party Supplies, Kids' Products, Snacks, Home Care",
#         'Home and kitchen products, outdoor gear, electronics, and personal care items.',
#         "Household items, children's products, health and wellness, fashion",
#         'Electronics, Health & Fitness, Home & Kitchen, Clothing',
#         'Kitchen & Dining, Electronics, Fashion, Health & Fitness, Home & Kitchen',
#         'Clothing, Accessories, Home Goods, Electronics, Kitchenware',
#         'Health and wellness, fashion, home goods, electronics',
#         'Electronics, Home Goods, Clothing',
#         'Electronics, Home & Kitchen, Toys',
#         'Electronics, Health & Personal Care, Food & Snacks, Kitchen & Dining',
#         'Fashion, Home & Kitchen, Electronics',
#         'Jewelry, Clothing, Home Decor, Gifts',
#         'Home appliances, kitchenware, electronics, personal care',
#         'Clothing, Home Goods', 'Electronics, Footwear, Kitchenware',
#         'Home decor, Kitchenware, Health products, Fashion',
#         'Electronics, Home & Kitchen, Clothing, Tools',
#         'Kitchen & Dining, Electronics, Health & Wellness',
#         'Electronics, Home Decor, Kitchenware, Fashion',
#         'Fashion, Home Decor, Kitchen Appliances',
#         'Kitchen appliances, electronics, clothing, and accessories',
#         'Electronics, Snacks, Personal Care, Home Goods, Clothing',
#         'Home & Kitchen, Footwear, Health & Wellness, Fashion',
#         'Kitchen appliances, health and beauty, clothing, home goods',
#         'Clothing, Footwear, Home Goods',
#         'Home and Kitchen Products, Cleaning Supplies, Kitchen Gadgets, Personal Care',
#         'Home & Kitchen, Health & Beauty, Fashion, Food & Beverages',
#         'Home & Kitchen, Health & Wellness, Fashion, Food & Beverages',
#         'Home & Kitchen, Clothing, Kitchenware',
#         "Active wear, casual wear, children's clothing, accessories",
#         'Electronics, Home Decor, Kitchenware, Clothing, Gifts',
#         'Electronics, Home & Kitchen, Outdoor Gear, Personal Care',
#         'Electronics, Health & Wellness, Kitchen Appliances',
#         'Home goods, personal care, electronics, clothing, food',
#         'Home and Kitchen, Electronics, Automotive',
#         'Home & Kitchen, Health & Fitness, Electronics, Clothing',
#         'Clothing, Home Decor, Kitchenware, Electronics',
#         'Electronics, Home Decor, Audio Equipment, Accessories',
#         'Electronics, Accessories, Home Decor',
#         'Home & Kitchen, Security, Health & Wellness',
#         'Home & Kitchen, Electronics, Health & Beauty, Fashion',
#         'Clothing, Home Goods, Kitchen Appliances, Health Products',
#         'Electronics, Home & Kitchen, Fashion, Accessories',
#         'Health supplements, home goods, personal care',
#         'Backpacks,Smart Speakers,Coffee Makers,Food Containers,Costumes,Tableware,Electronics',
#         'Home Decor, Kitchen Appliances, Pet Products',
#         'Cookware, Kitchen Gadgets, Home Decor, Electronics, Health Products',
#         'Electronics, Kitchenware, Health Products, Clothing',
#         'Health supplements, food products, electronics, personal care',
#         'Footwear, Health & Personal Care, Home Appliances',
#         'Home Decor, Kids Products, Fashion',
#         'Health and wellness products, footwear, home goods',
#         'Fashion, Health & Beauty, Home & Kitchen',
#         'Electronics, Fashion, Home & Kitchen, Gaming',
#         'Health and wellness, home goods, kitchenware, fashion',
#         'Kitchen, Home, Health, Electronics',
#         'Clothing, Home Decor, Health Products',
#         'Snacks, Chocolates, Beverages, Health Products, Kitchenware',
#         'Electronics, Home Appliances, Security Products',
#         'Electronics, Home Improvement, Health & Household',
#         'Clothing, Kitchen Tools, Electronics, Food Products',
#         'Clothing, Accessories, Kitchen Gadgets, Home Organization',
#         'Clothing, Home Decor, Kitchen Items, Accessories',
#         'Camera accessories, photography equipment, kitchenware, running shoes',
#         'Home & Kitchen, Clothing, Footwear, Accessories',
#         'Home & Kitchen, Electronics, Travel Accessories',
#         'Clothing, Electronics, Kitchen Supplies, Health Products',
#         'Fashion, Home Decor, Health & Wellness',
#         "Fashion, Home Decor, Electronics, Kids' Products",
#         'Health supplements, cleaning products, home appliances, personal care, food items, electronics',
#         'Clothing, Electronics, Home Goods, Health Products',
#         'Fashion, Jewelry, Electronics, Home Goods',
#         'Home decor, Kitchen accessories, Jewelry',
#         'Electronics, Kitchenware, Health Products',
#         "Home decor, children's products, clothing, accessories",
#         'Watches, Kitchenware, Home Appliances, Personal Care, Clothing',
#         'Home & Kitchen, Electronics, Fashion, Food & Beverages',
#         'Clothing, Baby Products, Electronics',
#         'Health, Electronics, Kitchen Appliances, Home Improvement',
#         'Clothing, Kitchenware, Home Decor, Snacks, Personal Care',
#         'Health supplements, clothing, home decor, kitchenware',
#         'Home & Kitchen, Electronics, Furniture, Health & Personal Care, Food & Beverage',
#         'Health and wellness, electronics, home improvement',
#         'Electronics, Fashion, Home Goods, Kitchen Supplies, Personal Care',
#         'Home & Kitchen, Fashion, Health & Wellness, Electronics',
#         'Home & Kitchen, Fashion, Baking',
#         'Health and wellness, home goods, fashion',
#         'Home decor, Fashion, Kitchen appliances, Electronics',
#         'Home & Kitchen, Fashion, Health & Personal Care',
#         'Clothing, Home Goods, Accessories',
#         'Clothing, Accessories, Health Supplements, Home Decor, Electronics',
#         'Home & Kitchen, Tea, Clothing, Electronics',
#         'Electronics, Gaming, Home Appliances',
#         'Home & Kitchen, Food & Beverages, Decor, Fashion',
#         'Electronics, Footwear, Kitchen Appliances, Snacks, Health Products',
#         'Electronics, Health & Beauty, Home & Kitchen, Fashion',
#         'Home goods, clothing, health and wellness, kitchen gadgets',
#         'Electronics, Fitness, Nutrition, Accessories',
#         'Health and beauty, home decor, personal care, and comfort products',
#         'Health supplements, fitness products, natural foods',
# ...
#         'Specific products, Personal experiences, Recommendations',
#         'Specific products and sizes mentioned',
#         'Specific products, personal use, gifts',
#         'Product recommendations, Purchase history',
#         'Specific products, Purchase history, Brand loyalty',
#         'Specific products mentioned in reviews, including personal experiences and recommendations.',
#         'Specific products, recommendations from friends',
#         'Specific products, purchase history',
#         'Specific products, personal experiences, brand comparisons',
#         'Specific products, purchase history, brand mentions',
#         'Specific products, gifts for family',
#         'Specific products, personal experiences, brand mentions',
#         'Specific products, Gifting, Recommendations',
#         'Specific products, personal experiences, and recommendations',
#         'Specific products, Purchase history, Returns',
#         'Specific products, shopping cart, recommendations',
#         'Granddaughters, Gifts, Recommendations'], dtype=object),
#  'Focus Aspect': array(['Quality, Brand, Price',
#         'Average Rating, Quality, Price, Aesthetics',
#         'Average Rating, Quality, Fit',
#         'Average Rating, Quality, Functionality',
#         'Quality, Price, Brand, Functionality',
#         'Average Rating, Quality, Brand', 'Quality, Brand, User Reviews',
#         'Average Rating, Number of Ratings, Price, Material, Functionality',
#         'Average Rating, Price, Brand',
#         'Average Rating, Number of Ratings, Quality',
#         'Quality, Comfort, Fit, and Functionality',
#         'Average Rating, Number of Ratings, Brand',
#         'Price, quality, comfort, effectiveness',
#         'Average Rating, Number of Ratings, Quality, Durability',
#         'Average Rating, Fabric Quality, Fit',
#         'Quality, Comfort, Price, Brand',
#         'Average Rating, Number of Ratings, Quality, Functionality',
#         'Quality, Fit, Comfort', 'Quality and durability.',
#         'Average Rating, Quality, Comfort, Value',
#         'Quality, Functionality, Design', 'Quality, Price, Brand',
#         'Average Rating, Number of Ratings, Quality, Fit, Comfort',
#         'Average Rating, Number of Ratings, Price, Quality',
#         'Average Rating, Number of Ratings, Brand, Quality',
#         'Average Rating, Number of Ratings, Fit', 'Quality and fit',
#         'Quality and affordability.',
#         'Average Rating, Number of Ratings, Quality, Price',
#         'Quality, Comfort, Functionality',
#         'Average Rating, Number of Ratings, Quality, Price, Functionality',
#         'Quality, Fit, Design, and Functionality',
#         'Quality, Comfort, Design', 'Average Rating, Brand, Fit',
#         'Average Rating, Brand, Quality', 'Quality, comfort, and variety',
#         'Quality, Fit, Comfort, Style',
#         'Quality, functionality, and user experience.',
#         'Quality, Comfort, Durability',
#         'Average Rating, Number of Ratings, Quality, Comfort, Functionality',
#         'Average Rating, Quality, Price', 'Quality and performance',
#         'Quality, Comfort, Price, Functionality',
#         'Average Rating, Number of Ratings, Quality, Value',
#         'Average Rating, Number of Ratings, Quality, Comfort, Fit, Functionality',
#         'Average Rating', 'Comfort, Quality, Fit, Design, Price',
#         'Quality, comfort, effectiveness',
#         'Quality, effectiveness, comfort',
#         'Quality, Value, Fit, Performance', 'Quality, Comfort, Price',
#         'Comfort, Fit, Quality, Functionality',
#         'Average Rating, Number of Ratings, Fit, Comfort',
#         'Quality, Comfort, Fit, Price', 'Quality, Functionality, Size',
#         'Quality and features',
#         'Average Rating, Number of Ratings, Quality, Fit',
#         'Quality, Functionality, Brand',
#         'Quality, Performance, Reliability', 'Quality, Fit, Brand, Price',
#         'Quality, Price, Comfort',
#         'Quality, effectiveness, and user experience.',
#         'Quality, Brand, Features',
#         'Quality, Comfort, Effectiveness, Brand reputation',
#         'Quality, Functionality, Price',
#         'Average Rating, Number of Ratings, Brand, Material, Price',
#         'Average Rating, Brand, Price', 'Average Rating, Quality, Comfort',
#         'Average Rating, Number of Ratings, Price, Brand',
#         'Average Rating, Number of Ratings, Quality, Price, Brand',
#         'Quality, Durability, Price',
#         'Average Rating, Comfort, Fit, Quality, Price',
#         'Quality, Design, Material', 'Comfort, Fit, Quality',
#         'Average Rating, Number of Ratings, Quality, Features',
#         'Material, Fit, Quality', 'Quality, Brand, Average Rating',
#         'Average Rating, Number of Ratings, Quality, Performance',
#         'Comfort, Quality, Fit, Brand',
#         'Quality, Taste, Appearance, Functionality',
#         'Comfort, Quality, Fit, Design, Functionality',
#         'Quality, Eco-friendliness, Brand reputation',
#         'Average Rating, Number of Ratings, Quality, Comfort, Taste',
#         'Quality, comfort, functionality',
#         'Average Rating, Quality, Material, Brand',
#         'Quality, Comfort, Design, Customer Experience',
#         'Average Rating, Number of Ratings, Quality, Brand',
#         'Quality, Appearance, Value', 'Quality, Brand, Functionality',
#         'Average Rating, Number of Ratings, Quality, Comfort',
#         'Quality, comfort, effectiveness, user experience',
#         'Quality, Value, Performance',
#         'Quality, Comfort, Functionality, Design',
#         'Quality, Comfort, Design, Functionality',
#         'Quality, Average Rating, Price',
#         'Average Rating, Number of Ratings, Material, Brand, Price',
#         'Quality, Functionality, Brand, Price',
#         'Quality, comfort, health benefits, price',
#         'Quality, Comfort, Organic, Price',
#         'Average Rating, Brand, Quality, Functionality',
#         'Quality, price, brand', 'Quality, Functionality, Packaging',
#         'Average Rating, Quality, Comfort, Functionality',
#         'Average Rating, Number of Ratings, Quality, Functionality, Design',
#         'Quality, Performance, Value', 'Average Rating, Quality, Value',
#         'Quality, durability, and functionality',
#         'Quality, usability, health benefits',
#         'Average Rating, Brand, Material', 'Quality, Fit, Material',
#         'Price, Quality, Brand',
#         'Average Rating, Number of Ratings, Quality, Functionality, Durability',
#         'Quality, Fit, Personalization',
#         'Quality, functionality, user experience',
#         'Quality, Performance, and Brand',
#         'Average Rating, Comfort, Versatility',
#         'Quality, Price, Brand, User Experience',
#         'Average Rating, Number of Ratings, Brand, Price',
#         'Quality, Material, Price', 'Quality, Performance, Brand',
#         'Comfort, Quality, Functionality, Design',
#         'Average Rating, Number of Ratings, Brand, Material, Size',
#         'Quality, Flavor, Compatibility, Price',
#         'Average Rating, Price, Quality',
#         'Quality, functionality, and user experience',
#         'Quality, Price, Brand, Comfort', 'Quality, Fit, Comfort, Design',
#         'Quality and functionality',
#         'Average Rating, Number of Ratings, Quality, Comfort, Fit',
#         'Average Rating, Brand, Comfort, Quality',
#         'Quality, Price, Brand, and User Experience',
#         'Average Rating, Brand, Product Benefits',
#         'Quality, Brand, Health Benefits',
#         'Average Rating, Number of Ratings, Material, Brand',
#         'Average Rating, Number of Ratings, Quality, Functionality, Comfort',
#         'Quality, Durability', 'Quality, health benefits, ingredients',
#         'Quality, Features, Brand', 'Quality, performance, and value',
#         'Average Rating, Quality',
#         'Quality, service, and product performance.',
#         'Average Rating, Number of Ratings, Quality, Functionality, Price',
#         'Quality, Fit, Material, Price',
#         'Average Rating, Quality, Performance, Price',
#         'Quality, durability, functionality, taste',
#         'Quality, Fit, Material, Brand', 'Quality, Comfort, Aesthetics',
#         'Average Rating, Number of Ratings, Fit, Quality',
#         'Quality, durability, functionality',
#         'Quality, Material, Size, Brand',
#         'Average Rating, Number of Ratings, Material, Size',
#         'Average Rating, Quality, Ease of Use',
#         'Average Rating, Number of Ratings, Quality, Ease of Use',
#         'Quality, Fit, Functionality, Brand',
#         'Quality, Taste, Functionality', 'Comfort, Quality, Ease of Use',
#         'Quality, Value, Comfort',
#         'Quality, Comfort, Functionality, Brand',
#         'Average Rating, Material, Comfort, Quality',
#         'Average Rating, Number of Ratings',
#         'Quality, Design, Functionality', 'Comfort, Fit, Quality, Value',
#         'Product Benefits, Quality, Brand',
#         'Average Rating, Number of Ratings, Quality, Taste, Ease of Use',
#         'Average Rating, Quality, Fit, Comfort',
#         'Quality, Fit, Comfort, Price',
#         'Quality, Functionality, Brand Reputation',
#         'Average Rating, Quality, Comfort, Price',
#         'Average Rating, Quality, Fit, Design',
#         'Average Rating, Quality, Performance',
#         'Quality, ease of use, effectiveness',
#         'Average Rating, Number of Ratings, Price',
#         'Quality, Taste, Comfort',
#         'Average Rating, Number of Ratings, Quality, Functionality, Taste',
#         'Quality, Ease of Use, Comfort', 'Quality, Performance, Price',
#         'Quality, comfort, fit, and practicality.', 'Quality and comfort',
#         'Quality, Fit, Price, Brand',
#         'Average Rating, Quality, Comfort, Design',
#         'Quality, Functionality, Color', 'Quality, Size, Price',
#         'Quality, Design, Functionality, Comfort, Durability',
#         'Quality, Performance, Customer Service',
#         'Quality, Comfort, Value, Design',
#         'Quality, fit, and functionality',
#         'Quality, comfort, effectiveness, and value',
#         'Average Rating, Brand, Performance',
#         'Quality, Taste, Functionality, Price',
#         'Quality, Comfort, Aesthetics, Price', 'Quality, Value, Price',
#         'Average Rating, Quality, Fit, Price',
#         'Quality, Fit, Functionality', 'Quality, Comfort, Affordability',
#         'Average Rating, Quality, Style',
#         'Quality, price, brand reputation, effectiveness',
#         'Quality, Value for Money, Design',
#         'Quality, Functionality, User Experience',
#         'Average Rating, Number of Ratings, Quality, Comfort, Design',
#         'Average Rating, Quality, Functionality, Comfort',
#         'Quality, Comfort, Fit', 'Quality, effectiveness, user experience',
#         'Quality, functionality, fit',
#         'Quality, comfort, and functionality',
#         'Taste, Comfort, Quality, Size',
#         'Average Rating, Number of Ratings, Quality, Comfort, Durability',
#         'Average Rating, Number of Ratings, Quality, and Fit',
#         'Average Rating, Number of Ratings, Material, Price',
#         'Quality, Fit, Usability', 'Quality, flavor, functionality',
#         'Quality, Functionality', 'Quality and Freshness',
#         'Quality, usability, and features',
#         'Quality, design, functionality', 'Quality, durability, price',
#         'Quality, Fit, Taste, Functionality', 'Taste, Quality, Value',
#         'Comfort, Quality, Functionality, Price',
#         'Average Rating, Number of Ratings, Quality, Value for Money',
#         'Quality, Price, Functionality, Brand reputation',
#         'Average Rating, Brand, Quality, Fit',
#         'Quality, Comfort, Fit, Softness',
#         'Average Rating, Comfort, Quality, Appearance',
#         'Quality, Material, Average Rating, Price',
#         'Average Rating, Quality, Fit, Performance',
#         'Average Rating, Quality, Fit, Value',
#         'Quality and functionality.',
#         'Average Rating, Number of Ratings, Brand, Functionality, User Experience',
#         'Average Rating, Number of Ratings, Material, Size, Brand',
#         'Average Rating, Brand, Comfort, Effectiveness',
#         'Quality, Fit, Performance',
#         'Average Rating, Quality, Personalization',
#         'Quality, Value, Functionality',
#         'Average Rating, Number of Ratings, Quality, Durability, Price',
#         'Quality, Functionality, Comfort',
#         'Average Rating, Quality, Comfort, Durability',
#         'Quality, functionality, and aesthetics',
#         'Quality, Performance, Brand Reputation',
#         'Price, Average Rating, Brand',
#         'Functionality, Family suitability, Quality',
#         'Quality, Fit, Value', 'Price, Quality, Comfort',
#         'Average Rating, Price, Size',
#         'Average Rating, Number of Ratings, Fit, Comfort, Quality',
#         'Quality, effectiveness, and comfort.',
#         'Quality, functionality, and design',
#         'Average Rating, Number of Ratings, Product Benefits',
#         'Size, Fit, Comfort', 'Quality, Fit, Comfort, Brand',
#         'Quality, Functionality, Organization',
#         'Average Rating, Quality, and Functionality.',
#         'Quality, Comfort, Fit, Functionality',
#         'Quality, performance, brand reputation',
#         'Quality, Design, Comfort, Aesthetics',
#         'Average Rating, Quality, Durability, Value',
#         'Quality, Performance, Comfort', 'Quality, Comfort, Price, Design',
#         'Comfort, Performance, Quality',
#         'Average Rating, Number of Ratings, Quality, Durability, Functionality',
#         'Comfort, Fit, Quality, Price',
#         'Quality, Brand, Price, Functionality',
#         'Quality, Effectiveness, Durability',
#         'Average Rating, Number of Ratings, Quality, Functionality, Brand',
#         'Quality, price, and functionality',
#         'Quality, performance, and brand reputation.',
#         'Comfort, quality, effectiveness', 'Fit, Functionality, Comfort',
#         'Quality, Brand, User experience',
#         'Quality, Performance, User Experience',
#         'Quality, Design, Functionality, Price', 'Quality, Fit, Brand',
#         'Quality, Comfort, Fit, Value', 'Average Rating, Fit, Comfort',
#         'Average Rating, Brand, Size',
#         'Average Rating, Number of Ratings, Quality, Brand, Price',
#         'Average Rating, Quality, Convenience',
#         'Quality, effectiveness, value',
#         'Average Rating, Quality, Comfort, Fit',
#         'Comfort, Quality, Functionality',
#         'Comfort, support, fit, usability',
#         'Quality, features, and effectiveness', 'Value, Comfort, Quality',
#         'Size, Quality, Fit', 'Average Rating, Quality, Comfort, Style',
#         'Quality, Style, Functionality', 'Average Rating, Material, Brand',
#         'Average Rating, Quality, Size, Brand',
#         'Average Rating, Color, Fit', 'Quality, comfort, price',
#         'Quality, functionality, design',
#         'Average Rating, Quality, Compatibility, Design',
#         'Average Rating, Quality, Fit, Ease of Use',
#         'Average Rating, Quality, Price, Brand',
#         'Average Rating, Quality, Value for Money',
#         'Quality, effectiveness, health benefits',
#         'Average Rating, Brand, Color',
#         'Average Rating, Quality, Durability, Style',
#         'Average Rating, Number of Ratings, Quality.',
#         'Quality, functionality, brand reputation',
#         'Quality, Durability, Functionality',
#         'Average Rating, Price, Size, Quality',
#         'Quality, Size, Fit, Brand',
#         'Quality, Comfort, Functionality, Brand Reputation',
#         'Quality, Sizing, Material', 'Fit, Quality, Functionality',
#         'Comfort, Fit, Style', 'Material, Average Rating, Comfort',
#         'Quality, effectiveness, value for money',
#         'Price, Average Rating, Quality', 'Quality, Average Rating, Brand',
#         'Average Rating, Quality, Fit, Functionality',
#         'Comfort, fit, quality, price',
#         'Quality, Price, Brand, Average Rating',
#         'Quality, Functionality, Ease of Use, Brand Reputation',
#         'Average Rating, Price, Comfort, Quality',
#         'Average Rating, Quality, Durability', 'Quality and effectiveness'],
#        dtype=object)}

# %%
idx = 0
prompt = gen_search_task_prompt(user_instructions['train'][idx]['task'], user_profiles[user_instructions['train'][idx]['user_id']]['user_profile'])

# %%
print(prompt)
# Out:
# You will act as an online shopper.
# Your Profile:
# Gender: Female
# Age: 35-44
# Occupation: Writer
# Price Sensitivity: Medium
# Shopping Interest: Electronics, Home & Kitchen, Fashion, Health & Beauty
# Brand Preference: Aibocn, DACHEE, IBENZER, Columbia, Nutrition Essentials, Stauffers, KitchenAid, Fossil, ILIFE, simplehuman, Utopia Bedding, HC COLLECTION, Linenspa, CINEYO, DearMy, Basic Brands, Roku, Anne Klein, Hanes, ZESICA, Madison Park
# Diversity Preference: High
# Interaction Complexity: High
# Tone and Style: Enthusiastic, Detailed, Positive
# Item Reference: Specific products and brands mentioned frequently
# Focus Aspect: Quality, Brand, Price
#
#
# You are required to generate a search phrase to perform the following search task:
# Task: Hey there! I'm super excited to find some high-quality replacement parts for my robotic vacuum cleaner. Looking for a reputable brand with great filters and brushes that'll keep my floors sparkling clean. Any awesome recommendations around $20?
#
# Generate a search phrase that is somewhat vague, reflecting your preferences and personalities without revealing the complete details
# of the target product.
# Rules:
# • You pay more attention to "Focus Aspect" of products, make sure to include some of them in the search phrase.
# • Ensure the search phrase aligns with your overall tone and style: Enthusiastic, Detailed, Positive.
# • Try to make the phrase as natural as possible and stick to the personalities in your profile.
# • Do not include any additional information or explanations and stay grounded.
# • Do not hallucinate information that is not provided.
# • No more than 10 words.

# %%
all_products['B08GC2KTG6']
# Out:
# {'main_category': 'Home_and_Kitchen',
#  'title': 'Electropan Replacement Vacuum Filter Brush Kit for Robotic Vacuum ILIFE V3, V3s, V3s pro, V5, V5s, V5s pro ILIFE Robot Vacuum Replacement Parts Ilife Vacuum Filters V3s',
#  'average_rating': 4.3,
#  'rating_number': 2534,
#  'features': ['Vaccum Parts works with Ilife V3, Ilife V3s pro, Ilife V5, Ilife V5s, Ilife V5s Pro Robotic Vacuum Cleaner. Good quality ilife v3s pro Robotic Vacuum Replacement Parts',
#   'Robot Parts Cleaner Accessory kit can keep your vacuum cleaner at peak performance, Suggest to replace ILIFE Vacuum Filters & Robot Vacuum Brush Replacement every 2-3 months',
#   'Vacuum Cleaner Parts/ robot Vacuum Accessories for Ilife robot helps to keep your house clean and save effort for housework',
#   'Ilife Vacuum Replacement Parts is very easy to install, and very easy to wash these Ilife vacuum parts (including Ilife robot vacuum hepa filters, Ilife vacuum primary filter, Ilife robot vacuum side brushes)',
#   '100% Compatible with Ilife Vacuum Cleaner Accessories/Ilife Parts/Replacement Vacuum Filters/Vacuum Cleaner Hepa Filters Replacements for Ilife'],
#  'description': [],
#  'price': '18.0',
#  'store': 'Electropan',
#  'categories': ['Home & Kitchen',
#   'Vacuums & Floor Care',
#   'Vacuum Parts & Accessories',
#   'Attachments & Brushes',
#   'Attachments'],
#  'details': {'Brand Name': 'Electropan',
#   'Item Weight': '6.7 ounces',
#   'Package Dimensions': '8.03 x 5.31 x 2.44 inches',
#   'Color': 'Part 2',
#   'Compatible Device': 'ilife v3s vacuum robot, ilife robot vacuum cleaner V3, ilife vacuum cleaner V5, ilife v5s robotic mop & vacuum cleaner, ilife v5s pro robot vacuum mop cleaner',
#   'Material Type': 'HEPA',
#   'Batteries Included?': 'No',
#   'Batteries Required?': 'No',
#   'Best Sellers Rank': {'Industrial & Scientific': 11469,
#    'Commercial Indoor Vacuum Fittings': 15,
#    'Vacuum Attachments': 301},
#   'Date First Available': 'August 20, 2020',
#   'Brand': 'Electropan',
#   'Material': 'HEPA',
#   'Compatible Devices': 'ilife v3s vacuum robot, ilife robot vacuum cleaner V3, ilife vacuum cleaner V5, ilife v5s robotic mop & vacuum cleaner, ilife v5s pro robot vacuum mop cleanerilife v3s vacuum robot, ilife robot vacuum cleaner V3, ilife vacuum cleaner V5, ilife v5s robotic mop & vacuum cleaner, ilife v5s pro robot vacuum m…  See more',
#   'Duration': '3',
#   'Reusability': 'Reusable'},
#  'parent_asin': 'B08GC2KTG6'}

# %%
idx = 0
user_instructions['train'][idx]['task']
user_profiles[user_instructions['train'][idx]['user_id']]['user_profile']
# Out:
# {'Gender': 'Female',
#  'Age': '35-44',
#  'Occupation': 'Writer',
#  'Price Sensitivity': 'Medium',
#  'Shopping Interest': 'Electronics, Home & Kitchen, Fashion, Health & Beauty',
#  'Brand Preference': 'Aibocn, DACHEE, IBENZER, Columbia, Nutrition Essentials, Stauffers, KitchenAid, Fossil, ILIFE, simplehuman, Utopia Bedding, HC COLLECTION, Linenspa, CINEYO, DearMy, Basic Brands, Roku, Anne Klein, Hanes, ZESICA, Madison Park',
#  'Diversity Preference': 'High',
#  'Interaction Complexity': 'High',
#  'Tone and Style': 'Enthusiastic, Detailed, Positive',
#  'Item Reference': 'Specific products and brands mentioned frequently',
#  'Focus Aspect': 'Quality, Brand, Price'}

# %%
user_instructions['train'][0]['target']['product_info']#.keys()
# Out:
# {'main_category': 'Home_and_Kitchen',
#  'title': 'Electropan Replacement Vacuum Filter Brush Kit for Robotic Vacuum ILIFE V3, V3s, V3s pro, V5, V5s, V5s pro ILIFE Robot Vacuum Replacement Parts Ilife Vacuum Filters V3s',
#  'average_rating': 4.3,
#  'rating_number': 2534,
#  'features': ['Vaccum Parts works with Ilife V3, Ilife V3s pro, Ilife V5, Ilife V5s, Ilife V5s Pro Robotic Vacuum Cleaner. Good quality ilife v3s pro Robotic Vacuum Replacement Parts',
#   'Robot Parts Cleaner Accessory kit can keep your vacuum cleaner at peak performance, Suggest to replace ILIFE Vacuum Filters & Robot Vacuum Brush Replacement every 2-3 months',
#   'Vacuum Cleaner Parts/ robot Vacuum Accessories for Ilife robot helps to keep your house clean and save effort for housework',
#   'Ilife Vacuum Replacement Parts is very easy to install, and very easy to wash these Ilife vacuum parts (including Ilife robot vacuum hepa filters, Ilife vacuum primary filter, Ilife robot vacuum side brushes)',
#   '100% Compatible with Ilife Vacuum Cleaner Accessories/Ilife Parts/Replacement Vacuum Filters/Vacuum Cleaner Hepa Filters Replacements for Ilife'],
#  'description': [],
#  'price': '18.0',
#  'store': 'Electropan',
#  'categories': ['Home & Kitchen',
#   'Vacuums & Floor Care',
#   'Vacuum Parts & Accessories',
#   'Attachments & Brushes',
#   'Attachments'],
#  'details': {'Brand Name': 'Electropan',
#   'Item Weight': '6.7 ounces',
#   'Package Dimensions': '8.03 x 5.31 x 2.44 inches',
#   'Color': 'Part 2',
#   'Compatible Device': 'ilife v3s vacuum robot, ilife robot vacuum cleaner V3, ilife vacuum cleaner V5, ilife v5s robotic mop & vacuum cleaner, ilife v5s pro robot vacuum mop cleaner',
#   'Material Type': 'HEPA',
#   'Batteries Included?': 'No',
#   'Batteries Required?': 'No',
#   'Best Sellers Rank': {'Industrial & Scientific': 11469,
#    'Commercial Indoor Vacuum Fittings': 15,
#    'Vacuum Attachments': 301},
#   'Date First Available': 'August 20, 2020',
#   'Brand': 'Electropan',
#   'Material': 'HEPA',
#   'Compatible Devices': 'ilife v3s vacuum robot, ilife robot vacuum cleaner V3, ilife vacuum cleaner V5, ilife v5s robotic mop & vacuum cleaner, ilife v5s pro robot vacuum mop cleanerilife v3s vacuum robot, ilife robot vacuum cleaner V3, ilife vacuum cleaner V5, ilife v5s robotic mop & vacuum cleaner, ilife v5s pro robot vacuum m…  See more',
#   'Duration': '3',
#   'Reusability': 'Reusable'},
#  'parent_asin': 'B08GC2KTG6'}

# %%
import random

def gen_search_task_prompt(task, profile_dict, max_words=10):
    """
    Generate a search task prompt based on the task and user profile.
    Args:
        task (str): The search task to be performed.
        profile_dict (dict): Dictionary containing the user profile fields and values.
        max_words (int): Maximum allowed words for the generated search phrase.
    Returns:
        str: The generated search task prompt.
    """
    prompt = f"""You will act as an online shopper.
Your Profile:
Gender: {profile_dict['Gender']}
Age: {profile_dict['Age']}
Occupation: {profile_dict['Occupation']}
Price Sensitivity: {profile_dict['Price Sensitivity']}
Shopping Interest: {profile_dict['Shopping Interest']}
Brand Preference: {profile_dict['Brand Preference']}
Diversity Preference: {profile_dict['Diversity Preference']}
Interaction Complexity: {profile_dict['Interaction Complexity']}
Tone and Style: {profile_dict['Tone and Style']}
Item Reference: {profile_dict['Item Reference']}
Focus Aspect: {profile_dict['Focus Aspect']}


You are required to generate a search phrase to perform the following search task:
Task: {task}

Generate a search phrase that is somewhat vague, reflecting your preferences and personalities without revealing the complete details
of the target product.
Rules:
• You pay more attention to "Focus Aspect" of products, make sure to include some of them in the search phrase.
• Ensure the search phrase aligns with your overall tone and style: {profile_dict['Tone and Style']}.
• Try to make the phrase as natural as possible and stick to the personalities in your profile.
• Do not include any additional information or explanations and stay grounded.
• Do not hallucinate information that is not provided.
• No more than {max_words} words.
"""
    return prompt

def calculate_res_acc(rank):
    """
    Calculate the retrieval accuracy (Res Acc) based on the rank of the target product.
    Args:
        rank (int): The rank of the target product in the retrieved list.
    Returns:
        float: The calculated Res Acc score.
    """
    if rank <= 10:
        return 1 - (rank - 1) / 10
    else:
        return 0

def generate_random_counterfactuals(task, valid_values, ground_truth, repetitions, llm_system):
    """
    Generate random counterfactuals by varying user profile dimensions.
    Args:
        tasks (list): List of search tasks.
        user_profile_fields (list): List of user profile field names.
        valid_values (dict): Dictionary of valid values for each profile field.
        ground_truths (dict): Dictionary of ground truth items for each task.
        repetitions (int): Number of repetitions for each profile variation.
        llm_system (object): The LLM system with a `retrieve` method to generate search results.
    Returns:
        list: Results for each task, including average scores for each profile variation.
    """
    results = []
    prompts = []

    # for task_num in range(len(tasks)):
    # task = tasks[task_num]
    # prompts[task_num] = []
    task_results = []
    ground_truth = ground_truths#[task]

    for field, values in valid_values.items():
        field_results = []

        for value in values:
            for j in range(repetitions):
                # first entry should be not be randomized
                if j == 0:
                    profile = {k: v[0] if k != field else value for k, v in valid_values.items()}
                else:
                    # Generate a randomized profile with `field` set to `value`
                    profile = {k: random.choice(v) if k != field else value
                            for k, v in valid_values.items()}

                # Generate search prompt
                prompt = gen_search_task_prompt(task, profile)
                prompts.append(prompt)

                # Retrieve results from the LLM system
                ranked_list = llm_system.retrieve(prompt)

                # Evaluate results
                if ground_truth in ranked_list:
                    rank = ranked_list.index(ground_truth) + 1  # Get the 1-based rank
                    score = calculate_res_acc(rank)
                else:
                    score = 0  # Ground truth not in top 10
                field_results.append(score)

        # Average score for the current field-value pair
        avg_score = sum(field_results) / len(field_results)
        task_results.append((field, value, avg_score))

    results.append((task, task_results))

    return results, prompts

# Example usage
class MockLLMSystem:
    """
    Mock LLM system to simulate retrieval of ranked lists.
    """
    def retrieve(self, prompt):
        prod_list = ["item1", "item2", "item3", "item4", "item5",
                "item6", "item7", "item8", "item9", "item10"]

        #randomly reorder the list 
        random.shuffle(prod_list)
        
        return prod_list

# %%
import random

def gen_search_task_prompt(task, profile_dict, max_words=10):
    """
    Generate a search task prompt based on the task and user profile.
    Args:
        task (str): The search task to be performed.
        profile_dict (dict): Dictionary containing the user profile fields and values.
        max_words (int): Maximum allowed words for the generated search phrase.
    Returns:
        str: The generated search task prompt.
    """
    prompt = f"""You will act as an online shopper.
Your Profile:
Gender: {profile_dict['Gender']}
Age: {profile_dict['Age']}
Occupation: {profile_dict['Occupation']}
Price Sensitivity: {profile_dict['Price Sensitivity']}
Shopping Interest: {profile_dict['Shopping Interest']}
Brand Preference: {profile_dict['Brand Preference']}
Diversity Preference: {profile_dict['Diversity Preference']}
Interaction Complexity: {profile_dict['Interaction Complexity']}
Tone and Style: {profile_dict['Tone and Style']}
Item Reference: {profile_dict['Item Reference']}
Focus Aspect: {profile_dict['Focus Aspect']}


You are required to generate a search phrase to perform the following search task:
Task: {task}

Generate a search phrase that is somewhat vague, reflecting your preferences and personalities without revealing the complete details
of the target product.
Rules:
• You pay more attention to "Focus Aspect" of products, make sure to include some of them in the search phrase.
• Ensure the search phrase aligns with your overall tone and style: {profile_dict['Tone and Style']}.
• Try to make the phrase as natural as possible and stick to the personalities in your profile.
• Do not include any additional information or explanations and stay grounded.
• Do not hallucinate information that is not provided.
• No more than {max_words} words.
"""
    return prompt

def calculate_res_acc(rank):
    """
    Calculate the retrieval accuracy (Res Acc) based on the rank of the target product.
    Args:
        rank (int): The rank of the target product in the retrieved list.
    Returns:
        float: The calculated Res Acc score.
    """
    if rank <= 10:
        return 1 - (rank - 1) / 10
    else:
        return 0

def generate_random_counterfactuals(task, valid_values, user_profile, repetitions, llm_system):
    """
    Generate random counterfactuals by varying user profile dimensions.
    Args:
        tasks (list): List of search tasks.
        user_profile_fields (list): List of user profile field names.
        valid_values (dict): Dictionary of valid values for each profile field.
        ground_truths (dict): Dictionary of ground truth items for each task.
        repetitions (int): Number of repetitions for each profile variation.
        llm_system (object): The LLM system with a `retrieve` method to generate search results.
    Returns:
        list: Results for each task, including average scores for each profile variation.
    """
    prompts = []
    #one of the prompt should be the original profile
    # next (repetitions - 1) entries should be randomized

    for field, values in valid_values.items():

        for value in values:
            for j in range(repetitions):
                # first entry should be not be randomized
                if j == 0:
                    profile = {k: v[0] if k != field else value for k, v in valid_values.items()}
                else:
                    # Generate a randomized profile with `field` set to `value`
                    profile = {k: random.choice(v) if k != field else value
                            for k, v in valid_values.items()}

                # Generate search prompt
                prompt = gen_search_task_prompt(task, profile)
                prompts.append(prompt)
                
def generate_random_counterfactuals(task, valid_values, user_profile, repetitions):
    """
    Generate random counterfactuals by varying user profile dimensions.
    Args:
        task (str): The specific task for which prompts are generated.
        valid_values (dict): Dictionary of valid values for each profile field.
        user_profile (dict): Original user profile to be used as the base.
        repetitions (int): Number of repetitions for generating counterfactuals.
        llm_system (object): The LLM system with a `retrieve` method to generate search results.
    Returns:
        tuple: Results and a list of prompts for each task, including average scores for each profile variation.
    """
    prompts = []

    for i in range(repetitions):
        if i == 0:
            # First iteration: Use the original profile without randomization
            profile = user_profile.copy()
        else:
            # Subsequent iterations: Randomize profile by perturbing across multiple dimensions
            profile = {
                field: (random.choice(values) if field in valid_values else user_profile[field])
                for field, values in valid_values.items()
            }

        # Generate a search prompt using the current profile
        prompt = gen_search_task_prompt(task, profile)
        prompts.append(prompt)


    return prompts

    return results, prompts

# Retrieve results from the LLM system
                # ranked_list = llm_system.retrieve(prompt)
# # Evaluate results
#                 if ground_truth in ranked_list:
#                     rank = ranked_list.index(ground_truth) + 1  # Get the 1-based rank
#                     score = calculate_res_acc(rank)
#                 else:
#                     score = 0  # Ground truth not in top 10
#                 field_results.append(score)

#         # Average score for the current field-value pair
#         avg_score = sum(field_results) / len(field_results)
#         task_results.append((field, value, avg_score))

#     results.append((task, task_results))


# Example usage
class MockLLMSystem:
    """
    Mock LLM system to simulate retrieval of ranked lists.
    """
    def retrieve(self, prompt):
        prod_list = ["item1", "item2", "item3", "item4", "item5",
                "item6", "item7", "item8", "item9", "item10"]

        #randomly reorder the list 
        random.shuffle(prod_list)
        
        return prod_list

# %%
# Example parameters
task = "Find the best laptop for work"

valid_values = {
    "Gender": ["Female", "Male"],
    "Age": ["18-24", "25-34", "35-44", "45-49", "50-55", "56+"],
    "Occupation": ["Student", "Professional", "Retired"],
    "Price Sensitivity": ["Low", "Medium", "High"],
    "Shopping Interest": ["Electronics", "Clothing", "Sports Gear"],
    "Brand Preference": ["Brand A", "Brand B", "Brand C"],
    "Diversity Preference": ["High", "Low"],
    "Interaction Complexity": ["Simple", "Detailed"],
    "Tone and Style": ["Casual", "Professional"],
    "Item Reference": ["Laptop", "Shoe"],
    "Focus Aspect": ["Price", "Durability", "Design"]
}

repetitions = 10
mock_llm = MockLLMSystem()

# Run the evaluation
results, prompts = evaluate_personalized_search(task, valid_values, 'item3', repetitions, mock_llm)

# Print the results
for task_result in results:
    task, field_results = task_result
    print(f"Task: {task}")
    for field, value, avg_score in field_results:
        print(f"  Field: {field}, Value: {value}, Avg. Score: {avg_score:.2f}")
# Out:
# Task: Find the best laptop for work
#   Field: Gender, Value: Male, Avg. Score: 0.55
#   Field: Age, Value: 56+, Avg. Score: 0.60
#   Field: Occupation, Value: Retired, Avg. Score: 0.60
#   Field: Price Sensitivity, Value: High, Avg. Score: 0.41
#   Field: Shopping Interest, Value: Sports Gear, Avg. Score: 0.63
#   Field: Brand Preference, Value: Brand C, Avg. Score: 0.48
#   Field: Diversity Preference, Value: Low, Avg. Score: 0.55
#   Field: Interaction Complexity, Value: Detailed, Avg. Score: 0.47
#   Field: Tone and Style, Value: Professional, Avg. Score: 0.50
#   Field: Item Reference, Value: Shoe, Avg. Score: 0.45
#   Field: Focus Aspect, Value: Design, Avg. Score: 0.58

# %%
len(set(prompts))
# Out:
# 298

# %%
user_instructions['train'][idx]['target']['product_info']['parent_asin']
# Out:
# 'B08GC2KTG6'

# %%
idx = 0

user_task = user_instructions['train'][idx]['task']
user_profile = user_profiles[user_instructions['train'][idx]['user_id']]['user_profile']
valid_values = unique_vals

# Run the evaluation
prompts = generate_random_counterfactuals(task, valid_values, user_profile, repetitions)

# %%
user_profile
# Out:
# {'Gender': 'Female',
#  'Age': '35-44',
#  'Occupation': 'Writer',
#  'Price Sensitivity': 'Medium',
#  'Shopping Interest': 'Electronics, Home & Kitchen, Fashion, Health & Beauty',
#  'Brand Preference': 'Aibocn, DACHEE, IBENZER, Columbia, Nutrition Essentials, Stauffers, KitchenAid, Fossil, ILIFE, simplehuman, Utopia Bedding, HC COLLECTION, Linenspa, CINEYO, DearMy, Basic Brands, Roku, Anne Klein, Hanes, ZESICA, Madison Park',
#  'Diversity Preference': 'High',
#  'Interaction Complexity': 'High',
#  'Tone and Style': 'Enthusiastic, Detailed, Positive',
#  'Item Reference': 'Specific products and brands mentioned frequently',
#  'Focus Aspect': 'Quality, Brand, Price'}

# %%
print(prompts[5])
# Out:
# You will act as an online shopper.
# Your Profile:
# Gender: Female
# Age: 56+
# Occupation: College/grad student
# Price Sensitivity: Low
# Shopping Interest: Outdoor gear, clothing, electronics, home improvement
# Brand Preference: Neewer, Patriot Memory, Belkin, Satechi, Ray-Ban, Distil Union, Jaybird, Evelots, OLIVERS, ONEHOO, Injinji, Outdoor Research, Kunodi, Troadlop, Goodthreads, U MUST HAVE, Love-KANKEI, Utopia Bedding, PUR, Muscle Pharm, DBR Tech, NY Threads, MIRA, BALEAF, Crave Beverages, Amazon, PANGTON VILLA, Trademark Fine Art, Wallniture, SUPERIOR, Unique Loom, JS NOVA JUNS, Memorygou, Donerton, MILPROX, BULKSUPPLEMENTS.COM, MOSISO, RAINYEAR make life easier, JORMATT, THE NORTH FACE, MARMOT, Mottee&Zconia, Bedsure, Genteele, Kingole, QCQHDU, TEKAMON, Stupell Industries, Safavieh, Deco Brothers, Apple, Valuetoner, HIWARE, TP-Link, Winsome, BeeGreeny, Genesis, Jadaol, Kurt S. Adler, Dandy Decor by Ko & Co, BLACK+DECKER, EKASN, HCB, Cuisinart, KWUY, Oirlv, Southpole, Alpine Swiss, Sigvetan, YINGFENG, Belife, Vibram, Amazon Essentials, Whiskware
# Diversity Preference: High
# Interaction Complexity: Medium
# Tone and Style: Positive, Appreciative, Critical when necessary
# Item Reference: Specific products, purchase history, tech support
# Focus Aspect: Average Rating, Quality, Value
#
#
# You are required to generate a search phrase to perform the following search task:
# Task: Find the best laptop for work
#
# Generate a search phrase that is somewhat vague, reflecting your preferences and personalities without revealing the complete details
# of the target product.
# Rules:
# • You pay more attention to "Focus Aspect" of products, make sure to include some of them in the search phrase.
# • Ensure the search phrase aligns with your overall tone and style: Positive, Appreciative, Critical when necessary.
# • Try to make the phrase as natural as possible and stick to the personalities in your profile.
# • Do not include any additional information or explanations and stay grounded.
# • Do not hallucinate information that is not provided.
# • No more than 10 words.

# %%
user_profile
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 user_profile
#
# NameError: name 'user_profile' is not defined

# %%
print(prompts[0][9])
# Out:
# You will act as an online shopper.
# Your Profile:
# Gender: Female
# Age: 18-24
# Occupation: Retired
# Price Sensitivity: Low
# Shopping Interest: Electronics
# Brand Preference: Brand C
# Diversity Preference: Low
# Interaction Complexity: Detailed
# Tone and Style: Casual
# Item Reference: Shoe
# Focus Aspect: Price
#
#
# You are required to generate a search phrase to perform the following search task:
# Task: Find the best laptop for work
#
# Generate a search phrase that is somewhat vague, reflecting your preferences and personalities without revealing the complete details
# of the target product.
# Rules:
# • You pay more attention to "Focus Aspect" of products, make sure to include some of them in the search phrase.
# • Ensure the search phrase aligns with your overall tone and style: Casual.
# • Try to make the phrase as natural as possible and stick to the personalities in your profile.
# • Do not include any additional information or explanations and stay grounded.
# • Do not hallucinate information that is not provided.
# • No more than 10 words.

# %%
from utils.search_product_by_query import search_product_by_query

# %%
res =

# %%
from pyserini.search.lucene import LuceneSearcher

# Use a prebuilt index for testing
searcher = LuceneSearcher.from_prebuilt_index('robust04')
hits = searcher.search('hello world')

print(f'Total hits: {len(hits)}')
for i in range(len(hits)):
    print(f"{i+1}: {hits[i].docid}, {hits[i].score}")
