# %%
import os
import json

from utils.bedrock_functions import build_anthropic_request_body, invoke_bedrock_endpoint

data_dir = '/home/ec2-user/code_repos/PersonalizationAE/inputs/pwab_data'

# %%
def load_json(files, data_dir= data_dir):
    if isinstance(files, str):
        with open(f"{data_dir}/{files}", "r", encoding="utf-8") as f:
            data = json.load(f)
            print(f"Loaded {len(data)} records from {files}")
            return data

    elif isinstance(files, list):
        
        combined_data = []
        for filepath in files:
            with open(f"{data_dir}/{filepath}", "r", encoding="utf-8") as f:
                data = json.load(f)
                combined_data.append(data)
                print(f"Loaded {len(data)} records from {filepath}")
                
        # if combined_data is a list of lists, flatten it
        if isinstance(combined_data[0], list):
            combined_data = [item for sublist in combined_data for item in sublist]
        # if combined_data is a list of dicts, combine them
        elif isinstance(combined_data[0], dict):
            combined_data = {k: v for d in combined_data for k, v in d.items()}
        else:
            raise ValueError("Data must be a list of lists or a list of dicts.")
        return combined_data

    else:
        raise ValueError("Argument must be either a single file path (string) or a list of file paths.")

# %%
filenames = os.listdir(data_dir)

# Identify files belonging to 'all_products'
all_products_files = [
    f for f in filenames
    if f.startswith("all_products_part_") and f.endswith(".json")
]

# Identify files belonging to 'user_history'
user_history_files = [
    f for f in filenames
    if f.startswith("user_history_part_") and f.endswith(".json")
]

# Sort files if desired (e.g., to ensure consistent order)
all_products_files.sort()
user_history_files.sort()

# %%
all_products = load_json(all_products_files)
user_history = load_json(user_history_files)
user_instructions = load_json("user_instructions.json")
user_profiles = load_json("user_profiles.json")
# Out:
# Loaded 17886 records from all_products_part_1.json
# Loaded 17886 records from all_products_part_2.json
# Loaded 334 records from user_history_part_1.json
# Loaded 334 records from user_history_part_2.json
# Loaded 332 records from user_history_part_3.json
# Loaded 2 records from user_instructions.json
# Loaded 1000 records from user_profiles.json

# %%
all_products['B08GC2KTG6']
# Out:
# {'main_category': 'Home_and_Kitchen',
#  'title': 'Electropan Replacement Vacuum Filter Brush Kit for Robotic Vacuum ILIFE V3, V3s, V3s pro, V5, V5s, V5s pro ILIFE Robot Vacuum Replacement Parts Ilife Vacuum Filters V3s',
#  'average_rating': 4.3,
#  'rating_number': 2534,
#  'features': ['Vaccum Parts works with Ilife V3, Ilife V3s pro, Ilife V5, Ilife V5s, Ilife V5s Pro Robotic Vacuum Cleaner. Good quality ilife v3s pro Robotic Vacuum Replacement Parts',
#   'Robot Parts Cleaner Accessory kit can keep your vacuum cleaner at peak performance, Suggest to replace ILIFE Vacuum Filters & Robot Vacuum Brush Replacement every 2-3 months',
#   'Vacuum Cleaner Parts/ robot Vacuum Accessories for Ilife robot helps to keep your house clean and save effort for housework',
#   'Ilife Vacuum Replacement Parts is very easy to install, and very easy to wash these Ilife vacuum parts (including Ilife robot vacuum hepa filters, Ilife vacuum primary filter, Ilife robot vacuum side brushes)',
#   '100% Compatible with Ilife Vacuum Cleaner Accessories/Ilife Parts/Replacement Vacuum Filters/Vacuum Cleaner Hepa Filters Replacements for Ilife'],
#  'description': [],
#  'price': '18.0',
#  'store': 'Electropan',
#  'categories': ['Home & Kitchen',
#   'Vacuums & Floor Care',
#   'Vacuum Parts & Accessories',
#   'Attachments & Brushes',
#   'Attachments'],
#  'details': {'Brand Name': 'Electropan',
#   'Item Weight': '6.7 ounces',
#   'Package Dimensions': '8.03 x 5.31 x 2.44 inches',
#   'Color': 'Part 2',
#   'Compatible Device': 'ilife v3s vacuum robot, ilife robot vacuum cleaner V3, ilife vacuum cleaner V5, ilife v5s robotic mop & vacuum cleaner, ilife v5s pro robot vacuum mop cleaner',
#   'Material Type': 'HEPA',
#   'Batteries Included?': 'No',
#   'Batteries Required?': 'No',
#   'Best Sellers Rank': {'Industrial & Scientific': 11469,
#    'Commercial Indoor Vacuum Fittings': 15,
#    'Vacuum Attachments': 301},
#   'Date First Available': 'August 20, 2020',
#   'Brand': 'Electropan',
#   'Material': 'HEPA',
#   'Compatible Devices': 'ilife v3s vacuum robot, ilife robot vacuum cleaner V3, ilife vacuum cleaner V5, ilife v5s robotic mop & vacuum cleaner, ilife v5s pro robot vacuum mop cleanerilife v3s vacuum robot, ilife robot vacuum cleaner V3, ilife vacuum cleaner V5, ilife v5s robotic mop & vacuum cleaner, ilife v5s pro robot vacuum m…  See more',
#   'Duration': '3',
#   'Reusability': 'Reusable'},
#  'parent_asin': 'B08GC2KTG6'}

# %%
user_instructions['train'][0].keys()
# Out:
# dict_keys(['user_id', 'task', 'target', 'timestamp', 'type'])

# %%
user_instructions['train'][0]['target']['product_info']#.keys()
# Out:
# {'main_category': 'Home_and_Kitchen',
#  'title': 'Electropan Replacement Vacuum Filter Brush Kit for Robotic Vacuum ILIFE V3, V3s, V3s pro, V5, V5s, V5s pro ILIFE Robot Vacuum Replacement Parts Ilife Vacuum Filters V3s',
#  'average_rating': 4.3,
#  'rating_number': 2534,
#  'features': ['Vaccum Parts works with Ilife V3, Ilife V3s pro, Ilife V5, Ilife V5s, Ilife V5s Pro Robotic Vacuum Cleaner. Good quality ilife v3s pro Robotic Vacuum Replacement Parts',
#   'Robot Parts Cleaner Accessory kit can keep your vacuum cleaner at peak performance, Suggest to replace ILIFE Vacuum Filters & Robot Vacuum Brush Replacement every 2-3 months',
#   'Vacuum Cleaner Parts/ robot Vacuum Accessories for Ilife robot helps to keep your house clean and save effort for housework',
#   'Ilife Vacuum Replacement Parts is very easy to install, and very easy to wash these Ilife vacuum parts (including Ilife robot vacuum hepa filters, Ilife vacuum primary filter, Ilife robot vacuum side brushes)',
#   '100% Compatible with Ilife Vacuum Cleaner Accessories/Ilife Parts/Replacement Vacuum Filters/Vacuum Cleaner Hepa Filters Replacements for Ilife'],
#  'description': [],
#  'price': '18.0',
#  'store': 'Electropan',
#  'categories': ['Home & Kitchen',
#   'Vacuums & Floor Care',
#   'Vacuum Parts & Accessories',
#   'Attachments & Brushes',
#   'Attachments'],
#  'details': {'Brand Name': 'Electropan',
#   'Item Weight': '6.7 ounces',
#   'Package Dimensions': '8.03 x 5.31 x 2.44 inches',
#   'Color': 'Part 2',
#   'Compatible Device': 'ilife v3s vacuum robot, ilife robot vacuum cleaner V3, ilife vacuum cleaner V5, ilife v5s robotic mop & vacuum cleaner, ilife v5s pro robot vacuum mop cleaner',
#   'Material Type': 'HEPA',
#   'Batteries Included?': 'No',
#   'Batteries Required?': 'No',
#   'Best Sellers Rank': {'Industrial & Scientific': 11469,
#    'Commercial Indoor Vacuum Fittings': 15,
#    'Vacuum Attachments': 301},
#   'Date First Available': 'August 20, 2020',
#   'Brand': 'Electropan',
#   'Material': 'HEPA',
#   'Compatible Devices': 'ilife v3s vacuum robot, ilife robot vacuum cleaner V3, ilife vacuum cleaner V5, ilife v5s robotic mop & vacuum cleaner, ilife v5s pro robot vacuum mop cleanerilife v3s vacuum robot, ilife robot vacuum cleaner V3, ilife vacuum cleaner V5, ilife v5s robotic mop & vacuum cleaner, ilife v5s pro robot vacuum m…  See more',
#   'Duration': '3',
#   'Reusability': 'Reusable'},
#  'parent_asin': 'B08GC2KTG6'}

# %%
request_json = build_anthropic_request_body(
    system_prompt="You are a useful assistant.",
    user_prompt=rp,
    max_tokens=1024,
    temperature=0
    )

# Model ID for your chosen Anthropic Claude variant on Bedrock.
model_id = "us.anthropic.claude-3-5-sonnet-20241022-v2:0"

    # Invoke the endpoint.
response_data = invoke_bedrock_endpoint(request_json, model_id)
print("Response from Claude:", json.dumps(response_data, indent=2))

# %%
user_profiles = load_json('/home/ec2-user/AgentPersonalization/PersonalWAB/PersonalWAB/envs/pwab/data/user_profiles.json')
user_instructions = load_json('/home/ec2-user/AgentPersonalization/PersonalWAB/PersonalWAB/envs/pwab/data/user_instructions.json')
all_products = load_json('/home/ec2-user/AgentPersonalization/PersonalWAB/PersonalWAB/envs/pwab/data/all_products_part_1.json')
user_history = load_json('/home/ec2-user/AgentPersonalization/PersonalWAB/PersonalWAB/envs/pwab/data/user_history_part_1.json')

# %%
# user_profiles
user_instructions['train'][10]
# Out:
# {'user_id': 'AHGKZS3ICK7OVRJV3XMFJN2ZQUDQ',
#  'task': "Looking for well-rated men's house slippers with comfortable lining and durable soles. Need good fit and quality. Prefer known brands.",
#  'target': {'product_info': {'main_category': 'Clothing_Shoes_and_Jewelry',
#    'title': 'VLLy Mens Slippers Moccasins with Plush Lined Cozy House Bedroom Shoes for Men',
#    'average_rating': 4.5,
#    'rating_number': 5377,
#    'features': ['Please ORDER ONE SIZE UP, cause of this thick fur inside. If you need can also adjust the bow-knot to fit.',
#     'Rubber sole',
#     'Suggest 1 Size Up for Better Fitting, because of the faux fur lining or thick socks in winter.',
#     'Mens comfy fuzzy fur slippers, wide designed suitable for indoor use and the occasional quick trip outside for the mail or whatever.',
#     'Warm and fluffy inside, excellent winter slipper with memory foam, you can wear them for a long time with the arch support.',
#     'Casual moccasins for house bedroom footwear, durable and slip resistant waterproof rubber sole can protects you from slipping or sliding.',
#     'A great gift for your families and friends for all kinds of festivals to giving their tired feet a well deserved rest.'],
#    'description': [],
#    'price': '25.99',
#    'store': 'VLLy',
#    'categories': ['Clothing, Shoes & Jewelry', 'Men', 'Shoes', 'Slippers'],
#    'details': {'Item model number': 'ms04v1',
#     'Department': 'mens',
#     'Date First Available': 'November 5, 2017'},
#    'parent_asin': 'B07C1Z2JLC'},
#   'review': {'rating': 1.0,
#    'title': 'Order 2 sizes up if you want anything like a proper fit',
#    'text': "The shoe looks good but that's where it ends. The rt. shoe sole is off to one side making it hard to walk in an already uncomfortable shoe. THEY LOOK GOOD BUT THATS JUST LIPSTICK ON A PIG.<br /><br />In short, DO NOT WASTE YOUR MONEY! SPEND A BIT MORE AND GET A SHOE THAT ACTUALLY FITS AND IS MADE PROPERLY.",
#    'parent_asin': 'B07C1Z2JLC',
#    'timestamp': 1635801846032},
#   'split': 'train'},
#  'timestamp': 1635801846032,
#  'type': 'search'}

# %%
from pprint import pprint

# %%
print(f"User ID: {user_instructions['train'][10]['user_id']}")
print('-'*50+'\n')
pprint(f"User Profile: {user_profiles[user_instructions['train'][10]['user_id']]}")
print('-'*50+'\n')
pprint(f"Task: {user_instructions['train'][10]['task']}")
print('-'*50+'\n')
user_history[user_instructions['train'][10]['user_id']]
# Out:
# User ID: AHGKZS3ICK7OVRJV3XMFJN2ZQUDQ
# --------------------------------------------------
#
# ("User Profile: {'user_profile': {'Gender': 'Male', 'Age': '35-44', "
#  "'Occupation': 'Other', 'Price Sensitivity': 'Medium', 'Shopping Interest': "
#  "'Home & Kitchen, Electronics, Health & Personal Care', 'Brand Preference': "
#  "'Tablecraft, SAMSUNG, Able Life Comfortably Independent, Amazon Essentials, "
#  'Neato Robotics, Proster, Primitive Home Decors, MEVIS LINE, MAXROCK, QBK, '
#  "VLLy, 10 Seconds, GOOJODOQ, US Window And Floor, NICETOWN, Skechers, Lasko', "
#  "'Diversity Preference': 'Medium', 'Interaction Complexity': 'Medium', 'Tone "
#  "and Style': 'Concise, Direct, Critical', 'Item Reference': 'Specific "
#  "products, Purchase history, Recommendations', 'Focus Aspect': 'Average "
#  "Rating, Quality, Fit'}}")
# --------------------------------------------------
#
# ("Task: Looking for well-rated men's house slippers with comfortable lining "
#  'and durable soles. Need good fit and quality. Prefer known brands.')
# --------------------------------------------------
# [{'product_info': {'main_category': 'Health_and_Household',
#    'title': 'Tablecraft Film Wrapper Film Dispenser, Kenkut Single Roll of Plastic Food Cling Wrap and Aluminum Foil Holder, Slide Cutter, Heavy Duty Foodservice Restaurant Kitchen',
#    'average_rating': 4.7,
#    'rating_number': 568,
#    'features': ['Improved; refillable commercial plastic wrap dispenser with slide cutter for food service film wrap and aluminum foil; Wall mounting option on back with integrated handles',
#     'Toothless metal safety blade seal wrap slide cutter included; Interchangeable slide cutter for film or metal safety blade for foil',
#     'This food wrapping film is 22 inches long; 7.62 inches high and 6.5 inches wide; Perfect for film and foil; holds 12-18" rolls up to 6" diameter; 3,000 foot roll',
#     'Non-slip feet; Dishwasher Safe; Hygienic patented design, complies to HACCP and food code standards with stay-open lid',
#     'Clear lid cover so you can see Integrated handles for safe handling; stay-open lid for easy loading; reinforced durable hinge system; wall-mounting option'],
#    'description': ['Features both a slide cutter and metal safety blade; reinforced durable hinge system; wall-mounting option and non-slip feet'],
#    'price': '49.9',
#    'store': 'Tablecraft',
#    'categories': ['Health & Household',
#     'Household Supplies',
#     'Paper & Plastic',
#     'Disposable Food Storage',
#     'Plastic Wrap'],
#    'details': {'Material': 'ABS Plastic',
#     'Brand': 'Tablecraft',
#     'Size': '1 PACK',
#     'Is Microwaveable': 'Yes',
#     'Product Dimensions': '20 x 8.5 x 7 inches; 0.01 Ounces',
#     'Is Discontinued By Manufacturer': 'Yes',
#     'Item model number': 'KK3',
#     'Date First Available': 'February 10, 2010',
#     'Manufacturer': 'Tablecraft'},
#    'parent_asin': 'B004I3VSPQ'},
#   'review': {'rating': 5.0,
#    'title': 'Five Stars',
#    'text': 'Great product',
#    'parent_asin': 'B004I3VSPQ',
#    'timestamp': 1418236292000},
#   'split': 'history'},
#  {'product_info': {'main_category': 'Electronics',
#    'title': 'Samsung BN59-01223A Remote Control',
#    'average_rating': 4.6,
#    'rating_number': 600,
#    'features': ['package height : 27.432 cm',
#     'package length : 5.334 cm',
#     'package width : 8.382 cm',
#     'Product type : REMOTE CONTROL'],
#    'description': ['This is an authorized aftermarket product. Fits with various Samsung brand models. It has a oem part # BN59-01223A.'],
#    'price': 'None',
#    'store': 'SAMSUNG',
#    'categories': ['Electronics',
#     'Television & Video',
#     'Accessories',
#     'Remote Controls'],
#    'details': {'Product Dimensions': '9 x 2 x 1 inches',
#     'Item Weight': '3.52 ounces',
#     'Item model number': 'BN59-01223A',
#     'Batteries': '2 AA batteries required.',
#     'Best Sellers Rank': {'Electronics': 158257, 'Remote Controls': 9520},
#     'Is Discontinued By Manufacturer': 'No',
#     'Date First Available': 'July 19, 2015',
#     'Manufacturer': 'Samsung',
#     'Brand': 'SAMSUNG',
#     'Special Feature': 'Ergonomic',
#     'Max Number of Supported Devices': '1',
#     'Compatible Devices': 'Television',
#     'Connectivity Technology': 'Infrared'},
#    'parent_asin': 'B0121LNLOM'},
#   'review': {'rating': 1.0,
#    'title': 'One Star',
#    'text': 'I would not reccomend this thing unless you have a Doctorate degree in Physics and Science from MIT',
#    'parent_asin': 'B0121LNLOM',
#    'timestamp': 1497282187527},
#   'split': 'history'},
#  {'product_info': {'main_category': 'Health_and_Household',
#    'title': 'Able Life Universal Stand Assist, Chair Lift Assist for Elderly, Grab Bar Standing Aid for Seniors, Daily Living Mobility Aid',
#    'average_rating': 4.2,
#    'rating_number': 1841,
#    'features': ['Prevent Falls: The stand assist provides stability, balance, and independence when sitting or standing from a couch or recliner; perfect for the elderly, those in rehab, or anyone needing mobility assistance',
#     'Fully Adjustable: Compatible with furniture cushions that are 12 to 21 inches above the ground, 19 to 26 inches wide, and 24 to 27 inches deep; please see our sizing image and video for a tutorial on how to measure your furniture prior to purchase',
#     'Padded Handle Grips: The handles provide a comfortable and secure place to grip and support up to 300 pounds; the handles adjust 7 to 10 inches above the horizontal frame of the stand assist; please see our sizing image or video for a visual aid',
#     'Cushion Compatibility: Compatible with either fixed, stitched, or removable cushions; install the stand assist frame either around or under your cushion depending on furniture style or size',
#     'Low Profile Design: The low-profile design of the Able Life assistive device matches the look and feel of your home and helps to make your existing furniture functionable again, providing an alternative solution to a lift chair'],
#    'description': [],
#    'price': 'None',
#    'store': 'Able Life Comfortably Independent',
#    'categories': ['Health & Household',
#     'Medical Supplies & Equipment',
#     'Mobility & Daily Living Aids',
#     'Mobility Aids & Equipment',
#     'Standing Aids & Supports'],
#    'details': {'Material': 'Powder Coated Steel',
#     'Color': 'Brown',
#     'Item Dimensions LxWxH': '24 x 19 x 12 inches',
#     'Brand': 'Able Life Comfortably Independent',
#     'Model Name': 'Couch Assist Grab Bar',
#     'Is Discontinued By Manufacturer': 'No',
#     'Product Dimensions': '24 x 19 x 12 inches; 8 Pounds',
#     'Item model number': '8150',
#     'Date First Available': 'February 1, 2014',
#     'Manufacturer': 'Stander'},
#    'parent_asin': 'B00I45JJRS'},
#   'review': {'rating': 5.0,
#    'title': "... wife had total knee replacement and this product worked great! I don't know what she would have done ...",
#    'text': "My wife had total knee replacement and this product worked great! I don't know what she would have done without it.<br />Very strong and well made. Looks good to!<br />I recommend this for anyone needing assistance getting up from chairs or sofa.",
#    'parent_asin': 'B00I45JJRS',
#    'timestamp': 1530899295867},
#   'split': 'history'},
#  {'product_info': {'main_category': 'Clothing_Shoes_and_Jewelry',
#    'title': "Amazon Essentials Men's Classic-Fit Quick-Dry Golf Pant, Grey, 42W x 32L",
#    'average_rating': 3.6,
#    'rating_number': 3,
#    'features': ['100% Polyester',
#     'Imported',
#     'Machine Wash',
#     'Lightweight and quick-drying, performance fabric makes this golf pant a go-to pick for sporty style with a classic pedigree',
#     'Interior gripper waistband keeps shirts tucked',
#     'Sport made better: we listen to customer feedback and fine-tune every detail to ensure quality, fit, and comfort',
#     'Model is 6\'2" and wearing a size 32"x32"'],
#    'description': ['An Amazon brand - Lightweight and quick-drying fabric makes this golf pant a go-to pick for sporty style with a classic pedigree',
#     'Amazon Essentials is focused on creating affordable, high-quality, and long-lasting everyday clothing you can rely on. Our line of men’s must-haves includes polo shirts, chino pants, classic-fit shorts, casual button-downs, and crew-neck tees. Our consistent sizing takes the guesswork out of shopping, and each piece is put to the test to maintain the highest standards in quality and comfort.'],
#    'price': 'None',
#    'store': 'Amazon Essentials',
#    'categories': ['Clothing, Shoes & Jewelry',
#     'Sport Specific Clothing',
#     'Golf',
#     'Men',
#     'Pants'],
#    'details': {'Package Dimensions': '14.88 x 9.8 x 1.5 inches; 1.1 Pounds',
#     'Item model number': 'S17AE65001',
#     'Department': 'mens',
#     'Date First Available': 'November 16, 2017',
#     'Manufacturer': 'Amazon Essentials'},
#    'parent_asin': 'B06XW4B3B1'},
#   'review': {'rating': 2.0,
#    'title': 'Two Stars',
#    'text': 'small fit',
#    'parent_asin': 'B06XW4B3B1',
#    'timestamp': 1536086102919},
#   'split': 'history'},
#  {'product_info': {'main_category': 'Home_and_Kitchen',
#    'title': 'Neato Robotics Original Replacement Parts- Boundary Markers, 13 Feet, Compatible with all Neato Intelligent Robot Vacuums.',
#    'average_rating': 4.3,
#    'rating_number': 605,
#    'features': ['Neato Boundary Markers let you decide where your Neato robot can clean and where it should “KEEP OUT"',
#     'Easily cut the magnetic strip to fit doorways, around pet bowls, thick carpeted top stairs, or anywhere you don’t want you Neato robot to go',
#     'Compatible with Neato Botvac Series, Neato Botvac D Series, Neato Botvac Connected and Neato XV Series robots.Compatible with Neato Botvac Series, Neato Botvac D Series, Neato Botvac Connected and Neato XV Series robots.',
#     'Always use Neato Genuine accessories. Using non-authorized accessories can damage your robot and void your warranty.'],
#    'description': ['Neato Robotics Original Replacement Parts- Boundary Markers, 13 Feet, Compatible with all Neato Intelligent Robot Vacuums.'],
#    'price': '28.16',
#    'store': 'Neato Robotics',
#    'categories': ['Home & Kitchen',
#     'Vacuums & Floor Care',
#     'Vacuums',
#     'Robotic Vacuums'],
#    'details': {'Brand': 'Neato Robotics',
#     'Model Name': '945-0009',
#     'Color': 'Brown',
#     'Filter Type': 'Cartridge',
#     'Power Source': 'Battery Powered',
#     'Are Batteries Included': 'No',
#     'Form Factor': 'Robotic',
#     'Product Dimensions': '180 x 5.5 x 1.25 inches',
#     'Item Weight': '14.1 ounces',
#     'Manufacturer': 'Neato Robotics',
#     'Country of Origin': 'United Kingdom',
#     'Item model number': '945-0009',
#     'Best Sellers Rank': {'Home & Kitchen': 991638, 'Robotic Vacuums': 939},
#     'Is Discontinued By Manufacturer': 'No',
#     'Specific instructions for use': 'carpet',
#     'Assembly required': 'No',
#     'Number of pieces': '1',
#     'Warranty Description': '3 year manufacture limited.',
#     'Batteries required': 'No',
#     'Surface Recommendation Floor': '',
#     '': 'Item Weight 0.4 Kilograms'},
#    'parent_asin': 'B004JKLN9E'},
#   'review': {'rating': 1.0,
#    'title': 'One Star',
#    'text': "don't stop the bot",
#    'parent_asin': 'B004JKLN9E',
#    'timestamp': 1540923693558},
#   'split': 'history'},
#  {'product_info': {'main_category': 'Electronics',
#    'title': '3x1 HDMI Switch with Audio Extractor, Proster 3 Port 4K HDMI Switcher HDMI Audio Converter Include PIP IR Remote and 3.5mm Male to 2 RCA Female Stereo Audio Cable',
#    'average_rating': 4.2,
#    'rating_number': 2459,
#    'features': ["3x1 HDMI Switch with Audio Extractor: It's not only a HDMI 3x1 Swtich with PIP fuction, but also a HDMI Audio Extractor. Comes with a 3.5mm to RCA cable, you have three modes of audio output.",
#     'HDMI 1.4 Version with HDMI Cable：This HDMI Switch input resolution: up to 4K@30hz,2016P,3D,supports Video EDID Pass Through, Audio EDID Settings: 2CH and 5.1CH, Our HDMI Switcher NOT support HDCP 2.2',
#     '3 HDMI input converter to 1 HDMI Display(Pass Mode)+ optical Toslink Output(5.1CH Mode) or stereo audio output(2CH Mode) come with RCA Cable; Automatic, Manual or Remote Switching',
#     "High Quality ABS plastic casing, 24K gold-plated connectors; Reduce signal loss, get a better output signal. 【Note: The switch cann't be used with other converter, such as HDMI to DVI Converter.】",
#     'Wide Compatible: Suitable for various HDMI source devices like Roku or Chromecast without dedicated audio output as well as Blu-ray/ DVD/ HD player, cable/satellite box, Amazon Fire TV,PS3/4, Apple TV, Xbox, PC/laptop, HD camera, HD DVR etc. (NOTE: Not for PS5)'],
#    'description': [],
#    'price': '22.95',
#    'store': 'Proster',
#    'categories': ['Electronics',
#     'Home Audio',
#     'Home Audio Accessories',
#     'Distribution',
#     'Selector Switch Boxes'],
#    'details': {'Package Dimensions': '9.33 x 6.26 x 1.06 inches; 6.74 Ounces',
#     'Item Weight': '6.7 ounces',
#     'Manufacturer': 'Proster Trading Limited',
#     'Item model number': '4330353443',
#     'Best Sellers Rank': {'Audio & Video Selector Boxes': 114},
#     'Is Discontinued By Manufacturer': 'No',
#     'Date First Available': 'July 9, 2017',
#     'Color': '3x1 Hdmi Switch With Audio Extractor',
#     'Connector Type': 'RCA, Auxiliary, DVI, HDMI',
#     'Brand': 'Proster',
#     'Compatible Devices': 'DVR, Gaming Console, Television, DVD Player, Personal Computer, Camera, Blu-Ray Player',
#     'Cable Type': 'USB, HDMI'},
#    'parent_asin': 'B073TTS9QG'},
#   'review': {'rating': 5.0,
#    'title': "Best thing I've got for my systems",
#    'text': "Can't say enough about the great quality of this product, It works as described. Easy to set up and is small enough to hide in plane sight. I will be ordering one for each of my TV's",
#    'parent_asin': 'B073TTS9QG',
#    'timestamp': 1541525215945},
#   'split': 'history'},
#  {'product_info': {'main_category': 'Home_and_Kitchen',
#    'title': 'Primitive Home Decors Star Berry Vine Gingham Check Black and Nutmeg 72" x 15.5" Lined Cotton Valance',
#    'average_rating': 4.7,
#    'rating_number': 71,
#    'features': ['72" wide x 15.5" long, 2" header, 2.5" rod pocket.',
#     'Window coverings are fully-lined to prevent fading, and 100% cotton.',
#     'Colors are Black and Nutmeg.',
#     'Valances are priced and sold individually.',
#     'Part of the Berry Vine Gingham Check Collection from Home Collections by Raghu.'],
#    'description': ['Star Berry Vine Gingham Valance - Black. Berry Vine Gingham window treatments are fully lined to prevent fading. Color: Black and Nutmeg with Stars. Size: 72" x 15.5". 100% Cotton construction. Priced and sold individually. Designed and manufactured exclusively for Primitive Home Decors.'],
#    'price': '29.95',
#    'store': 'Primitive Home Decors',
#    'categories': ['Home & Kitchen',
#     'Home Décor Products',
#     'Window Treatments',
#     'Curtains & Drapes',
#     'Valances'],
#    'details': {'Brand': 'Primitive Home Decors',
#     'Color': 'Black',
#     'Material': 'Cotton',
#     'Product Dimensions': '72"L x 15.5"W',
#     'Opacity': 'Blackout',
#     'Special Feature': 'lined',
#     'Style': 'Modern',
#     'Pattern': 'Checked',
#     'Curtain Form': 'Valance',
#     'Top Style': 'Gingham',
#     'Size': '72" x 15.5"',
#     'Weave Type': 'Plain',
#     'Item Weight': '12.8 ounces',
#     'Number of Items': '1',
#     'Product Care Instructions': 'Dry clean recommended for best results.',
#     'Package Weight': '0.36 Kilograms',
#     'Manufacturer': 'Home Collections by Raghu',
#     'Item model number': '8541878136',
#     'Best Sellers Rank': {'Home & Kitchen': 951712,
#      'Window Treatment Valances': 1717},
#     'Date First Available': 'August 18, 2017'},
#    'parent_asin': 'B075JPTJSW'},
#   'review': {'rating': 5.0,
#    'title': 'Very nice',
#    'text': 'This was of good quality and was fantastic when installed, highly recommend',
#    'parent_asin': 'B075JPTJSW',
#    'timestamp': 1541525336021},
#   'split': 'history'},
#  {'product_info': {'main_category': 'Home_and_Kitchen',
#    'title': 'Mevis Line Egg Slicer for Hard Boiled Eggs and Egg Timer for Boiling Eggs Set, (Red Color)',
#    'average_rating': 4.3,
#    'rating_number': 1790,
#    'features': ['Take the trouble out of slicing hard-boiled eggs! Slice faster the perfect little slices for your salads and sandwiches!',
#     'The egg cutter slices the eggs perfectly in any way with just one quick push. Need to dice? Vertically rotate your sliced egg and slice it once more.',
#     'The egg slicer is only for slicing eggs!',
#     'No more guessing! The egg timer is the secret! It works perfectly every single time! Just drop it in the pot with your eggs and make the perfect boiled eggs!',
#     'Satisfaction guaranteed! Made of food-safe polyresin, the egg timer reacts to the heat while boiling, changing color to show how well done they are: soft, medium or hard-boiled'],
#    'description': [],
#    'price': 'None',
#    'store': 'MEVIS LINE',
#    'categories': ['Home & Kitchen',
#     'Kitchen & Dining',
#     'Kitchen Utensils & Gadgets',
#     'Graters, Peelers & Slicers',
#     'Mandolines & Slicers',
#     'Egg Slicers'],
#    'details': {'Product Dimensions': '6.5 x 4 x 2.5 inches',
#     'Item Weight': '7.4 ounces',
#     'Manufacturer': 'MEVIS LINE',
#     'Item model number': 'Mev 004',
#     'Best Sellers Rank': {'Kitchen & Dining': 238195, 'Egg Slicers': 156},
#     'Is Discontinued By Manufacturer': 'No',
#     'Date First Available': 'May 1, 2020',
#     'Brand': 'MEVIS LINE',
#     'Material': 'Stainless Steel, Plastic',
#     'Color': 'Egg Slicer With Egg Timer',
#     'Recommended Uses For Product': 'Egg',
#     'Product Care Instructions': 'Dishwasher Safe',
#     'Blade Material': 'Stainless Steel',
#     'Blade Shape': 'Round',
#     'Operation Mode': 'Manual'},
#    'parent_asin': 'B07NK2MXL9'},
#   'review': {'rating': 1.0,
#    'title': 'Very cheap',
#    'text': "I have a hard time believing that tis product got such good ratings, The first time I used it the wire rack came apart from the holders and the wires themselves were very loose and wouldn't cut eggs. This has got to be one of the worst represented products that I have ever come across on Amazon. Amazon is not at fault but need to do some research into this company.",
#    'parent_asin': 'B07NK2MXL9',
#    'timestamp': 1567035075851},
#   'split': 'history'},
#  {'product_info': {'main_category': 'Electronics',
#    'title': 'MAXROCK (TM Super Mini Total Soft Silicon Earbuds Headphones with Mic Music Sleep Choice for Cellphones Ipad Tablet Mp3 Laptop and Most 3.5mm Audio Player (Coral Pink)',
#    'average_rating': 4.2,
#    'rating_number': 4816,
#    'features': ['♬【ULTRA-SOFT ERGOFIT】Perfect size ultra-soft ErgoFit in-ear earbud headphones conform instantly to your ear for running, travel and sleep, avoiding falling out',
#     '♬【BUILD-IN MICROPHONE】Universal build-in microphone for iphone, Samsung, and most smart phones, with updated materials of microphone key to make the clear sound both for calling and record sound or songs',
#     '♬【NOISE ISOLATING EARPLUGS EARBUDS】Travel and sleep music best partner, total soft silicon comfort to wear, and in-ear Noise isolating earplugs prefect your hearing from harmful noise levels at loud events, cut out excess sound from everyday life and your favorite activities and offer you pure music, Best choice to Side Sleeper♬',
#     '♬【WIDE COMPATIBLE】Compatible with all 3.5mm audio cable jack smart phones and devices, including the full range of Apple iPhones, iPads, iPods, Samsung Galaxy and Note Series, Game console, MP3 MP4 music players, Nexus, HTC, laptops, tablets, PC and more',
#     '♬【MULTIFUNCTIONAL BUTTON】Convenient hands-free calling, Answer, Reject and end calls directly with the earphones, easily play/pause, skip music tracks through the remote button'],
#    'description': ['Specification',
#     'Driver: 5mmSensitivity: 103+ / -3dBFrequency: 20-20kHzImpedance: 16 ohmPlug: 3.5mm PlugCord Length: 120mm/4.7”Microphone: talk play pause music for most smart cell phones and skip music function for iphone series and iPod.',
#     'Ear house: Incredible Soft Silicone',
#     "For this kind mini earbuds , which is our unique patent headphones , the selling hits is the whole silicone house could insert your ear comfortable without falling out trouble, greatly reduce the noise and provide all-day comfort, the ear buds fit gently and safely in the ears, offering secure placement and long-lasting comfort. Weighing almost nothing ... What's more , the mini 5 mm driver offer you crystal crisp sound for most music , the mini microphone suitable for most smartphones and sensitive to talk and skip to choose the music for iphone, ipad, audiobooks...would be the fashion easy sport choice for you",
#     'Are You the One Need Music to Fall Asleep?',
#     'If you happened the one need fall asleep to music, this is the unique earphone you can’t miss, this kind headphone with the most comfortable ergonomic ear tip design, adopted high quality super soft silicone, you can easily relax on your side, head on the pillow, and no feeling the pressure and pain into ears when normal headsets might be too large or bothersome. Really the sleep and travel hit for you ! Perfect for Sleeping, Sports, Air Travel, Meditation and Relaxation',
#     'Tips',
#     'For this headphone, which are made of total silicone, so we match the durable zipper case for protecting it, please store it in the zipper case when you don’t use it to ensure the uselife.',
#     'Warranty',
#     'Maxrock strongly stands behind each headphone it designs and sells, you can enjoy 90 Days Warranty from date of purchase and 24 Hours friendly customer service.'],
#    'price': '13.99',
#    'store': 'MAXROCK',
#    'categories': ['Electronics',
#     'Headphones, Earbuds & Accessories',
#     'Headphones & Earbuds',
#     'Earbud Headphones'],
#    'details': {'Package Dimensions': '3.6 x 2.9 x 1.4 inches',
#     'Item Weight': '0.176 ounces',
#     'Best Sellers Rank': {'Electronics': 97738,
#      'Earbud & In-Ear Headphones': 5440},
#     'Date First Available': 'June 11, 2019',
#     'Department': 'Boys',
#     'Manufacturer': 'Toptele',
#     'Units': '1 Count',
#     'Number Of Items': '1',
#     'Brand': 'MAXROCK',
#     'Model Name': 'P103',
#     'Color': 'Coral Pink',
#     'Form Factor': 'In Ear',
#     'Connectivity Technology': 'Wired'},
#    'parent_asin': 'B00V9FN2VY'},
#   'review': {'rating': 1.0,
#    'title': 'Not worth it.',
#    'text': "This is the third pair I have received and like the first two only one side works. at first I thought it was me or the connection but the ear buds from this company failed 3 times so that's it for MAXROCK",
#    'parent_asin': 'B00V9FN2VY',
#    'timestamp': 1602432831611},
#   'split': 'history'},
#  {'product_info': {'main_category': 'Health_and_Household',
#    'title': '3/4 Arch Support Insoles for Women/Men,QBK Orthotics Shoe Insoles High Arch Supports Shoe Insoles for Plantar Fasciitis, Flat Feet, Over-Pronation,Height Increase Insoles, Heel Cushion Inserts，M',
#    'average_rating': 4.0,
#    'rating_number': 3211,
#    'features': ['【HIGH ARCH SUPPORT INSERTS】 3/4 length high arch support, Perfectly fits the contours of your Arch, helping you Disperse more pressure on the heel',
#     "【PLANTAR FASCIITIS INSOLES】QBK's orthotic insoles provide relief from plantar symptoms, heel pain, burning and stabbing pain",
#     '【STURDY SUPPORT】Firm EVA material suitable for foot support and disperse the pressure on the heel',
#     '【CORRECTION OF FOOT POSITION】 – Ensure proper foot and ankle alignment. So spreading foot pressure eliminates foot, knee, and even back pain, making walking or standing more comfortable.',
#     '【PROFESSIONAL DESIGN】The insoles surface layer uses anti-skid moisture-wicking technology to help reduce heat and friction during vigorous exercise, keep feet cool and dry',
#     '【CUSTOMER SERVICE】Please use it according to the instructions. 12-month quality guarantee. If you have any questions, please get in touch with us, and we will be the first time to provide services for you'],
#    'description': [],
#    'price': '18.98',
#    'store': 'QBK',
#    'categories': ['Health & Household',
#     'Health Care',
#     'Foot Health',
#     'Inserts & Insoles',
#     'Insoles'],
#    'details': {'Brand': 'QBK',
#     'Color': 'Blue',
#     'Product Benefits': 'High Arch',
#     'Use for': 'Feet',
#     'Material': 'Ethylene Vinyl Acetate',
#     'Product Dimensions': '3.94 x 1.18 x 1.18 inches; 4.66 Ounces',
#     'Item model number': 'QA1',
#     'Date First Available': 'July 14, 2020',
#     'Manufacturer': 'QBK',
#     'Country of Origin': 'China'},
#    'parent_asin': 'B0966K94CZ'},
#   'review': {'rating': 5.0,
#    'title': 'One great purchase',
#    'text': "I have diminished use of my right foot due to an injury, I must wear a brace to walk, my left foot (not to be outdone) has weakened and both feet are giving me trouble with over pronation along with bone spurs. I have tried everything, expensive inserts, specialty shoes, you name it. I was giving up and beginning to think I was just going to have to live with it.<br /><br />I was exploring my options and came across the QBK Orthotics Shoe Insoles with arch support so I gave them a try and WOW what a difference! They cupped my heel, supported my arch, cushioned my heel to prevent bone spurs, lastly they were very easy to insert and actually worked with my brace. I have used the inserts every day and won't wear shoes without them.<br /><br />I'm going to get several more so I don't have to keep moving them from shoe to shoe. I also plan to get some for my wife who is a healthcare worker and on her feet everyday.<br /><br />This is one of the best purchases I have made and am thrilled that I finally found something that works. Thank you",
#    'parent_asin': 'B0966K94CZ',
#    'timestamp': 1628859474015},
#   'split': 'history'},
#  {'product_info': {'main_category': 'Clothing_Shoes_and_Jewelry',
#    'title': 'VLLy Mens Slippers Moccasins with Plush Lined Cozy House Bedroom Shoes for Men',
#    'average_rating': 4.5,
#    'rating_number': 5377,
#    'features': ['Please ORDER ONE SIZE UP, cause of this thick fur inside. If you need can also adjust the bow-knot to fit.',
#     'Rubber sole',
#     'Suggest 1 Size Up for Better Fitting, because of the faux fur lining or thick socks in winter.',
#     'Mens comfy fuzzy fur slippers, wide designed suitable for indoor use and the occasional quick trip outside for the mail or whatever.',
#     'Warm and fluffy inside, excellent winter slipper with memory foam, you can wear them for a long time with the arch support.',
#     'Casual moccasins for house bedroom footwear, durable and slip resistant waterproof rubber sole can protects you from slipping or sliding.',
#     'A great gift for your families and friends for all kinds of festivals to giving their tired feet a well deserved rest.'],
#    'description': [],
#    'price': '25.99',
#    'store': 'VLLy',
#    'categories': ['Clothing, Shoes & Jewelry', 'Men', 'Shoes', 'Slippers'],
#    'details': {'Item model number': 'ms04v1',
#     'Department': 'mens',
#     'Date First Available': 'November 5, 2017'},
#    'parent_asin': 'B07C1Z2JLC'},
#   'review': {'rating': 1.0,
#    'title': 'Order 2 sizes up if you want anything like a proper fit',
#    'text': "The shoe looks good but that's where it ends. The rt. shoe sole is off to one side making it hard to walk in an already uncomfortable shoe. THEY LOOK GOOD BUT THATS JUST LIPSTICK ON A PIG.<br /><br />In short, DO NOT WASTE YOUR MONEY! SPEND A BIT MORE AND GET A SHOE THAT ACTUALLY FITS AND IS MADE PROPERLY.",
#    'parent_asin': 'B07C1Z2JLC',
#    'timestamp': 1635801846032},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Health_and_Household',
#    'title': "10 Seconds 3810 Ultra Support Poron Insoles Plantar Fasciitis Morton's Neuroma Metatarsalgia Support Anti Fatigue Light Weight Vibration Dampening Carbon Support & Metatarsal Pad M 6/6.5, W 7.5/8",
#    'average_rating': 4.5,
#    'rating_number': 861,
#    'features': ['This is the heavy duty, heavy impact work horse of insoles. Specifically designed for use in demanding environments. From the warehouse to the gym, this is the insole to use when the strain is tough. The Ultra Arch Insole provides relief from common foot ailments like Plantar Fasiatis, Mortons Nuroma and diabetic sufferers.',
#     'Arch Firmness: High',
#     'Arch Height/Support: Medium/High',
#     'Use: Designed for use during Heavy Impact activities, Athletic and Work',
#     'Deep Heel Cup: Deeper heel cup adds cushion around heel which forms to the foot and provides an increase in stability'],
#    'description': [],
#    'price': '64.99',
#    'store': '10 Seconds',
#    'categories': ['Health & Household',
#     'Health Care',
#     'Foot Health',
#     'Inserts & Insoles',
#     'Insoles'],
#    'details': {'Brand': '10 Seconds',
#     'Color': '1 Pack',
#     'Use for': 'Foot',
#     'Material': 'Carbon Fiber',
#     'Recommended Uses For Product': 'Heel',
#     'Package Dimensions': '14.17 x 4.45 x 1.57 inches; 6.07 Ounces',
#     'Department': 'Unisex-adult',
#     'Date First Available': 'November 19, 2019',
#     'Manufacturer': 'Hickory Brands'},
#    'parent_asin': 'B081QP7CP8'},
#   'review': {'rating': 5.0,
#    'title': 'BEST - BAR NONE!',
#    'text': "My wife and I both have foot problems; we've tried everything to ease the pain from long hours of standing in a hospital hard floor environment. When we tried the 10 Second 3810 Ultra Support Insole, we hit paydirt! The insoles have all but stopped any pain we had; they really are the best we've ever tried! We have had them for quite some time and are as good now as they were when we first received them. I would buy a dozen if they weren't so expensive, so for now we just swap from shoe to shoe. Thanks' 10 Second",
#    'parent_asin': 'B081QP7CP8',
#    'timestamp': 1639933878317},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Electronics',
#    'title': 'GOOJODOQ Bluetooth Sleep Headphones Bluetooth 4.2 Wireless Soft in-Ear Sleeping Earbuds, 18 Hours Music time, Wireless Sleep Headsets for Insomnia, Side Sleeper, Gym, Relaxation and Sports-Black',
#    'average_rating': 3.7,
#    'rating_number': 2278,
#    'features': ['★Soft and comfortable earplugs noise isolating design★-soft and comfortable in-ear earplug design effectively block out background noise, perfectly block out the snoring, living-room TV sound, office noise and roommate move noise and etc. , protect your listening in noisy environment.',
#     '★12-Hours quick charging for at least 18 hours’ playing time★-goojodoqq wireless Bluetooth sleeping headphones with improved lithium polymer battery brings up to 18 hours pleasure musically and socially with a quick charge of only12 hours.',
#     '★Ergonomic double layer design for most ear size★-made of two size ear tips fit entirely in ear for most size ear canals according to plug it in certain Deep of your ear, and the soft and flexible silicone ear house enable it to fit and stay in ear perfectly avoiding falling out.',
#     '★Hd sound in your workout time & hands-free phone calls★-- adopting latest Bluetooth 4. 2 technology, superior acoustic components, Goojodoq sleeping earphones produce incredible sound quality with dynamic listening experience. In-line mic and button control, you can enjoy hands-free phone calls and control volume and track. The built-in HD microphone transmits your voice with clearly.',
#     "★100% satisfaction ★-- total silicone material with upgrade double-layer ear cap, make it comfortable for 24 hours wearing. Provides 30 days return and 6 months and kind customer service. If you have any questions, please don't hesitate to contact us."],
#    'description': [],
#    'price': '29.99',
#    'store': 'GOOJODOQ',
#    'categories': ['Electronics',
#     'Headphones, Earbuds & Accessories',
#     'Headphones & Earbuds',
#     'Earbud Headphones'],
#    'details': {'Package Dimensions': '6.42 x 3.78 x 1.14 inches',
#     'Item Weight': '2.89 ounces',
#     'Item model number': 'GOOJODOQ-J09',
#     'Batteries': '1 Lithium Ion batteries required.',
#     'Best Sellers Rank': {'Electronics': 20664,
#      'Earbud & In-Ear Headphones': 1750},
#     'Is Discontinued By Manufacturer': 'No',
#     'Date First Available': 'January 7, 2019',
#     'Manufacturer': 'GOOJODOQ',
#     'Country of Origin': 'China',
#     'Units': '1.0 Count',
#     'Number Of Items': '1',
#     'Brand': 'GOOJODOQ',
#     'Model Name': 'Hearphone',
#     'Color': 'Black',
#     'Form Factor': 'In Ear',
#     'Connectivity Technology': 'Wireless'},
#    'parent_asin': 'B07MFKF6JC'},
#   'review': {'rating': 1.0,
#    'title': "Don't buy",
#    'text': 'After only about 6 weeks one ear piece stopped working, the volume adjust and on/off are located where a slight amount of movement will mute or turn it off completely. Very good sound but not a reliable set of plugs.',
#    'parent_asin': 'B07MFKF6JC',
#    'timestamp': 1644160796420},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Home_and_Kitchen',
#    'title': 'US Window and Floor 2" Cordless Faux Wood Blinds, Blind Size 25" x 72", Outside Mount',
#    'average_rating': 4.6,
#    'rating_number': 1983,
#    'features': ['100% Pvc',
#     'This blind is to be installed on a door or a wall above a window casing. Actual blind size is 25" wide x 72" high.',
#     'The blinds come with installation instruction, a 3 1/4" decorative valance with ending corner valances, L clips (to connect the corner valances to the front valance), valance clips, mounting brakcets, hold down brackets, tilt wand and screws included.',
#     '2" x 2 1/4" heavy duty steel headrail.',
#     'Cordless lift mechanism provides a more modern and cleaner appearance to every room. Simply hold the bottom rail to lift or lower the blind down. Provide a safe environment for home with pets and kids. No more exposed dangling cords.',
#     'Our high-quality blinds are durable and resistant to humidity. Slats are made of non-leaded PVC. They are low maintenance and long lasting.'],
#    'description': ['This blind is to be installed on a fresh door or a flat-surface wall above a window casing. Our blinds are crafted with high quality components including high profile steel head rail and quality PVC foam slats. Our blinds resist heat and humidity, and are great for all areas including the kitchen, laundry, and bathroom. Mounting hardware and an outside-mount decorative valance with valance returns are also included. Mounting screws provided are best for drywall or sheetrock only. They are not for concrete or metal surfaces.'],
#    'price': '77.51',
#    'store': 'US Window And Floor',
#    'categories': ['Home & Kitchen',
#     'Home Décor Products',
#     'Window Treatments',
#     'Blinds & Shades',
#     'Horizontal Blinds'],
#    'details': {'Material': 'Engineered Wood',
#     'Product Dimensions': '72"L x 25"W',
#     'Brand': 'US Window And Floor',
#     'Color': 'Smooth White',
#     'Recommended Uses For Product': 'Indoor',
#     'Specific instructions for use': 'Door',
#     'Room Type': 'All Interiors, Bedroom, Living Room, Dining Room, Kitchen, Kids, Nursery, Bathroom, Home Office',
#     'Operation Mode': 'Manual',
#     'Special Feature': 'Cordless, Wand Tilt',
#     'Included Components': 'Blind, Tilt Wand, Outside Mount Type Majestic Valance with Returns, Valance Clips, L Clips(for Returns), Mounting Brackets, Hold Down Brackets, Screws, Installation Instructions',
#     'Number of Items': '1',
#     'Care instructions': 'Wipe away dust with micro fiber cloth when needed. For stains, mix one part of vinegar and one part of lukewarm water in a bow. Dip soft cloth into the mixture. Wring the cloth. Use the damp-dry cloth to wipe out the stains.',
#     'Size': '25 x 72',
#     'Mounting Type': 'Outside Mount',
#     'Number Of Panels': '1',
#     'Water Resistance Level': 'Not Water Resistant',
#     'Item Weight': '9.28 pounds',
#     'Manufacturer': 'US Window and Floor',
#     'Country of Origin': 'Vietnam',
#     'Item model number': 'CLF0102500720',
#     'Best Sellers Rank': {'Home & Kitchen': 193134,
#      'Horizontal Window Blinds': 147},
#     'Volume': '816.75 Cubic Inches',
#     'Fabric Type': '100% Pvc',
#     'Finish types': 'Smooth',
#     'Assembly required': 'No',
#     'Number of pieces': '1',
#     'Warranty Description': '1 year manufacturer',
#     'Batteries required': 'No'},
#    'parent_asin': 'B07P8W9KZQ'},
#   'review': {'rating': 1.0,
#    'title': 'No instructions. Broken parts',
#    'text': "Purchased 2 for French doors, neither had complete instructions no way to get the valance side pcs. on and they weren't even in the instructions. The rod that is used to open the blinds 1 was broken. Don't waste your money. Didn't call the mfg. if they sell this kind of stuff they probably don't really care anyway.",
#    'parent_asin': 'B07P8W9KZQ',
#    'timestamp': 1658542949600},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Home_and_Kitchen',
#    'title': 'NICETOWN Bordered Sheer Linen Curtains for Bedroom, Rod Pocket & Back Tab Privacy Flax Semi Sheer Window Treatment Color Block Drapes for Living Room/Hall, White+Navy Blue, W52 by L84, Set of 2',
#    'average_rating': 4.6,
#    'rating_number': 3566,
#    'features': ['Ready Made: Package includes 2 panels of bordered flax sheer linen curtain, each measures 52"W (104"W for pair), with\xa07 back loops (2" Diam) for different hanging options and standard rod.',
#     'Luxury Linen: The weave of the linen fibers creates dimensional highs and lows. And the premium linen has a crisp, natural texture that filters light beautifully but still with privacy.',
#     'Contrasting Border: A contrasting stripe on each side adds the linen curtains a pop of color against the white base, which will bring both casual warmth and refined style to the room.',
#     'Rod Pocket & Back Tab: A dual top treatment will provide you more than 2 hanging options — pleated, bunched, or with your clip-rings to be perfectly suitable with any of your home decors.',
#     "Easy Care: NICETOWN linen texture is wrinkle-free and has a good vertical sense for Easy Care. It's OK if you need tumble dry, quick ironing, steam clean, or machine washable in cold water."],
#    'description': [],
#    'price': '21.99',
#    'store': 'NICETOWN',
#    'categories': ['Home & Kitchen',
#     'Home Décor Products',
#     'Window Treatments',
#     'Curtains & Drapes',
#     'Panels'],
#    'details': {'Brand': 'NICETOWN',
#     'Color': 'Linen-navy Blue Border',
#     'Material': 'Polyester, Polyester Blend',
#     'Product Dimensions': '84"L x 52"W',
#     'Opacity': 'Sheer',
#     'Special Feature': 'Wrinkle Free, Fade Resistant, Washable',
#     'Room Type': 'Bedroom',
#     'Style': 'Classic',
#     'Pattern': 'Solid',
#     'Theme': 'Fashion',
#     'Curtain Form': 'Window Tier Curtain',
#     'Top Style': 'Back Tab, Rod Pocket',
#     'Size': 'W52 x L84',
#     'Included Components': 'Attribute not applicable for product',
#     'Age Range (Description)': 'Adult',
#     'Recommended Uses For Product': 'Indoor',
#     'Specific Uses For Product': 'Decorative',
#     'Number of Items': '2',
#     'Product Care Instructions': 'Machine Wash',
#     'Package Weight': '0.74 Kilograms',
#     'Item Weight': '1.63 pounds',
#     'Manufacturer': 'NICETOWN',
#     'Country of Origin': 'China',
#     'Best Sellers Rank': {'Home & Kitchen': 9923,
#      'Window Treatment Tiers': 3,
#      'Window Curtain Panels': 96},
#     'Date First Available': 'September 27, 2021'},
#    'parent_asin': 'B0834Q33T4'},
#   'review': {'rating': 5.0,
#    'title': 'Good products l',
#    'text': 'Very good value, looks great',
#    'parent_asin': 'B0834Q33T4',
#    'timestamp': 1658543083933},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Home_and_Kitchen',
#    'title': 'US Window And Floor 2" Faux Wood 22.5" W x 84" H, Inside Mount Cordless Window Blinds, 22.5 x 84, Smooth White,CLF0102240840',
#    'average_rating': 4.5,
#    'rating_number': 1117,
#    'features': ['100% Pvc',
#     'Fit windows at the widths between 22 7/8" - 23 1/8". (Actual blind size is 22 1/2" x 84").',
#     'The blinds come with installation instructions, mounting brackets, a tilt wand, a 3 1/4" decorative valance (Ending corner valances are not included), valance clips, and screws.',
#     '2" x 2 1/4" heavy duty steel headrail.',
#     'Cordless lift mechanism provides a more modern and cleaner appearance to every room. Simply hold the bottom rail to lift or lower the blind down. Provide a safe environment for home with pets and kids. No more exposed dangling cords.',
#     'Our high-quality blinds are durable and resistant to humidity. Slats are made of non-leaded PVC. They are low maintenance and long lasting.'],
#    'description': ['The minimum depth required to mount blind is 1 1/2 inch. The minimum depth required for flush-mounting is 3 inch. Our blinds are crafted with high quality components including high profile steel head rail and quality PVC foam slats. Our blinds resist heat and humidity, and are great for all indoor areas including the kitchen, laundry, and bathroom. Installation instructions, a 3 1/4" decorative valance, valance clips, a tilt wand mounting brackets, and screws are included. Valance returns or ending corner valances are NOT included. Mounting screws provided are best for drywall or sheetrock only. They are not for concrete or metal surfaces.'],
#    'price': '50.88',
#    'store': 'US Window And Floor',
#    'categories': ['Home & Kitchen',
#     'Home Décor Products',
#     'Window Treatments',
#     'Blinds & Shades',
#     'Horizontal Blinds'],
#    'details': {'Material': 'Engineered Wood',
#     'Product Dimensions': '84"L x 22.5"W',
#     'Brand': 'US Window And Floor',
#     'Color': 'Smooth White',
#     'Recommended Uses For Product': 'Indoor',
#     'Specific instructions for use': 'Window',
#     'Room Type': 'All Interiors, Bedroom, Living Room, Dining Room, Kitchen, Kids, Nursery, Bathroom, Home Office',
#     'Operation Mode': 'Manual',
#     'Special Feature': 'Cordless, Wand Tilt',
#     'Included Components': 'Blind, Tilt Wand, Inside Mount Type Majestic Valance without Returns, Valance Clips, Mounting Brackets, Screws, Installation Instructions',
#     'Number of Items': '1',
#     'Care instructions': 'Wipe away dust with micro fiber cloth when needed. For stains, mix one part of vinegar and one part of lukewarm water in a bow. Dip soft cloth into the mixture. Wring the cloth. Use the damp-dry cloth to wipe out the stains.',
#     'Size': '22.5 x 84',
#     'Mounting Type': 'Inside Mount',
#     'Number Of Panels': '1',
#     'Water Resistance Level': 'Not Water Resistant',
#     'Item Weight': '9.08 pounds',
#     'Manufacturer': 'US Window and Floor',
#     'Country of Origin': 'Vietnam',
#     'Item model number': 'CLF0102240840',
#     'Best Sellers Rank': {'Home & Kitchen': 194804,
#      'Horizontal Window Blinds': 148},
#     'Volume': '811.69 Cubic Inches',
#     'Fabric Type': '100% Pvc',
#     'Finish types': 'Smooth',
#     'Assembly required': 'No',
#     'Number of pieces': '1',
#     'Warranty Description': '1 year manufacturer',
#     'Batteries required': 'No'},
#    'parent_asin': 'B07PC3PCSZ'},
#   'review': {'rating': 1.0,
#    'title': 'Cheap hardware',
#    'text': 'Installing was a nightmare, poor instructions, flimsy base, and not something I could recommend.',
#    'parent_asin': 'B07PC3PCSZ',
#    'timestamp': 1659301070751},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Clothing_Shoes_and_Jewelry',
#    'title': "Skechers Men's GOrun Consistent-Athletic Workout Running Walking Shoe Sneaker with Air Cooled Foam",
#    'average_rating': 4.5,
#    'rating_number': 11955,
#    'features': ['Imported',
#     'Rubber sole',
#     'Skechers GOrun Consistent is a well-cushioned lace up runner and trainer perfect for a variety of workouts in and out of the gym. The responsive ULTRA GO cushioning midsole and a smooth leather and mesh fabric upper offer an incredibly responsive workout shoe. Ideal for interval running, walking, treadmill and workouts.',
#     'UPPER: Smooth athletic leather upper with synthetic and mesh fabric detail. Comfortable lightweight and well ventilated upper design. Synthetic toe and heel overlays, mesh fabric panels. Lace up front with padded collar and tongue. Printed detail with S logo.',
#     'MIDSOLE CUSHION: ULTRA GO midsole material delivers comfort and response. Parametric midsole construction for support and stability.',
#     'INSOLE CUSHION: Air Cooled Goga Mat insole provides shock absorption and support. OUTSOLE: Mid-foot strike zone promotes efficiency in each stride.',
#     "WEIGHT: 8 3/4 oz. per shoe in a men's size 9."],
#    'description': ["Skechers GOrun Consistent is a well-cushioned lace up runner and trainer perfect for a variety of workouts in and out of the gym. The responsive ULTRA GO cushioning midsole and a smooth leather and mesh fabric upper offer an incredibly responsive workout shoe. The company's success stems from it's high quality, diversified, and affordable product line that meets consumers' Various lifestyle needs. Since it's inception in 1992, the Skechers diverse product offering has grown from utility style boots to include seven Skechers brands and five uniquely branded fashion lines for men and women. Skechers is an award-winning global leader in lifestyle footwear offering shoes that appeal to trend-savvy men, women and kids everywhere. The brand's styles include the latest innovative athletic, casual and fashion sneakers as well as sandals and boots—with many collections featuring Skechers air-cooled memory foam insoles for added comfort. Plus, Skechers offers a range of slip-resistant work FOOTWEAR for men and women, as well as cool, fun, playful and lighted styles that boys and girls love. Always ahead of the fashion curve, Skechers has made its sport, casual and dress casual shoes essential to every closet."],
#    'price': '51.53',
#    'store': 'Skechers',
#    'categories': ['Clothing, Shoes & Jewelry',
#     'Men',
#     'Shoes',
#     'Athletic',
#     'Walking'],
#    'details': {'Product Dimensions': '10 x 15 x 6 inches; 2 Pounds',
#     'Item model number': '220081-WNVR',
#     'Department': 'Mens',
#     'Date First Available': 'September 27, 2019',
#     'Manufacturer': 'Skechers'},
#    'parent_asin': 'B0BG317W7D'},
#   'review': {'rating': 1.0,
#    'title': "DON'T WASTE YOUR MONEY!",
#    'text': 'The shoes are not what Sketchers other shoes feel like. They do not support, nor do they have any kind of arch and heel support. I was very disappointed.',
#    'parent_asin': 'B0BG317W7D',
#    'timestamp': 1662836775674},
#   'split': 'test'},
#  {'product_info': {'main_category': 'Home_and_Kitchen',
#    'title': 'Lasko Oscillating Tower Fan, Nighttime Setting, Remote Control, Portable, Timer, for Bedroom, Home and Office, 3 Quiet Speeds, 42.5", Silverwood, T42954',
#    'average_rating': 4.6,
#    'rating_number': 15380,
#    'features': ['BEAT THE HEAT – Powered by 3 speed settings H/M/L, fan is perfectly sized to aim over a high bed and powerful enough to blow across the room. If you live in the heat with no central air, and window AC units do a poor job of moving air around your whole house or apartment, this fan creates excellent air flow making you feel cooler..Voltage:120 volts.Number of speeds:3',
#     'VERY QUIET – Fan creates a powerful breeze, but even on H, you can still hear the TV. Easy to assemble and operate. Comes with built-in carry handle, optional oscillation and energy efficient auto shut off timer programmable from 0. 5 to 7. 5 hours. The remote is the best when you don’t feel like getting up to change the settings. Widespread oscillation',
#     'SLEEP LIKE A BABY – Circulates the warm & stuffy air at night so you can get some rest. Creates just the right amount of white noise at bedside for sleeping. Nighttime Setting automatically dims the control display and sets the fan on (H) for an hour, then (M) for an hour, and then stays on (L) until you interact with the fan again.',
#     'A REAL SPACE SAVER – Standing 42.5” tall with a small 13” x 13” footprint, the sleek, vertical design optimizes floor space letting you to put the fan in places where pedestal & box fans won’t fit, without sacrificing air circulation, comfort or style. Ideal for the dorm, kitchen, living room, RV and camper.',
#     'TRUSTED FOR GENERATIONS – Lasko has been making quality household products for over 100 years. Lasko fans are ETL Listed, come with our patented Blue Plug safety fuse technology, and are backed by a 1-yr limited , making them a safe choice for a cooling breeze when it’s hot and humid outdoors.'],
#    'description': ['Lasko’s Wind Curve® tower fans have a sophisticated profile and space-saving design that blends seamlessly into your home decor. The high-reaching tower fan design, 3 quiet speeds, and optional oscillation provide maximum air delivery and full-room coverage. Set your fan to automatically turn off after a period of use (0.5-7.5 hours) with the electronic timer option. Now with a convenient Nighttime feature setting, which automatically decreases fan speed and dims controls for overnight use. Move this tower fan easily from room-to-room with a built-in carry handle, and keep the remote close at hand with handy on-board storage. Comes equipped with the Lasko Blue Plug, trusted safety fuse technology. Simple base assembly required.'],
#    'price': '62.79',
#    'store': 'Lasko',
#    'categories': ['Home & Kitchen',
#     'Heating, Cooling & Air Quality',
#     'Household Fans',
#     'Tower Fans'],
#    'details': {'Brand': 'Lasko',
#     'Color': 'woodgrain and grey',
#     'Electric fan design': 'Floor Fan',
#     'Power Source': 'Corded Electric',
#     'Product Dimensions': '13"D x 13"W x 42.5"H',
#     'Room Type': 'Bedroom,Living Room,Dorm,Kitchen',
#     'Special Feature': '7.5 hour timer, Widespread oscillation, Multi-function remote control, Nighttime setting, 3 Speeds',
#     'Recommended Uses For Product': 'Cooling, Ventilating, Air Circulation',
#     'Noise Level': '55.4 dB',
#     'Wattage': '48 watts',
#     'Finish Type': 'Matte',
#     'Air Flow Capacity': '634 Cubic Feet Per Minute',
#     'Blade Length': '42.5 Inches',
#     'Voltage': '120 Volts',
#     'Collection Name': 'Wind Curve',
#     'Switch Type': 'Push Button',
#     'Item Weight': '0.01 ounces',
#     'Included Components': 'Tower Fan, Remote Control, User manual',
#     'Indoor/Outdoor Usage': 'Indoor',
#     'Model Name': 'T42954',
#     'Control Method': 'Touch',
#     'Manufacturer': 'Lasko',
#     'Country of Origin': 'China',
#     'Item model number': 'T42954',
#     'Best Sellers Rank': {'Home & Kitchen': 8201, 'Household Tower Fans': 25},
#     'Finish types': 'Matte',
#     'Care instructions': 'Please see user manual for instructions',
#     'Assembly required': 'No',
#     'Number of pieces': '1',
#     'Warranty Description': '1 year limited warranty',
#     'Batteries required': 'Yes',
#     'Mounting Type Floor Mount': '',
#     '': 'Number of Speeds 3',
#     'Material Plastic': ''},
#    'parent_asin': 'B07PLJ69P2'},
#   'review': {'rating': 5.0,
#    'title': 'BEST - BAR NONE!',
#    'text': 'This fan is great!!!',
#    'parent_asin': 'B07PLJ69P2',
#    'timestamp': 1662836832112},
#   'split': 'test'}]

# %%
user_history['AGMQSZEQFFKH33FJQZLN7MF5QX2Q']
# Out:
# [{'product_info': {'main_category': 'Health_and_Household',
#    'title': 'Spoonk Acupressure Eco Mat, Pagoda Blue - with Massage Ball, Travel Mat & Sling Bag - Back & Neck Massager - Travel Pillow - Stress & Muscle Relief - Sleep Aid - Relaxation Kit - Made with Cotton',
#    'average_rating': 4.3,
#    'rating_number': 2974,
#    'features': ['The Original Spiked Relaxation Mat; Spoonk Mats work on the simple principle of acupressure; Over 6000 stimulation points help with stress relief; Combo includes regular mat with sling-style carrying bag, travel mat, and groove ball',
#     'Stress, Muscle Tension And Pain Relief; High quality stimulation points increase circulation; A great sleep aid and massager for stiff muscles; Make it part of your go-to relaxation kit for back and neck pain; Rejuvenate and rebalance the whole body',
#     'Achieve Deep Relaxation; Use your Spoonk Mat to calm down before bed, help you wake up in the morning, soothe muscles after a workout; Travel Mat rolls up for easy head, neck, and back massage;\xa0Use Groove Ball for foot massage and reflexology',
#     'Eco-Friendly; Non-toxic stim points made with hypoallergenic ABS plastic; Mats are filled with plant-based, CertiPur-US Eco-foam; 100% cotton fabric is Global Organic Textile Standard certified',
#     'Relax Your World; Spoonk is committed to producing unique products that improve quality of life; Each product is designed to have long lasting effects on your health, immune system, and overall state of mind'],
#    'description': ['Spoonk Acupressure Mat works on the principles of acupressure - healing art known as Shiatsu massage - by stimulating increased circulation with 6210 acupressure stimulation points pressed against problematic areas it helps remove blocked energy and muscle tension or pain while rejuvenates whole body. Laying on the acupressure mat before sleeping for 25 minutes develops effect of deep relaxation that is crucial for deeper and sounder sleep .'],
#    'price': '69.99',
#    'store': 'Spoonk',
#    'categories': ['Health & Household',
#     'Health Care',
#     'Alternative Medicine',
#     'Acupuncture'],
#    'details': {'Material': '100% Cotton',
#     'Item Weight': '1.3 Kilograms',
#     'Brand': 'Spoonk',
#     'Color': 'Pagoda Blue',
#     'Product Dimensions': '18 x 8 x 8 inches; 2.87 Pounds',
#     'Is Discontinued By Manufacturer': 'No',
#     'Date First Available': 'February 16, 2013',
#     'Manufacturer': 'Spoonk Space'},
#    'parent_asin': 'B07BYJ3389'},
#   'review': {'rating': 5.0,
#    'title': 'Five Stars',
#    'text': 'Love it!!!!',
#    'parent_asin': 'B07BYJ3389',
#    'timestamp': 1452779837000},
#   'split': 'history'},
#  {'product_info': {'main_category': 'Clothing_Shoes_and_Jewelry',
#    'title': "adidas Outdoor Men's AX2 Mid Gore-Tex Hiking Boot",
#    'average_rating': 4.6,
#    'rating_number': 417,
#    'features': ['60% Textile/40% Synthetic',
#     'Rubber sole',
#     'Lining: GORE-TEX extended comfort footwear',
#     'Sockliner: molded sockliner to enhance comfort and fit',
#     'Midsole: lightweight EVA midsole for long term cushioning',
#     'Outsole: super high traction rubber for optimal grip in wet conditions',
#     '5mm lug height'],
#    'description': ['A fast, lightweight mid-cut boot for hikes and multifunctional use. Keeps feet dry with a breathable gore-tex® membrane. Enhanced grip, eva cushioning and adiprene® support.'],
#    'price': 'None',
#    'store': 'adidas outdoor',
#    'categories': ['Clothing, Shoes & Jewelry',
#     'Men',
#     'Shoes',
#     'Outdoor',
#     'Hiking & Trekking',
#     'Hiking Boots'],
#    'details': {'Is Discontinued By Manufacturer': 'No',
#     'Product Dimensions': '14 x 10 x 6 inches; 1.31 Pounds',
#     'Item model number': 'Q34271',
#     'Department': 'mens',
#     'Date First Available': 'December 19, 2013',
#     'Manufacturer': 'adidas Outdoor Adult Code'},
#    'parent_asin': 'B00DQZ1Z7I'},
#   'review': {'rating': 5.0,
#    'title': 'Five Stars',
#    'text': 'Best boots ever!!',
#    'parent_asin': 'B00DQZ1Z7I',
#    'timestamp': 1453752941000},
#   'split': 'history'},
#  {'product_info': {'main_category': 'Grocery_and_Gourmet_Food',
#    'title': 'Mastic Gum – 0.6oz',
#    'average_rating': 4.0,
#    'rating_number': 310,
#    'features': [],
#    'description': ['Mastic Gum (Mastik Sakiz)'],
#    'price': '11.99',
#    'store': 'Krinos',
#    'categories': ['Grocery & Gourmet Food',
#     'Snacks & Sweets',
#     'Candy & Chocolate',
#     'Chewing & Bubble Gum'],
#    'details': {'Is Discontinued By Manufacturer': 'No',
#     'Package Dimensions': '3.23 x 2.13 x 2.05 inches; 0.6 Ounces',
#     'UPC': '844208086066',
#     'Manufacturer': 'Krinos'},
#    'parent_asin': 'B0036Z93PO'},
#   'review': {'rating': 5.0,
#    'title': 'Five Stars',
#    'text': 'Love this stuff!!!!! Top quality, been buying this for the past two years.',
#    'parent_asin': 'B0036Z93PO',
#    'timestamp': 1509146470265},
#   'split': 'history'},
#  {'product_info': {'main_category': 'Health_and_Household',
#    'title': 'Sonic LX Professional Personal Massager Gun Percussion Massage Gun with Heat - 9 Speeds + 10 Attachment Massagers for Neck and Back - Massage Gun Deep Tissue Muscle Massage Gun for Athletes (Blue)',
#    'average_rating': 4.6,
#    'rating_number': 2913,
#    'features': ["HEATED MASSAGE GUN FOR MAXIMUM RELIEF: The heated massage gun is an excellent way to provide you with deep tissue relief and improve flexibility. The heated head option of this personal massager helps relax stiffness in your body's tissues, which will feel much better after using one!",
#     "FASTER RECOVERY: Give your muscles the relief they deserve. This muscle massage gun is perfect for giving your body professional therapy it'll love. You can choose from 9 intensity levels and switch up with one of the 10 included heads.",
#     'MYRIAD THERAPEUTIC BENEFITS: Fast & deep pain & stress relief right in your hand! The LifePro deep tissue muscle massage gun comes with 10 massage tips to rejuvenate your neck, back & whole body.',
#     'GO PRO & BOOST YOUR PERFORMANCE: Train harder, get stronger! Your massager gun vibrations & heating trigger myofascial release to boost your body’s ability to regenerate cells & repair itself.',
#     "LONG-LASTING POWER ON THE GO: Don't let your healing stop! This handheld percussion massage gun comes with a battery providing up to 4 hrs of quiet & effective massage on a single charge."],
#    'description': [],
#    'price': '139.99',
#    'store': 'LifePro',
#    'categories': ['Health & Household',
#     'Wellness & Relaxation',
#     'Massage Tools & Equipment',
#     'Electric Massagers',
#     'Back Massagers'],
#    'details': {'Use for': 'Whole Body',
#     'Power Source': 'Battery Powered',
#     'Material': 'Metal',
#     'Item Weight': '2 Pounds',
#     'Brand': 'LifePro',
#     'Product Dimensions': '14.17 x 4.13 x 9.84 inches; 2 Pounds',
#     'Date First Available': 'December 9, 2020',
#     'Manufacturer': 'LifePro'},
#    'parent_asin': 'B09H7NQH1L'},
#   'review': {'rating': 5.0,
#    'title': 'A must have!!!!',
#    'text': 'I use it for trigger point therapy. I am a massage therapist and have never used anything of this nature. I was looking at many other devices like this and could not bring myself to spend hundreds of dollars. After doing much research I came to choose your product. Not only did it have wonderful reviews, it was reasonably priced and I have heard the customer service and warranty are exceptional!',
#    'parent_asin': 'B09H7NQH1L',
#    'timestamp': 1608903361416},
#   'split': 'history'},
#  {'product_info': {'main_category': 'Health_and_Household',
#    'title': 'Halsa EMF Protection Cell Phone Sleeve, EMF Blocking Carrying Case, Phone Pouch. Pure Silver Fiber Fabric. High Shielding Efficiency, Fits in Pocket or Purse. Fits Most Phones. 4"x 8" Size.',
#    'average_rating': 4.4,
#    'rating_number': 111,
#    'features': ['\u200b\u200b🙌EFFECTIVE, EMF BLOCKING FABRIC: The Halsa EMF Blocking phone pouch interior fabric is comprised of 100% silver which offers the highest possible protection from electromagnetic field exposure emitted by mobile phones, resulting in a reduction of exposure to EMF by more than 99%. Outer colors available in both Gray and Pink!',
#     '👍ONE SIZE FITS MOST: This radiation blocking pouch/sleeve will fit most smart phones on the market today. The sleeve measures 8 inches tall by 4 inches wide. It features a drawstring closure to secure the phone. Please be sure to measure your phone prior to purchasing if you have an extra large phone.',
#     '✅ SHIELDING CAPABILITY: Reduces WiFi at both 2.4 and 5GHz, Bluetooth, Cell Signals including 5G networks, GPS, RFID, and radio signals with 60-80dB. Can accommodate different devices such as cell phones, two-way radios, smart watches,GPS units and other electronic devices.',
#     '😎PROTECTION ON THE GO: The best part about our sleeve, other than being lined with 100% silver fiber fabric, is that it is flexible, portable, and fits inside of your pocket without adding any bulk! Perfect for inside a purse, inside a backpack, in your pocket and so much more. Great for men, women, and kids!',
#     '🌞LIVE MORE, WORRY LESS: Our radiation protection hat will help to eliminate the anxiety about everyday radiation and the dangers that come with it. Feel confident that you are helping to protect yourself from the radiation that is around us.',
#     '👪 SMALL, FAMILY OWNED BUSINESS: You’re supporting a small, family owned business based here in the USA. We appreciate each of our customers and are happy to help with any questions about our breathing bracelets. Thank you for shopping local!',
#     '📲HOW TO TEST: Do not place a cell phone inside the product, and then try to call it. This is NOT an accurate way of testing the effectiveness. Instead, use an EMF meter to compare RF/microwave levels inside and outside the EMF product.'],
#    'description': [],
#    'price': '19.99',
#    'store': 'Halsa',
#    'categories': ['Health & Household',
#     'Health Care',
#     'Alternative Medicine',
#     'Magnetic Field Therapy'],
#    'details': {'Package Dimensions': '9.21 x 5.35 x 0.43 inches',
#     'Item Weight': '0.634 ounces',
#     'Item model number': 'Halsa1',
#     'Best Sellers Rank': {'Health & Household': 50556,
#      'Magnetic Field Therapy Products': 72},
#     'Special features': 'Card Slot',
#     'Other display features': 'Wireless',
#     'Form Factor': 'Pouch',
#     'Color': 'Grey',
#     'Manufacturer': 'Halsa',
#     'Date First Available': 'March 3, 2021',
#     'Brand': 'Halsa',
#     'Pattern': 'Solid',
#     'Theme': 'No Theme'},
#    'parent_asin': 'B08XWW17RF'},
#   'review': {'rating': 5.0,
#    'title': 'Beautiful!',
#    'text': 'Fits iPhone 13 pro no problem. I use this bag to put my phone in while at work. Very trustworthy brand. I loved it so much I purchased a second one!',
#    'parent_asin': 'B08XWW17RF',
#    'timestamp': 1654163692688},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Health_and_Household',
#    'title': 'Halsa EMF Protection Cell Phone Sleeve, EMF Blocking Carrying Case, Phone Pouch. Pure Silver Fiber Fabric. High Shielding Efficiency, Fits in Pocket or Purse. Fits Most Phones. 4"x 8" Size.',
#    'average_rating': 4.4,
#    'rating_number': 111,
#    'features': ['\u200b\u200b🙌EFFECTIVE, EMF BLOCKING FABRIC: The Halsa EMF Blocking phone pouch interior fabric is comprised of 100% silver which offers the highest possible protection from electromagnetic field exposure emitted by mobile phones, resulting in a reduction of exposure to EMF by more than 99%. Outer colors available in both Gray and Pink!',
#     '👍ONE SIZE FITS MOST: This radiation blocking pouch/sleeve will fit most smart phones on the market today. The sleeve measures 8 inches tall by 4 inches wide. It features a drawstring closure to secure the phone. Please be sure to measure your phone prior to purchasing if you have an extra large phone.',
#     '✅ SHIELDING CAPABILITY: Reduces WiFi at both 2.4 and 5GHz, Bluetooth, Cell Signals including 5G networks, GPS, RFID, and radio signals with 60-80dB. Can accommodate different devices such as cell phones, two-way radios, smart watches,GPS units and other electronic devices.',
#     '😎PROTECTION ON THE GO: The best part about our sleeve, other than being lined with 100% silver fiber fabric, is that it is flexible, portable, and fits inside of your pocket without adding any bulk! Perfect for inside a purse, inside a backpack, in your pocket and so much more. Great for men, women, and kids!',
#     '🌞LIVE MORE, WORRY LESS: Our radiation protection hat will help to eliminate the anxiety about everyday radiation and the dangers that come with it. Feel confident that you are helping to protect yourself from the radiation that is around us.',
#     '👪 SMALL, FAMILY OWNED BUSINESS: You’re supporting a small, family owned business based here in the USA. We appreciate each of our customers and are happy to help with any questions about our breathing bracelets. Thank you for shopping local!',
#     '📲HOW TO TEST: Do not place a cell phone inside the product, and then try to call it. This is NOT an accurate way of testing the effectiveness. Instead, use an EMF meter to compare RF/microwave levels inside and outside the EMF product.'],
#    'description': [],
#    'price': '19.99',
#    'store': 'Halsa',
#    'categories': ['Health & Household',
#     'Health Care',
#     'Alternative Medicine',
#     'Magnetic Field Therapy'],
#    'details': {'Package Dimensions': '9.21 x 5.35 x 0.43 inches',
#     'Item Weight': '0.634 ounces',
#     'Item model number': 'Halsa1',
#     'Best Sellers Rank': {'Health & Household': 50556,
#      'Magnetic Field Therapy Products': 72},
#     'Special features': 'Card Slot',
#     'Other display features': 'Wireless',
#     'Form Factor': 'Pouch',
#     'Color': 'Grey',
#     'Manufacturer': 'Halsa',
#     'Date First Available': 'March 3, 2021',
#     'Brand': 'Halsa',
#     'Pattern': 'Solid',
#     'Theme': 'No Theme'},
#    'parent_asin': 'B08XWW17RF'},
#   'review': {'rating': 5.0,
#    'title': 'Must have if you carry your phone everyday',
#    'text': 'Purchased these for me and my wife, I could not be any happier. Superior quality and does what it says it will. The only true emf protection on Amazon.',
#    'parent_asin': 'B08XWW17RF',
#    'timestamp': 1654163897260},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Clothing_Shoes_and_Jewelry',
#    'title': "adidas Men's Adilette Shower Slide",
#    'average_rating': 4.5,
#    'rating_number': 109066,
#    'features': ['100% Synthetic',
#     'Imported',
#     'Rubber sole',
#     'Shaft measures approximately low-top from arch',
#     "adidas men's Slide Sandal",
#     'The adidas brand has a long history and deep-rooted connection with sport. Everything we do is rooted in sport.',
#     'Driven by a relentless pursuit of innovation as well as decades of accumulating sports science expertise, we cater for all, from elite professional athletes and teams to any individual who wants to make sport part of their lives.'],
#    'description': ['Flip Flops Man Adidas ADILETTE SHOWER AQ1701'],
#    'price': '28.82',
#    'store': 'adidas',
#    'categories': ['Clothing, Shoes & Jewelry',
#     'Men',
#     'Shoes',
#     'Athletic',
#     'Sport Sandals & Slides'],
#    'details': {'Is Discontinued By Manufacturer': 'No',
#     'Product Dimensions': '8 x 4 x 7 inches; 2.45 Pounds',
#     'Item model number': 'AQ1701',
#     'Department': 'Mens',
#     'Date First Available': 'July 1, 2004',
#     'Manufacturer': 'Adidas'},
#    'parent_asin': 'B07FDB7GMZ'},
#   'review': {'rating': 1.0,
#    'title': 'Poorly made, not the original',
#    'text': 'Purchased these for shower shoes, they arrived with defects on the sole. It looked as though they were melted on the bottom. They ran too big , I wear an 8 1/2 and purchased an 8 that felt like a 10. The form of them make you feel like you are tilted forward.',
#    'parent_asin': 'B07FDB7GMZ',
#    'timestamp': 1654164287830},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Electronics',
#    'title': 'TP-Link 24 Port Gigabit Ethernet Switch | Desktop/ Rackmount | Limited Lifetime Protection | Plug & Play | Shielded Ports | Sturdy Metal | Fanless Quiet | Traffic Optimization | Unmanaged (TL-SG1024S)',
#    'average_rating': 4.7,
#    'rating_number': 117733,
#    'features': ['【One Switch Made to Expand Network】24× 10/100/1000Mbps RJ45 Ports supporting Auto Negotiation and Auto MDI/MDIX',
#     '【Gigabit that Saves Energy】Latest innovative energy-efficient technology greatly expands your network capacity with much less power consumption and helps save money',
#     '【Reliable and Quiet】IEEE 802. 3X flow control provides reliable data transfer and Fanless design ensures quiet operation',
#     '【Plug and Play】Easy setup with no software installation or configuration needed',
#     '【Limited Lifetime】Industry leading lifetime and free 24/7 technical support'],
#    'description': ['24-Port Gigabit Desktop/Rackmount Switch.'],
#    'price': '88.28',
#    'store': 'TP-Link',
#    'categories': ['Electronics',
#     'Computers & Accessories',
#     'Networking Products',
#     'Switches'],
#    'details': {'Product Dimensions': '11.57 x 7.09 x 1.73 inches',
#     'Item Weight': '3.44 pounds',
#     'Item model number': 'TL-SG1024S',
#     'Best Sellers Rank': {'Computer Networking Switches': 16},
#     'Date First Available': 'December 5, 2017',
#     'Manufacturer': 'TP-Link',
#     'Brand': 'TP-Link',
#     'Number of Ports': '24',
#     'Included Components': '24-Port Gigabit Desktop/Rackmount Switch Power cord Installation guide Rackmount kit Rubber feet',
#     'Color': 'Black',
#     'Compatible Devices': 'Desktop'},
#    'parent_asin': 'B0BZLBL1L9'},
#   'review': {'rating': 5.0,
#    'title': 'Stick with TP Link!',
#    'text': 'I purchased this to hardwire multiple gaming consoles instead of running multiple dedicated lines. Works like a charm with my next gen gaming consoles.',
#    'parent_asin': 'B0BZLBL1L9',
#    'timestamp': 1654164442454},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Electronics',
#    'title': 'Outlet Wall Mount ONLY for eero 6 Dual-Band mesh Wi-Fi 6 System [NOT Fit for eero Pro 6 and eero 6+], No Messy Wires | Space Saving | Easily Be Moved Outlet Mount Holder for eero 6 Extender (3 Pack)',
#    'average_rating': 4.6,
#    'rating_number': 446,
#    'features': ['【Upgraded Version】This outlet wall mount is specially designed for eero 6 mesh wifi system, NOT fit for the eero Pro 6 or eero mesh. Please confirm your eero device before purchase.',
#     '【Fantastic Cords Management】You can wrap the cord and hide them around the groove in the back of the eero 6 wall mount. Without messy wires any more, saving space while maintaining beauty.',
#     '【Easy to Move】All messy wires are hided on the back of the eero 6 mesh plug mount, you can plug in your eero wifi router to any electrical outlets in your home and can easily be moved from room to room, making the setup of network much more simple.',
#     '【Installation without Tools】No holes or screws in installation means no harm to your wall and no need extra tools. Looks neat and tidy with this outlet mount for eero 6 mesh wifi system.',
#     '【Worry-Free Guarantee】Thanks for choosing Tizomi Mall. Feel free to contact us for any questions or problems. We will provide you a satisfied service. (Note: eero 6 router and plug are NOT included).'],
#    'description': ['Wall mount holder for eero 6 dual-band mesh wifi 6 system (Does NOT fit the eero Pro 6)',
#     "1. No messy wires, it's a great product for getting the eero wifi router off of desk space. Hides the cable well.  2. Made of durable hard plastic material, sturdy enough and can hold the eero router securely.  3. Easy to install and replace, no need any tools to install, seamlessly connects your entire home, say goodbye to dead spots and buffering.  4. Suitable for any position as long as there is a socket, elegant looking makes your home more neat and clean.",
#     'Please Note',
#     'The eero 6 router device is',
#     'NOT',
#     'included  Designed for New eero 6 mesh WiFi router ONLY,',
#     'NOT',
#     'compatible with eero Pro 6.'],
#    'price': '18.99',
#    'store': 'Tizomi',
#    'categories': ['Electronics',
#     'Computers & Accessories',
#     'Networking Products',
#     'Whole Home & Mesh Wi-Fi Systems'],
#    'details': {'Package Dimensions': '7.99 x 4.37 x 3.74 inches',
#     'Item Weight': '10.8 ounces',
#     'Best Sellers Rank': {'Computers & Accessories': 6889,
#      'Whole Home & Mesh Wi-Fi Systems': 202},
#     'Date First Available': 'December 17, 2020',
#     'Manufacturer': 'Tizomi',
#     'Brand': 'Tizomi',
#     'Special Feature': 'WPS',
#     'Frequency Band Class': 'Dual-Band',
#     'Compatible Devices': 'Personal Computer',
#     'Frequency': '5 GHz',
#     'Recommended Uses For Product': 'Home',
#     'Connectivity Technology': 'WLAN',
#     'Number of Ports': '6',
#     'Control Method': 'App'},
#    'parent_asin': 'B0BMG8YVR3'},
#   'review': {'rating': 1.0,
#    'title': 'Just ok',
#    'text': 'Did not work for me. Difficult to run the wires through and hide the power cord. Purchased another brand on Amazon and completely happy.',
#    'parent_asin': 'B0BMG8YVR3',
#    'timestamp': 1654164768686},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Health_and_Household',
#    'title': 'Egooz Smell Proof Bags with Combination Lock, 11"X9" Large Smell Proof Pouch, Waterproof Smell Proof Case Conatiners for Travel Storage, Dark Grey',
#    'average_rating': 4.8,
#    'rating_number': 678,
#    'features': ['Covenient for stoarge: Open and Close with a smooth zipper around the bag, Large capacity can hold a lot of essential items,',
#     'Privacy Security Lock: Zippers interlock by built in combination lock to guard privacy and safety, Hanger tag includes simple instruction to set your desire code.',
#     'Function and Considerable Design: It has two velcro prockets removable dividers which allowing you organize your stuffs according your choice.',
#     'Perfect Size: Big enough to store necessary accessories, small and light weight for portable carry, Perfect for travel and home use.',
#     '100% MONEY BACK GUARANTEE. We stand behind the durability of our goods and offer an unconditional guarantee. If you are not completely satisfied with our products, we will refund your money no questions asked.'],
#    'description': ['Egooz Storage Bag with Combination Lock (11"X9"), Waterproof Storage Pouch for Travel Storage, Dark Gray'],
#    'price': 'None',
#    'store': 'E EGOOZ',
#    'categories': ['Health & Household',
#     'Household Supplies',
#     'Tobacco-Related Products',
#     'Tobacco Pipes & Accessories',
#     'Bags & Pouches'],
#    'details': {'Brand': 'E EGOOZ',
#     'Material': 'Carbon Fiber',
#     'Color': 'Grey',
#     'Product Dimensions': '11"L x 9"W x 2"H',
#     'Special Feature': 'Lockable',
#     'Recommended Uses For Product': 'Storage and Travel',
#     'Closure Type': 'Zipper',
#     'Shape': '矩形',
#     'Number of Items': '1',
#     'Size': '14 Piece Set',
#     'Number of Sets': '1',
#     'Manufacturer': 'E EGOOZ',
#     'Part Number': 'PBSPB-2019-04-A',
#     'Item Weight': '9.6 ounces',
#     'Style': 'Stylish',
#     'Pattern': 'Solid',
#     'Item Package Quantity': '1',
#     'Number Of Pieces': '1',
#     'Special Features': 'Lockable',
#     'Batteries Included?': 'No',
#     'Best Sellers Rank': {'Health & Household': 309969,
#      'Tobacco Pipe Bags & Pouches': 331},
#     'Date First Available': 'May 18, 2020'},
#    'parent_asin': 'B0874VR5RN'},
#   'review': {'rating': 5.0,
#    'title': 'Works like a charm!',
#    'text': 'I purchased this bag for a trip and it worked wonders. There are a lot of these type of bags on the internet and I have tried many. Most of them ten times more expensive. This bag blew the rest out of the water.',
#    'parent_asin': 'B0874VR5RN',
#    'timestamp': 1654165642547},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Electronics',
#    'title': 'Pedco UltraPod Lightweight Camera Tripod black ,One Size',
#    'average_rating': 4.5,
#    'rating_number': 840,
#    'features': ['Lightweight and compact tripod with fold-out legs and non-slip vinyl feet',
#     'Position camera at any angle with U-ball and socket mount assembly',
#     'Removable Velcro "one wrap" strap allows attachment to posts, tree limbs, railings, pack frames, or any sturdy object',
#     'Weighs two ounces; folds down to four inches for easy packing'],
#    'description': ['The UltraPod I is a small, convenient tripod that can be taken and used anywhere. Its 3 legs offer a stable base for your small camera, and the strap allows you to attach the UltraPod to a fence, rail, or tree. The strap is black Velcro "one wrap" and designed to be easily removable. This is designed to be a fun tripod for use with small digital cameras, web cams and more. Can also be used to mount remote flashes to light stands using the Velcro strap. Weight: 1.7oz. Amazon.com The UltraPod I from Pedco is a lightweight and compact tripod designed for go-anywhere convenience and to be used with any small optical device with a tripod socket. Weighing in at two ounces and measuring four inches folded, the UltraPod I can fit into a small camera bag or pack without adding excessive weight or bulk. Constructed from molded fiberglass reinforced nylon with aluminum-threaded components, the UltraPod I can support up to three pounds securely. With three fold out legs, the tripod provides a stable platform or it can be attached securely to a fence, rail, or tree with its Velcro "one wrap" strap. The UltraPod I\'s unique ball and socket mount assembly allow you to position the camera at any angle--granting access to otherwise tough to capture shots. s defects, the UltraPod I is built for years of use. Features: Fits any camera with a tripod socket Position camera at any angle with ball and socket mount assembly Molded from fiberglass reinforced nylon with aluminum-threaded components Fold-out legs with non-slip vinyl feet Removable Velcro "one wrap" strap Maximum Safe Load: 3 pounds Pan Adjustment: 360 degrees Tilt Adjustment: +/- 90 degrees Angular Adjustment: +/- 20 degrees Folded dimensions: 4 by 1 by 1. s defects'],
#    'price': 'None',
#    'store': 'PEDCO',
#    'categories': ['Electronics',
#     'Camera & Photo',
#     'Tripods & Monopods',
#     'Complete Tripods'],
#    'details': {'Item Package Dimensions L x W x H': '8.11 x 4.25 x 1.85 inches',
#     'Package Weight': '0.05 Kilograms',
#     'Item Dimensions  LxWxH': '5 x 5 x 5 inches',
#     'Item Weight': '0.09 Pounds',
#     'Brand Name': 'PEDCO',
#     'Warranty Description': 'Manufacturer Warranty',
#     'Model Name': 'IRP-UP1-BK-STD-BLK',
#     'Color': 'black',
#     'Material': 'Aluminum',
#     'Suggested Users': 'unisex-adult',
#     'Number of Items': '1',
#     'Manufacturer': 'PEDCO',
#     'Part Number': 'PED01020-BRK',
#     'Model Year': '2014',
#     'Included Components': 'PEDCO UltraPod 1, Tripod, 4"x1"x1.25", Black',
#     'Size': 'One Size',
#     'Sport Type': 'Camping & Hiking',
#     'Best Sellers Rank': {'Complete Tripod Units': 931},
#     'Date First Available': 'January 1, 2008',
#     'Brand': 'PEDCO',
#     'Compatible Devices': 'Camera',
#     'Special Feature': 'Manual',
#     'Weight Limit': '3 Pounds',
#     'Maximum Height': '10 Inches',
#     'Tripod Head Type': 'Ball Heads'},
#    'parent_asin': 'B000ANGNN0'},
#   'review': {'rating': 1.0,
#    'title': 'Great product, bad business practices',
#    'text': 'I am an ultralight thru hiker and was recommended this product by a fellow hiker. It is incredible, the lightest you can get if you like filming on the trail. My issue was that I received a used product and was disappointed. Amazon quickly sent me a new one and hopefully solved the issue of sending out used items. If I had to I would definitely buy again. This is the most convenient tripod I have owned.',
#    'parent_asin': 'B000ANGNN0',
#    'timestamp': 1654166269935},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Health_and_Household',
#    'title': 'Hallmark 9" Medium Mother\'s Day Gift Bag with Tissue Paper (Yellow with Pretty Flowers, Gold Accents) for Moms, Grandmothers, Nanas, Mom Squads',
#    'average_rating': 4.8,
#    'rating_number': 939,
#    'features': ['SIZE: Medium gift bag measures approximately 7.7" wide by 9.6" high by 4.3" deep. Perfect for holding candles, figurines, standard sized books, travel mugs or jewelry.',
#     'FRESH DESIGN: Vibrant yellow gift bag features colorful flowers in pink, coral, dark purple, white and teal green; Modern script lettering reads "Happy Mother\'s Day" in metallic gold; Green ribbon handles complete the look',
#     'ALL IN ONE: Purchase includes 2 sheets of white tissue paper to make wrapping presents for Mom quick and easy',
#     'THANK THEM for all that they are: Beautiful gift bags, wrapping paper and greeting cards are a great way to show the moms in your life how much they are loved',
#     "ECO FRIENDLY: Crafted from high-quality paper materials, Hallmark's eco friendly gift bags are made with paper from well-managed forests"],
#    'description': ['Show the moms in your life how much they are loved. This bold and bright yellow gift bag features sweet, artistic flowers in pink, magenta, indigo, teal green, coral and white. Elegant and modern script lettering reads "Happy Mother\'s Day" in gold foil. Green ribbon handles and 2 sheets of tissue paper add a special touch to presents for mom, grandma, nana, meemaw, or your mom squad. Medium gift bag is perfect for holding a book, scarf, candle or figurine. The Hallmark brand is widely recognized as the very best for greeting cards, gift wrap, and more. For more than 100 years, Hallmark has been helping its customers make everyday moments more beautiful and celebrations more joyful.'],
#    'price': 'None',
#    'store': 'Hallmark',
#    'categories': ['Health & Household',
#     'Stationery & Gift Wrapping Supplies',
#     'Gift Wrapping Supplies',
#     'Gift Bags'],
#    'details': {'Package Dimensions': '10.79 x 8.43 x 0.94 inches',
#     'Item Weight': '1.76 ounces',
#     'Manufacturer': 'Hallmark',
#     'Item model number': '0005WDB1171',
#     'Best Sellers Rank': {'Industrial & Scientific': 97271,
#      'Gift Wrap Bags': 3274},
#     'Date First Available': 'November 24, 2020',
#     'Brand': 'Hallmark',
#     'Color': 'Yellow, Gold',
#     'Material': 'Paper',
#     'Occasion': "Mother's Day",
#     'Included Components': 'Tissue Paper, Ribbon',
#     'Theme': 'Flowers,Forests',
#     'Number of Items': '1',
#     'Unit Count': '1.0 Count',
#     'Pattern': 'Yellow with pretty flowers',
#     'Size': '1 Count (Pack of 1)'},
#    'parent_asin': 'B0C3ML4LHN'},
#   'review': {'rating': 5.0,
#    'title': 'It’s Hallmark',
#    'text': 'Another terrific purchase from hallmark. Received it quick without any damage and you get everything you need all in one.',
#    'parent_asin': 'B0C3ML4LHN',
#    'timestamp': 1654166374163},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Clothing_Shoes_and_Jewelry',
#    'title': 'THE NORTH FACE Thermoball Traction Mule V Mens Slippers',
#    'average_rating': 4.7,
#    'rating_number': 2713,
#    'features': ['100% recycled PET ripstop',
#     'Made in the USA or Imported',
#     'Rubber sole',
#     "FORM MEETS FUNCTION. The Men's ThermoBall Traction Mule V shoe combines ThermoBall Eco insulation with a high-traction rubber outsole to make a slip-on that's ideal for base camp, après ski or shuffling out to grab the morning paper.",
#     'WATER-RESISTANT DURABILITY. Made with a 100%-recycled ripstop upper and finished with a Durable-Water Repellent (DWR), these highly durable winter shoes are water-resistant and warm.',
#     'SUPERIOR INSULATION. Take on the cold with superior warmth and recycled materials. Thermoball Eco uses small, round synthetic fiber clusters that closely mimic the way down insulates: trapping heat within small air pockets for warmth retention.',
#     "RECYCLED OUTSOLE. Move around confidently and with a clear conscience thanks to a 20%-recycled rubber outsole with supreme traction. From base camp to peak, you'll love the ability to stay grounded and maintain traction.",
#     'TAKE ON THE DAY. An essential closet staple, this shoe is a go-to classic anytime. Enjoy a comfortable fleece collar lining and a collapsible heel with elastic side panels for easy on/off. Proudly wear these as a badge of exploration with The North Face.'],
#    'description': [],
#    'price': '58.95',
#    'store': 'THE NORTH FACE',
#    'categories': ['Clothing, Shoes & Jewelry',
#     'Men',
#     'Shoes',
#     'Mules & Clogs'],
#    'details': {'Is Discontinued By Manufacturer': 'No',
#     'Product Dimensions': '6 x 10 x 15 inches; 1.1 Pounds',
#     'Department': 'mens',
#     'Date First Available': 'March 12, 2019',
#     'Manufacturer': 'The North Face'},
#    'parent_asin': 'B07PM8Y639'},
#   'review': {'rating': 5.0,
#    'title': 'Perfect fit, perfect slipper!',
#    'text': 'North face almost never lets me down. After a long day on the trail your feet will praise you for slipping into these. They are sturdy and well built and still make you feel as though you are walking on a cloud.',
#    'parent_asin': 'B07PM8Y639',
#    'timestamp': 1654168004730},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Electronics',
#    'title': 'Thule Subterra PowerShuttle Electronics Carrying Case',
#    'average_rating': 4.8,
#    'rating_number': 3968,
#    'features': ['Nylon',
#     'Imported',
#     'An electronics accessory case perfect for travel or work',
#     'Organize cables, adapters and small electronics in dedicated storage',
#     'Protect large headphones in main compartment',
#     'Charge your phone on the go with exterior phone pocket and cord pass through',
#     'Keep travel essentials within reach from your airline seat pocket',
#     'Built to last and protect belongings with durable materials, padding and YKK zippers'],
#    'description': ['Organize all cords, chargers, adapters and headphones in a Thule Subterra PowerShuttle. These electronic accessory case are designed to protect every piece of gear with dedicated pockets, elastic loops and padding. Perfect for travel, work or working from home, these travel cord organizers easily fit into backpacks, handbags and an airline seat pocket for quick access while in transit. Organize your life with a Thule Subterra PowerShuttle.'],
#    'price': '25.95',
#    'store': 'Thule',
#    'categories': ['Electronics',
#     'Computers & Accessories',
#     'Laptop Accessories',
#     'Bags, Cases & Sleeves',
#     'Messenger & Shoulder Bags'],
#    'details': {'Item Package Dimensions L x W x H': '13.39 x 8.11 x 3.31 inches',
#     'Package Weight': '0.29 Kilograms',
#     'Item Dimensions  LxWxH': '7.3 x 3.5 x 12.2 inches',
#     'Item Weight': '0.1 Kilograms',
#     'Brand Name': 'Thule',
#     'Warranty Description': 'Limited Lifetime',
#     'Model Name': 'Subterra',
#     'Color': 'Black',
#     'Material': 'Nylon',
#     'Suggested Users': 'unisex-adult',
#     'Manufacturer': 'Thule',
#     'Part Number': '3204139',
#     'Model Year': '2019',
#     'Style': 'Plus',
#     'Included Components': 'electronics travel case',
#     'Size': 'Plus',
#     'Best Sellers Rank': {'Laptop Messenger & Shoulder Bags': 26},
#     'Date First Available': 'August 10, 2019'},
#    'parent_asin': 'B07YXL6652'},
#   'review': {'rating': 5.0,
#    'title': 'It’s Thule, what more can I say',
#    'text': 'Great bag to organize all your accessories. I keep all my Apple products in this bag. I am brand loyal because of the impeccable quality and customer service.',
#    'parent_asin': 'B07YXL6652',
#    'timestamp': 1654168390502},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Electronics',
#    'title': 'Spigen Urban Fit Designed for Apple Airpods Case Cover for Airpods 1 & 2 [LED Light Visible] - Midnight Green',
#    'average_rating': 4.6,
#    'rating_number': 860,
#    'features': ['Minimal look with a premium knit fabric and PC lining',
#     'Soft microfiber inside keeps case clean and scratch-free',
#     'Open and raise feature for easier access',
#     'Supports LED light and wireless charging',
#     'Compatible with both AirPods 1 & 2'],
#    'description': [],
#    'price': '17.99',
#    'store': 'Spigen',
#    'categories': ['Electronics', 'Headphones, Earbuds & Accessories', 'Cases'],
#    'details': {'Product Dimensions': '2.32 x 1.95 x 1.05 inches',
#     'Item Weight': '1.09 ounces',
#     'Item model number': 'ASD00678',
#     'Best Sellers Rank': {'Electronics': 114857, 'Headphone Cases': 9979},
#     'Date First Available': 'December 11, 2019',
#     'Manufacturer': 'Spigen',
#     'Brand': 'Spigen',
#     'Color': 'Midnight Green',
#     'Compatible Devices': 'AirPods 1 / 2',
#     'Form Factor': 'Case',
#     'Shell Type': 'Soft'},
#    'parent_asin': 'B07X2ZQ3MH'},
#   'review': {'rating': 5.0,
#    'title': 'Great case!',
#    'text': 'Great value in this case. If you don’t purchase Apple care or even if you do this is a must have. The only complaint I have is the case is difficult to remove if you need to hit the sync button on the back of the charging case because there is no indent or slot to do this with the case on.',
#    'parent_asin': 'B07X2ZQ3MH',
#    'timestamp': 1654168583079},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Electronics',
#    'title': 'VRS Design Modern for Apple Airpods Pro Case (2019) White [US Patent Registered]',
#    'average_rating': 4.5,
#    'rating_number': 5017,
#    'features': ['The combination of rugged PC and Flexible TPU offers a versatile protection from hard drops, scratches and contamination.',
#     'Sophisticatedly optimized sleek design offers perfect grip to your hand and durable protection all around.',
#     'Perfectly designed to showcase the front LED light.',
#     'The precisely cutout charging port ensures easy recharging without ever having to remove your Airpods Case.',
#     'Designed to work with most wireless chargers.'],
#    'description': [],
#    'price': '16.99',
#    'store': 'VRS DESIGN',
#    'categories': ['Electronics', 'Headphones, Earbuds & Accessories', 'Cases'],
#    'details': {'Package Dimensions': '4.4 x 3.3 x 1.2 inches',
#     'Item Weight': '1.58 ounces',
#     'Item model number': '909419',
#     'Best Sellers Rank': {'Electronics': 30096, 'Headphone Cases': 2142},
#     'Special features': 'Flexible',
#     'Form Factor': 'Case',
#     'Color': 'White',
#     'Whats in the box': 'Leather Strap',
#     'Manufacturer': 'VRS DESIGN',
#     'Country of Origin': 'China',
#     'Date First Available': 'April 23, 2020',
#     'Brand': 'VRS DESIGN',
#     'Compatible Devices': 'Earphones',
#     'Shell Type': 'Hard'},
#    'parent_asin': 'B087L49CCW'},
#   'review': {'rating': 5.0,
#    'title': 'Simply beautiful!',
#    'text': 'I loved this case so much I purchased one for my wife as well. Very aesthetically pleasing, minimalistic and protective. Best case on the market.',
#    'parent_asin': 'B087L49CCW',
#    'timestamp': 1654169099040},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Health_and_Household',
#    'title': 'Oarkive Thumb Saver Massage Tools Deep Tissue Massager Trigger Point Massage Tool Pressure Hand Massager Tool Reflexology Professional Neck Shoulder Back Foot Equipment for Therapists',
#    'average_rating': 4.3,
#    'rating_number': 145,
#    'features': ['Professionally Crafted for Therapeutic Relief - Designed with the intent to mimic the pressure of a human thumb, our thumb saver massage tool offers the perfect solution for individuals experiencing chronic muscle discomfort. Our device penetrates deep into muscle tissue, the trigger point tool working diligently to alleviate tension, provide relief, and stimulate circulation. The tmj massage tool provides a targeted approach to muscle therapy that few other pressure point tool can match.',
#     'Superior Comfort and Universal Compatibility - Our finger massager boasts an exceptionally comfortable grip and universal fit, ensuring the hard plastic massager can be handled easily by anyone, regardless of hand size. The ergonomic design promises an intuitive, comfortable hold, making the pressure point massage tool an indispensable asset for anyone in need of a deep, relieving massage, from professional therapists to everyday users seeking relief from muscle tension.',
#     'Built to Last with Outstanding Pressure Capabilities - Constructed with high-quality, robust plastic, our massage tools for deep tissue promise longevity and durability, making it the perfect companion for the rigors of deep tissue massage tool. Its sturdy construction allows for the application of significant pressure without risk of deformation or damage to the tool, the manual massage tools enabling users to work out even the most stubborn muscle knots effectively.',
#     "The Perfect Tool for Massage Professionals - This hand massage tool is an invaluable addition to any massage therapist's arsenal. The neck massage tool significantly reduces hand and finger fatigue, the tmj massager allowing therapists to deliver targeted, effective treatment over extended periods without straining their hands. The back knot remover is an essential device designed to increase efficiency and the overall quality of the massage experience for both the therapist and client.",
#     "Incredible Value for Unbeatable Performance - Considering its ergonomic design, high-quality materials and the exceptional relief it provides, our thumb massager represents a fantastic investment. The thumb massager tool is a cost-effective solution for those seeking professional-grade muscle relief. Whether you're a professional therapist looking to improve your practice or an individual desiring deep tissue relief at home, the manual therapy tools promise unmatched value for its performance."],
#    'description': ['Description:',
#     'Introducing the reflexology tools - your ultimate ally against chronic muscle tension, fatigue, and pain! Imagine a scar tissue tool crafted to',
#     'replicate the pressure of a human thumb, honed to provide the same relief. Yes, you heard it right! Our ergonomic, hardy tmj massage',
#     'tools are designed to act as a perfect extension of your hand, the jaw massager providing intense pressure for a profound release and a',
#     'therapeutic. The jaw massager tmj is all about elevating your self-care routine to epic proportions!',
#     'Features:',
#     '- Material: ABS.',
#     '- Size: 13.5x3.5x4cm / 5.3x1.4x1.6inch(LxWxH).',
#     '- The massage tools for therapists effortlessly delves into stubborn knots, the trigger point therapy tool relieving you from the unbearable',
#     'stress, the foot massage tool making you feel rejuvenated and revitalized.',
#     "- With our massage tools & equipment, you're in for an unprecedented comfort! Thanks to its universal compatibility and comfortable grip,",
#     'the massage accessories fit into hands large or small, chunky or slender.',
#     '- Made from robust, high-quality plastic, our massage hand tool will last longer than the knots in your back. No matter how much pressure',
#     'you apply, the couples personal massager will neither deform nor break.',
#     "- It's a lifestyle upgrade. Dive into the blissful world of self-care with a back massaging tool that is durable, effective, comfortable, and",
#     'ridiculously affordable.',
#     'Don’t wait',
#     '- add this wonder body pressure points to your cart and say hello to a world of relief! Get your massage supplies today and feel the',
#     'difference in every rub!',
#     'Package List:',
#     '1 * Massage Tools for Feet Massagers for Deep Tissue Chiropractor Tools Massager Soft Tissue Release Tool Phantom Massage'],
#    'price': '5.99',
#    'store': 'Oarkive',
#    'categories': ['Health & Household',
#     'Wellness & Relaxation',
#     'Massage Tools & Equipment',
#     'Massage Tools',
#     'Back Massagers'],
#    'details': {'Material': 'Acrylonitrile Butadiene Styrene',
#     'Brand': 'Oarkive',
#     'Color': 'Blue',
#     'Special Feature': 'heat',
#     'Product Dimensions': '5.3"L x 1.4"W x 1.6"H',
#     'Package Dimensions': '5.47 x 2.01 x 1.42 inches; 3.21 Ounces',
#     'Item model number': '1',
#     'Date First Available': 'April 26, 2022',
#     'Manufacturer': 'Oarkive'},
#    'parent_asin': 'B0CDCJ76KG'},
#   'review': {'rating': 5.0,
#    'title': 'Must have for massage therapist',
#    'text': 'If you are an LMT please buy this asap. If you practice trigger point therapy it is a must have. Many years of massage in this manner can blow your thumbs out.',
#    'parent_asin': 'B0CDCJ76KG',
#    'timestamp': 1654169241140},
#   'split': 'train'},
#  {'product_info': {'main_category': 'Home_and_Kitchen',
#    'title': 'RYB HOME White Tablecloth for Buffet - Waterproof Table Cloth Indoor Outdoor Use for Wedding Decorations Holiday Dinner Reception Table, 60 x 60, White',
#    'average_rating': 4.5,
#    'rating_number': 6018,
#    'features': ['Waterproof Polyester',
#     'CONVENIENT SIZE - Square table protector 60x60 inch. Multiuse for 6-8 foot square-shaped tabletops. Fits most folding buffet tables, outdoor picnic tables, kitchen & dining tables.',
#     'SPILLPROOF - Keeps your table surface protected from cold spills and scratches. Wipe the stain with wet cloth or wash it.',
#     "HARD WEARING - This versatile tablecloth is a perfect combination of waterproof, scratch & dust resistant, wrinkle-free and won't fade, tear, or pill after repeated use.Perfect for indoor and outdoor use.",
#     'RELAXED ELEGANCE - Our line of premium tablecloths offers a chic, affordable flair for every holiday party or family dinner. To provide family and guests with a fresh feeling.',
#     'EASY CARE - If there is stain, you can take a damp cloth with cleaner and spot wash. Machine washable. Iron at low temperature.'],
#    'description': [],
#    'price': '12.95',
#    'store': 'RYB HOME',
#    'categories': ['Home & Kitchen',
#     'Kitchen & Dining',
#     'Kitchen & Table Linens',
#     'Tablecloths'],
#    'details': {'Brand': 'RYB HOME',
#     'Color': 'White',
#     'Material': 'Fabric',
#     'Product Dimensions': '60"L x 60"W',
#     'Shape': 'Square',
#     'Pattern': 'Solid',
#     'Occasion': 'Wedding, Holiday',
#     'Size': '60 x 60 inch',
#     'Number of Sets': '1',
#     'Care instructions': 'Machine Wash',
#     'Unit Count': '1.0 Count',
#     'Fabric Type': 'Waterproof Polyester',
#     'Corner Style': 'Pleated',
#     'Number of Items': '1',
#     'Item Weight': '1.01 pounds',
#     'Manufacturer': 'RYB HOME',
#     'Country of Origin': 'China',
#     'Best Sellers Rank': {'Kitchen & Dining': 9424, 'Tablecloths': 304},
#     'Perfume': 'Unscented',
#     'Number of pieces': '1',
#     'Batteries required': 'No'},
#    'parent_asin': 'B07MZHWQTB'},
#   'review': {'rating': 5.0,
#    'title': 'Great table cloth',
#    'text': 'My wife purchased this for our new dining room table and she absolutely loves it. We have 2 teenage sons that still eat like they are 5 and this table cloth has been washed many times. It has not faded or shrunk and hang dries in about an hour. It hold up to its stain resistance and water repellent.',
#    'parent_asin': 'B07MZHWQTB',
#    'timestamp': 1673368637030},
#   'split': 'test'},
#  {'product_info': {'main_category': 'Home_and_Kitchen',
#    'title': 'Americanflat 11x17 Gold Picture Frame - Legal Sized Paper Display. - Engineered Wood with Shatter Resistant Glass - Horizontal and Vertical Formats for Wall',
#    'average_rating': 4.8,
#    'rating_number': 51,
#    'features': ['Design: Gold 11x17 frame, perfect for your cherished memories; comes with hanging hardware for hassle-free display in both horizontal and vertical formats to hang flat against the wall.',
#     'Material: Engineered wood frame with tempered shatter-resistant glass that gives a clear view of your picture.',
#     "Quality: Durable, gallery-style frame; the frame's front has clear glass and a sturdy backboard to keep your photo in place.",
#     'Use and Display: Perfect for 11x17 inch pictures and legal papers.',
#     'Protective Packaging: American flat developed exclusive proprietary packaging that helps ensure safe delivery of fragile items; order with confidence, click and add to cart today!'],
# ...
#    'parent_asin': 'B000OYQOCK',
#    'timestamp': 1673463874311},
#   'split': 'test'},
#  {'product_info': {'main_category': 'Health_and_Household',
#    'title': 'Garden of Life mykind Organics Extra Strength Turmeric Inflammatory Response 120 Tablets-100mg Curcumin (95% Curcuminoids) Black Pepper, Probiotics Organic Non-GMO Vegan Gluten Free Herbal Supplement',
#    'average_rating': 4.7,
#    'rating_number': 7685,
#    'features': ['Supports the body’s healthy inflammatory function and antioxidant response',
#     '100mg curcumin from organic whole turmeric root - plus ginger root - both fermented to support bioavailability',
#     'Probiotics & organic black pepper extract for enhanced digestion. Conventional corn alcohol is used',
#     'Nutrients from real foods using water extraction & clean tablet technology with 100% organic & non-GMO tablet materials - no soy or corn-derived ingredients',
#     'Certified USDA Organic, Non-GMO Project Verified, NSF Certified Gluten Free, Certified Vegan & Kosher',
#     "During the summer months products may arrive warm but Amazon stores and ships products in accordance with manufacturers' recommendations, when provided."],
#    'description': ['Turmeric root (especially curcumin) has been long known for its antioxidant and healthy inflammation response properties.† Our Extra Strength turmeric contains 100mg of curcumin. For an additional boost, we’ve added organic whole turmeric and ginger root fermented to support their bioavailability.'],
#    'price': '35.94',
#    'store': 'Garden of Life',
#    'categories': ['Health & Household',
#     'Vitamins, Minerals & Supplements',
#     'Herbal Supplements',
#     'Turmeric'],
#    'details': {'Item Form': 'Vegetarian Tablet',
#     'Brand': 'Garden of Life',
#     'Age Range (Description)': 'Adult',
#     'Diet Type': 'Gluten Free, Vegan',
#     'Material Feature': 'Organic, Genetically Modified Organism (GMO) Free',
#     'Is Discontinued By Manufacturer': 'False',
#     'Product Dimensions': '2.75 x 2.75 x 5.22 inches; 12 Ounces',
#     'Item model number': '103239',
#     'Date First Available': 'August 25, 2018',
#     'Manufacturer': 'Garden of Life',
#     'Country of Origin': 'USA'},
#    'parent_asin': 'B091F42KBN'},
#   'review': {'rating': 5.0,
#    'title': 'Must have supplement',
#    'text': 'Out of all the turmeric supplements I have tried this on is by far the best. Takes pain away fairly quick and as a bonus it has probiotics in them. Give your supplements at least 30 days to work their way into your system before deciding if they work for your body or not.',
#    'parent_asin': 'B091F42KBN',
#    'timestamp': 1673464303802},
#   'split': 'test'},
#  {'product_info': {'main_category': 'Health_and_Household',
#    'title': 'Garden of Life Vitamin D3 Liquid 1000 IU Per Spray, Vegan D3 Vitamin for Women and Men, Mykind Organic D3 Plus Omegas - Vanilla Flavor - 125 Servings - 2 fl oz Liquid Whole Food D3 Vitamin Supplement',
#    'average_rating': 4.5,
#    'rating_number': 5338,
#    'features': ["SAY YES TO VEGAN D3: Our mykind Organics Liquid D3 Spray contains 100% Plant Based and Certified Vegan vitamin D3 from Lichen (no lanolin); One spray delivers 1,000 IU of D3―250% of the Daily Value―or if you'd like, take 5 sprays for 5000 IU of vitamin D",
#     'IMMUNE SYSTEM SUPPORT THAT SHINES: Our Organic Vitamin D supplement promotes calcium absorption for healthy bones and supports immune system function with Vitashine, Vegan Certified vitamin D as cholecalciferol; No lanolin or animal-derived ingredients',
#     'D3 WE FOUND YOUR PERFECT MATCH: What better way to deliver fat-soluble vitamin D3 than with plant omegas; Our D3 vitamin includes a Certified Organic omega-rich blend of Pumpkin and Cranberry Seed Oils which deliver 4mg of Omega-3 fatty acids per serving',
#     'HELLO LIQUID SUNSHINE: Why take D3 softgels or gummies made with sugar when you can one spray and be done? This liquid vitamin D3 comes in a delicious Vanilla flavor and is only sweetened with a little Stevia―no sugar, artificial flavors or sweeteners',
#     'VEGAN FRIENDLY D3 VITAMIN: Our Whole Food D3 Spray for adults is real to the root—tested at every step and Third Party Certified—so you don’t have to settle for less than Vegan, Organic, Non GMO Project Verified, Gluten Free, Kosher & Carbon Neutral'],
#    'description': [],
#    'price': '17.49',
#    'store': 'Garden of Life',
#    'categories': ['Health & Household',
#     'Vitamins, Minerals & Supplements',
#     'Vitamins',
#     'Vitamin D'],
#    'details': {'Brand': 'Garden of Life',
#     'Item Form': 'Liquid',
#     'Primary Supplement Type': 'Vitamin D3',
#     'Diet Type': 'Gluten Free, Kosher, Vegan',
#     'Flavor': 'Vanilla'},
#    'parent_asin': 'B00K5NEPLW'},
#   'review': {'rating': 5.0,
#    'title': 'Only D3 my family uses',
#    'text': 'My family are vegan and we take D3 and B12 to make sure we are getting what we need. We only purchase this brand and our blood test show how well they work.',
#    'parent_asin': 'B00K5NEPLW',
#    'timestamp': 1676815449563},
#   'split': 'test'},
#  {'product_info': {'main_category': 'Electronics',
#    'title': 'Echo Dot (3rd Gen, 2018 release) - Smart speaker with Alexa - Charcoal',
#    'average_rating': 4.7,
#    'rating_number': 1034896,
#    'features': ['MEET ECHO DOT - Our most compact smart speaker that fits perfectly into small spaces.',
#     'RICH AND LOUD SOUND - Better speaker quality than Echo Dot Gen 2 for richer and louder sound. Pair with a second Echo Dot for stereo sound.',
#     'ALEXA HELPS YOU DO MORE WITH PRIME - Listen to millions of songs with Amazon Music, use your voice to for 2-day shipping, listen to audiobooks on Audible, and much more.',
#     'MAKE YOUR LIFE EASIER - Alexa can set timers, check the weather, read the news, adjust thermostats, answer questions, and more to help with daily tasks.',
#     'DESIGNED TO PROTECT YOUR PRIVACY – Built with multiple layers of privacy controls including the ability to delete your recordings, mute your mic, and more in-app privacy controls.',
#     'CONTROL MUSIC WITH A SIMPLE PHRASE - Echo Dot allows you to stream songs from Amazon Music, Apple Music, Spotify, SiriusXM, and others, as well as via Bluetooth. Voice control with Alexa makes it easy to skip to the next song, adjust the volume, and pause without getting up.',
#     "CONNECT WITH OTHERS HANDS-FREE - Call friends and family who have the Alexa app or an Echo device. Instantly drop in on other rooms or announce to the whole house that dinner's ready.",
#     'ALEXA HAS SKILLS - With tens of thousands of skills and counting, Alexa is always getting smarter and adding new skills like tracking fitness, playing games, and more.'],
#    'description': [],
#    'price': 'None',
#    'store': 'Amazon',
#    'categories': [],
#    'details': {},
#    'parent_asin': 'B07H65KP63'},
#   'review': {'rating': 5.0,
#    'title': 'Great smart home device',
#    'text': 'I love Amazon and all the Alexa based devices. This is a must have if getting into home automation. I own 6 of these and have them all over the house.',
#    'parent_asin': 'B07H65KP63',
#    'timestamp': 1676815567022},
#   'split': 'test'},
#  {'product_info': {'main_category': 'Home_and_Kitchen',
#    'title': 'OXO Good Grips 3-Piece Funnel and Strainer Set (Set of 2)',
#    'average_rating': 4.7,
#    'rating_number': 4688,
#    'features': ['Each set includes: 4-oz funnel, 16-oz funnel and strainer',
#     'Strainer fits in both funnels',
#     'Soft ribs on funnel neck for a secure fit in all size bottle openings',
#     'High-heat plastic can withstand hot liquids',
#     'Soft, comfortable grips'],
#    'description': ['OXO’s three piece multi-purpose Funnel Set is ideal for transferring and straining soups, sauces, dry goods and more. Large and small funnels accommodate any size job, and the detachable strainer fits in both funnels for added versatility. Soft ribs on the neck of the funnels allows for a secure fit in all size bottle openings to prevent spilling, and the ribs allow air to escape so liquids pour in smoothly without splashing. Go ahead and pour steamy soup or hot fruit purees; the funnels and strainer are made of high-heat plastic. Soft handles on the funnels provide a firm grip, and the three pieces nest for compact storage.'],
#    'price': '39.99',
#    'store': 'OXO',
#    'categories': ['Home & Kitchen',
#     'Kitchen & Dining',
#     'Kitchen Utensils & Gadgets',
#     'Specialty Tools & Gadgets',
#     'Funnels'],
#    'details': {'Package Dimensions': '9.5 x 5.8 x 4.7 inches',
#     'Item Weight': '0.01 ounces',
#     'Manufacturer': 'OXO',
#     'Item model number': '並行輸入品',
#     'Best Sellers Rank': {'Kitchen & Dining': 15715, 'Funnels': 64},
#     'Is Discontinued By Manufacturer': 'No',
#     'Date First Available': 'August 28, 2015'},
#    'parent_asin': 'B017JE6TJK'},
#   'review': {'rating': 5.0,
#    'title': 'Oxo is my favorite',
#    'text': 'I purchased these funnels for my wife, but I ended up using them and loving them even more. They are compact and great for storage and they are incredibly durable.',
#    'parent_asin': 'B017JE6TJK',
#    'timestamp': 1677757051983},
#   'split': 'test'},
#  {'product_info': {'main_category': 'Home_and_Kitchen',
#    'title': "OXO Good Grips Chef's Squeeze Bottle - Small, 6 oz,Plastic",
#    'average_rating': 4.7,
#    'rating_number': 26038,
#    'features': ['Unique attached cap stays open while you squeeze for a precise pour',
#     'Cap snaps closed for shaking and convenient storage',
#     'Durable, reusable Bottle is perfect for oil, vinegar, dressing, condiments, syrups and drizzling dessert toppings',
#     'Bottle feature convenient measurement markings in cups, oz and mL',
#     'BPA free Bottle comes apart for easy cleaning and is dishwasher safe'],
#    'description': ['Whether you’re adding oil to a pan, drizzling chocolate on a cheesecake, or squeezing ketchup on a burger, the OXO good grips chef’s squeeze bottles provide one-handed precision. Whether you need a thin tip for precision or a wide tip for thicker dressings and sauces, we’ve got you (and your squeeze bottle! ) covered with interchangeable lids, Each with a unique, attached cap.'],
#    'price': '8.81',
#    'store': 'OXO',
#    'categories': ['Home & Kitchen',
#     'Kitchen & Dining',
#     'Dining & Entertaining',
#     'Dinnerware & Serveware',
#     'Condiment Squeeze Bottles'],
#    'details': {'Brand': 'OXO',
#     'Material': 'Plastic',
#     'Bottle Type': 'squeeze bottle',
#     'Capacity': '180 Milliliters',
#     'Special Feature': 'Bpa Free,Dishwasher Safe',
#     'Product Dimensions': '1.9"W x 6.8"H',
#     'Product Care Instructions': 'Dishwasher Safe',
#     'Model Name': 'Squeeze bottle',
#     'Recommended Uses For Product': 'Reusable',
#     'Number of Items': '1',
#     'Reusability': 'Reusable',
#     'Shape': 'Round',
#     'Style': 'Small (6oz)',
#     'Unit Count': '1.0 Count',
#     'Item Weight': '1.13 ounces',
#     'Manufacturer': 'OXO',
#     'Country of Origin': 'China',
#     'Item model number': '11219200',
#     'Best Sellers Rank': {'Kitchen & Dining': 122,
#      'Condiment Squeeze Bottles': 1},
#     'Is Discontinued By Manufacturer': 'No',
#     'Date First Available': 'October 23, 2017'},
#    'parent_asin': 'B078VSTWRS'},
#   'review': {'rating': 5.0,
#    'title': 'Oxo is the best',
#    'text': 'Save your money and quit buying cheap condiment bottles that are probably poisoning you. These things are made of high quality materials and store well in the fridge. The spouts are two different sizes.',
#    'parent_asin': 'B078VSTWRS',
#    'timestamp': 1677757438528},
#   'split': 'test'},
#  {'product_info': {'main_category': 'Grocery_and_Gourmet_Food',
#    'title': 'FGO Organic Rosehips Tea, Eco-Conscious Tea Bags, 20 Count (Pack of 1)',
#    'average_rating': 4.6,
#    'rating_number': 112498,
#    'features': ['ROSEHIPS TEA BAGS - 20 Tea Bags filled with premium rose hips from Chile and hibiscus from Egypt.',
#     'ORGANIC ROSE HIPS TEA - The tea is filled into tea bags and packed into foil-lined kraft bags in California',
#     '20 ECO-CONSCIOUS TEA BAGS - Our premium tea bags are constructed of Abacá Hemp Fiber Paper. They are free of dyes, adhesive, glue and chlorine bleach. No staples, strings, bags or extra waste - just delicious tea!',
#     'CERTIFIED USDA ORGANIC & NON-GMO - All our products are certified USDA Organic and certified Non-GMO. Look for the USDA Organic and Non-GMO Project seals on our products!',
#     'LOVE IT OR WE BUY IT - We don’t think you should pay for products that you don’t love. If you aren’t enjoying our products, simply let us know and we will refund your order - it’s as easy as that!'],
#    'description': [],
#    'price': '6.99',
#    'store': 'FGO',
#    'categories': ['Grocery & Gourmet Food', 'Beverages', 'Tea', 'Black'],
#    'details': {'Package Dimensions': '7.91 x 4.92 x 1.61 inches; 1.41 Ounces',
#     'UPC': '850033278606',
#     'Manufacturer': 'FGO'},
#    'parent_asin': 'B0BVGZ3J4V'},
#   'review': {'rating': 5.0,
#    'title': 'Must have for healthy liver',
#    'text': 'I purchased this for my liver after finishing chemo. It is a must. Milk thistle is the best for your live right along with dandelion root. I drink a couple cups a day. It is better to get you supplements in their natural Whole Foods form.',
#    'parent_asin': 'B0BVGZ3J4V',
#    'timestamp': 1677757698058},
#   'split': 'test'},
#  {'product_info': {'main_category': 'Clothing_Shoes_and_Jewelry',
#    'title': 'Q of Hearts T-Shirt Women Vintage Graphic Tee Casual Letters Print Short Sleeve Tops',
#    'average_rating': 4.5,
#    'rating_number': 1810,
#    'features': ['65% Cotton, 35% Polyester',
#     '进口',
#     'Pull On closure',
#     'Hand Wash Only',
#     '★Material: Cotton Blend, Super Soft And Comfortable to Wear.',
#     '★Feature: Q of Hearts T-Shirt, Letter Print, Short Sleeve, O-Neck, Casual Fashion Style, Perfectly Pairing With a Simple Jean, Short, Legging or Short Skirt, You Can Tie Up The Size of The Shirt to Make It Look More Cute and Stylish',
#     '★Great for Halloween, Party, Workout, Work, Outdoor, Sports, Holiday, Travel, Daily Wear Etc.A Good Gift Choice for Youself, Your Friends, Your Dear Mom, Daughter, Family Members and So On.',
#     '★Suggest To Hand/Machine Wash Cold Water, Do Not Dry Clean, Do Not Drying, Not Bleach.',
#     '★Package included:1 * Womens Q of Hearts Playing Card T-Shirt Funny Vintage Graphic Tees Tops'],
#    'description': ['Womens Q of Hearts Shirt Cute Graphic Tees Short Sleeve Soft Casual T Shirts Tops',
#     'Product Details: 1.Queen of Hearts Graphic Tees, Short Sleeve, O-Neck, Loose Casual Style 2.You Can Match with Trousers, Jeans, or Skirts to Get a Casual Yet Stylish Look 3.Occasion: Perfect for Halloween Holiday, Party, Casual Wear, Work ,Outdoor Etc Size Chart: (1Inch=2.54cm): Small: Length 66cm/26.0"", Bust 95cm/37.43"", Sleeve 16cm/6.3"" Medium: Length 68cm/26.4"", Bust 99cm/39.00"", Sleeve 17cm/6.7"" Large: Length 70cm/27.9"", Bust 103cm/40.58"", Sleeve 18cm/7.1"" X-Large: Length 72cm/28.7"", Bust 108cm/42.55"", Sleeve 19cm/7.5"" Due to manual measurement, please allow the difference of 1-2cm, thank you!! Our Service: We get all of our products with strict inspection, For customer satisfaction service and experience, However, It still comes across defective occasionall If you receive damaged or wrong items, please with attached pictures to us, we will provide you a satisfactory solution within 24 hours.'],
#    'price': '16.99',
#    'store': 'BOMYTAO',
#    'categories': ['Clothing, Shoes & Jewelry',
#     'Women',
#     'Clothing',
#     'Tops, Tees & Blouses',
#     'T-Shirts'],
#    'details': {'Department': 'womens',
#     'Date First Available': 'September 20, 2020'},
#    'parent_asin': 'B08ZKGQ7NB'},
#   'review': {'rating': 5.0,
#    'title': 'Great shirt',
#    'text': 'Wonderful shirt and gift for a new mom. I purchased this for my daughter in law who is due soon. This shirt is made very well and fits as expected. Super soft as well.',
#    'parent_asin': 'B08ZKGQ7NB',
#    'timestamp': 1677758526010},
#   'split': 'test'}]

# %%
df_tasks = pd.DataFrame(user_instructions['train'])

# %%
df_tasks
# Out:
#                            user_id  \
# 0     AGG72WL34NYISSHBB2DWT64GQYVQ
# 1     AGG72WL34NYISSHBB2DWT64GQYVQ
# 2     AGG72WL34NYISSHBB2DWT64GQYVQ
# 3     AGG72WL34NYISSHBB2DWT64GQYVQ
# 4     AGG72WL34NYISSHBB2DWT64GQYVQ
# ...                            ...
# 6891  AGOPFQEWTQZGQUC4C2JORTPEWDSQ
# 6892  AGOPFQEWTQZGQUC4C2JORTPEWDSQ
# 6893  AFFNKZ7FZORBP7YF4RY3YCE4LVEQ
# 6894  AELEDUR7XBMUCCKG6SWXRPBIUKAQ
# 6895  AGOPFQEWTQZGQUC4C2JORTPEWDSQ
#
#                                                    task  \
# 0     Hey there! I'm super excited to find some high...
# 1     Hey there! I'm super excited to share my thoug...
# 2     Hey there! I'm looking for cozy home decor tha...
# 3     Hey there! I'm on the hunt for some comfy yet ...
# 4     Hey there! I'm on the hunt for a stunning wome...
# ...                                                 ...
# 6891  Looking for a reasonably priced, well-rated ga...
# 6892  Looking for a cozy, well-rated white duvet cov...
# 6893  Hi there! I'm thrilled about this Audiocrazy s...
# 6894  Hey there! I'm looking for a reliable WiFi ext...
# 6895  Hey there! Looking for cozy bedding options th...
#
#                                                  target      timestamp  \
# 0     {'product_info': {'main_category': 'Home_and_K...  1635795071313
# 1     {'product_info': {'main_category': 'Home_and_K...  1635795271127
# 2     {'product_info': {'main_category': 'Home_and_K...  1635795793414
# 3     {'product_info': {'main_category': 'Clothing_S...  1635796171434
# 4     {'product_info': {'main_category': 'Clothing_S...  1635796875217
# ...                                                 ...            ...
# 6891  {'product_info': {'main_category': 'Electronic...  1661796772413
# 6892  {'product_info': {'main_category': 'Home_and_K...  1661798120785
# 6893  {'product_info': {'main_category': 'Electronic...  1661799119485
# 6894  {'product_info': {'main_category': 'Electronic...  1661799444264
# 6895  {'product_info': {'main_category': 'Home_and_K...  1661799520100
#
#            type
# 0        search
# 1        review
# 2     recommend
# 3        search
# 4        search
# ...         ...
# 6891     search
# 6892     search
# 6893     review
# 6894     search
# 6895  recommend
#
# [6896 rows x 5 columns]

# %%
user_profiles['AGG72WL34NYISSHBB2DWT64GQYVQ']
# Out:
# {'user_profile': {'Gender': 'Female',
#   'Age': '35-44',
#   'Occupation': 'Writer',
#   'Price Sensitivity': 'Medium',
#   'Shopping Interest': 'Electronics, Home & Kitchen, Fashion, Health & Beauty',
#   'Brand Preference': 'Aibocn, DACHEE, IBENZER, Columbia, Nutrition Essentials, Stauffers, KitchenAid, Fossil, ILIFE, simplehuman, Utopia Bedding, HC COLLECTION, Linenspa, CINEYO, DearMy, Basic Brands, Roku, Anne Klein, Hanes, ZESICA, Madison Park',
#   'Diversity Preference': 'High',
#   'Interaction Complexity': 'High',
#   'Tone and Style': 'Enthusiastic, Detailed, Positive',
#   'Item Reference': 'Specific products and brands mentioned frequently',
#   'Focus Aspect': 'Quality, Brand, Price'}}

# %%
list(data.values())[9]
# Out:
# {'user_profile': {'Gender': 'Female',
#   'Age': '35-44',
#   'Occupation': 'Homemaker',
#   'Price Sensitivity': 'Medium',
#   'Shopping Interest': 'Home goods, Kitchen appliances, Clothing, Health supplements',
#   'Brand Preference': "De'Longhi, Columbia, Yaktrax, IZOD, Targus, ALL FOR YOU, Liberty Orchards, Grasshoppers, NuNaturals, Softwalk, PheromoneOil.com, Stance, Skechers, Shark, Secura, Fintie, MG, Simple Joys by Carter's, Amazon Basics, ThermoPro, Dockers, KOGMO, Nordic Naturals, Syncwire, Amazon, Hario, Potter's Mugs, NETGEAR, Reynolds, softan, Nature's Bounty, SUOSDEY, Industrial Rewind, Zacurate, KMC, Crocs, Burt's Bees Baby, Anker, Reebok, DASH, OXO",
#   'Diversity Preference': 'Medium',
#   'Interaction Complexity': 'Medium',
#   'Tone and Style': 'Positive, detailed, and appreciative',
#   'Item Reference': 'Specific products and brands mentioned in reviews',
#   'Focus Aspect': 'Average Rating, Number of Ratings, Quality, Fit, Comfort'}}

# %%
print(f"Extracted {len(personas)} personas.")
# Save extracted personas to a file
with open("extracted_personas.json", "w") as f:
    json.dump(personas, f, indent=2)
